# %%
# !pip install requests beautifulsoup4 lxml pandas
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (2.32.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (4.13.5)
# Requirement already satisfied: lxml in /usr/local/lib/python3.12/dist-packages (6.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests) (2025.11.12)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4) (4.15.0)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import sqlite3
from pathlib import Path
from typing import Dict, Any

DB_PATH = Path("/content/g1_goias_news.db")  # vai ficar salvo no /content do Colab

CREATE_TABLE_SQL = """
CREATE TABLE IF NOT EXISTS g1_goias_news (
    id INTEGER PRIMARY KEY AUTOINCREMENT,
    title TEXT NOT NULL,
    subtitle TEXT,
    url TEXT NOT NULL UNIQUE,
    section TEXT,
    city TEXT,
    author TEXT,
    published_at TEXT,
    updated_at TEXT,
    text TEXT,
    tags TEXT,
    raw_html TEXT,
    scraped_at TEXT NOT NULL
);
"""

def get_conn():
    DB_PATH.parent.mkdir(parents=True, exist_ok=True)
    conn = sqlite3.connect(DB_PATH)
    conn.execute("PRAGMA journal_mode=WAL;")
    conn.execute("PRAGMA foreign_keys = ON;")
    return conn

def init_db():
    conn = get_conn()
    with conn:
        conn.execute(CREATE_TABLE_SQL)
    conn.close()

def insert_news(conn, record: Dict[str, Any]):
    sql = """
    INSERT OR IGNORE INTO g1_goias_news
    (title, subtitle, url, section, city, author,
     published_at, updated_at, text, tags, raw_html, scraped_at)
    VALUES (:title, :subtitle, :url, :section, :city, :author,
            :published_at, :updated_at, :text, :tags, :raw_html, :scraped_at)
    """
    with conn:
        conn.execute(sql, record)

# %%
from dateutil import parser as dateparser
from datetime import datetime, timedelta, timezone

def parse_datetime(text: str):
    if not text:
        return None
    try:
        dt = dateparser.parse(text)
        return dt
    except Exception:
        return None

# %%
def fetch_article(url: str) -> Dict:
    print(f"[ARTICLE] Baixando: {url}")
    soup = get_soup(url)

    # Título (costuma ser <h1> mesmo)
    title_tag = soup.find("h1")
    title = title_tag.get_text(strip=True) if title_tag else None

    # Subtítulo (olhar no inspecionar: pode ser h2, div, etc.)
    subtitle_tag = soup.find("h2")
    subtitle = subtitle_tag.get_text(strip=True) if subtitle_tag else None

    # Autor (ajustar conforme o HTML real)
    author_tag = (
        soup.find(attrs={"itemprop": "author"})
        or soup.find(class_="content-author__name")
    )
    author = author_tag.get_text(strip=True) if author_tag else None

    # Datas
    published_at = None
    updated_at = None
    time_tags = soup.find_all("time")
    if time_tags:
        published_at = parse_datetime(
            time_tags[0].get("datetime") or time_tags[0].get_text()
        )
        if len(time_tags) > 1:
            updated_at = parse_datetime(
                time_tags[-1].get("datetime") or time_tags[-1].get_text()
            )

    # Seção (ajustar seletor conforme o HTML)
    section = None
    section_tag = soup.find("a", {"data-analytics": "header-section"})
    if section_tag:
        section = section_tag.get_text(strip=True)

    # Corpo da notícia
    # IMPORTANTE: veja no inspecionar qual é a div correta
    # Ex. típico: div.mc-body ou div#materia etc.
    container = soup  # troque por algo como soup.find("div", class_="mc-body")
    paragraphs_tags = container.find_all("p")
    paragraphs = [p.get_text(" ", strip=True) for p in paragraphs_tags]
    text = "\n".join(paragraphs) if paragraphs else None

    # Cidade (heurística)
    city = None
    if paragraphs:
        first_line = paragraphs[0]
        if " - " in first_line:
            maybe_city = first_line.split(" - ")[0]
            if len(maybe_city.split()) <= 4:
                city = maybe_city

    # Tags (se houver links de tag)
    tags = None
    tags_container = soup.find_all("a", rel="tag")
    if tags_container:
        tags_list = [t.get_text(strip=True) for t in tags_container]
        tags = json.dumps(tags_list, ensure_ascii=False)

    scraped_at = datetime.utcnow().isoformat()

    return {
        "title": title,
        "subtitle": subtitle,
        "url": url,
        "section": section,
        "city": city,
        "author": author,
        "published_at": published_at,
        "updated_at": updated_at,
        "text": text,
        "tags": tags,
        "raw_html": str(soup),
        "scraped_at": scraped_at,
    }

# %%
import requests
from bs4 import BeautifulSoup
import time
from datetime import datetime, timedelta, timezone

# 1) Ajuste ESSA constante com base na URL que você achou no DevTools
# Exemplo (você deve trocar pelo formato REAL que viu):
FEED_URL_TEMPLATE = "https://g1.globo.com/go/goias/ultimas-noticias/index/feed/pagina-{page}.ghtml"
HEADERS = {
    "User-Agent": "Mozilla/5.0 (compatible; G1GoiasScraper/1.0; +https://seu-email-ou-site)"
}

def get_soup(url: str) -> BeautifulSoup:
    resp = requests.get(url, headers=HEADERS, timeout=10)
    resp.raise_for_status()
    return BeautifulSoup(resp.text, "lxml")


def fetch_listing_links_from_feed(page: int) -> list[str]:
    """
    Usa a mesma URL que o botão 'veja mais' chamaria,
    e devolve os links de notícias encontrados nessa 'página' do feed.
    """
    url = FEED_URL_TEMPLATE.format(page=page)
    print(f"[FEED] Baixando página de feed: {url}")
    soup = get_soup(url)

    urls = set()

    # Aqui dá pra ser mais específico se você souber o seletor dos cards.
    # Enquanto isso, filtramos todos <a> com /go/goias/noticia/ na URL:
    for a in soup.select("a"):
        href = a.get("href")
        if not href:
            continue
        if "/go/goias/noticia/" in href and href.startswith("https://"):
            urls.add(href)

    return sorted(urls)


def crawl_ultimas_noticias_ate_6_meses(max_pages: int = 300, months: int = 6):
    """
    Simula 'scroll + veja mais' usando o endpoint de feed/pagina-{n},
    e vai salvando notícias até achar coisas mais velhas que `months` meses.

    max_pages: limite de páginas de feed pra não cair em loop infinito
    """
    from __main__ import init_db, get_conn, insert_news, fetch_article, parse_datetime

    init_db()
    conn = get_conn()

    cutoff = datetime.now(timezone.utc) - timedelta(days=30 * months)
    print(f"[INFO] Data de corte (aprox.): {cutoff}")

    seen_urls = set()
    pages_so_far = 0
    pages_only_old = 0  # contagem de páginas em que tudo é velho

    for page in range(1, max_pages + 1):
        pages_so_far += 1
        try:
            article_urls = fetch_listing_links_from_feed(page)
        except Exception as e:
            print(f"[STOP] Erro ao baixar feed da página {page}: {e}")
            break

        if not article_urls:
            print(f"[STOP] Feed da página {page} veio vazio. Encerrando.")
            break

        page_has_newer = False

        for url in article_urls:
            if url in seen_urls:
                continue
            seen_urls.add(url)

            try:
                record = fetch_article(url)
            except Exception as e:
                print(f"[ERROR] Falha ao baixar artigo {url}: {e}")
                continue

            pub_dt_raw = record.get("published_at")
            pub_dt = parse_datetime(pub_dt_raw) if pub_dt_raw else None

            pub_dt_utc = None
            if pub_dt is not None:
                if pub_dt.tzinfo is None:
                    pub_dt_utc = pub_dt.replace(tzinfo=timezone.utc)
                else:
                    pub_dt_utc = pub_dt.astimezone(timezone.utc)

            # Se temos data e ela é mais velha do que a data de corte:
            if pub_dt_utc is not None and pub_dt_utc < cutoff:
                print(
                    f"[SKIP] {record['title'][:60]}... ({pub_dt_utc.date()}) "
                    f"< corte ({cutoff.date()})"
                )
                continue

            # Se não temos data, eu prefiro salvar mesmo assim (você pode mudar isso)
            insert_news(conn, record)
            page_has_newer = True
            print(f"[OK] salvo: {record['title'][:80]}")

            time.sleep(1)

        if not page_has_newer:
            pages_only_old += 1
            # se algumas páginas seguidas só têm notícia velha, podemos parar
            if pages_only_old >= 3:
                print(
                    f"[STOP] {pages_only_old} páginas seguidas só com notícia mais velha que o corte. Encerrando."
                )
                break
        else:
            pages_only_old = 0

        # descanso entre pages de feed
        time.sleep(1)

    conn.close()
    print(f"[DONE] Processadas {pages_so_far} páginas de feed.")

# %%
for p in range(1, 4):
    print(FEED_URL_TEMPLATE.format(page=p))
# Out:
# https://g1.globo.com/go/goias/ultimas-noticias/index/feed/pagina-1.ghtml
# https://g1.globo.com/go/goias/ultimas-noticias/index/feed/pagina-2.ghtml
# https://g1.globo.com/go/goias/ultimas-noticias/index/feed/pagina-3.ghtml

# %%
crawl_ultimas_noticias_ate_6_meses(max_pages=28, months=6)
# Out:
# [INFO] Data de corte (aprox.): 2025-06-13 20:16:24.565987+00:00
# [FEED] Baixando página de feed: https://g1.globo.com/go/goias/ultimas-noticias/index/feed/pagina-1.ghtml
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/12/10/cantor-sertanejo-e-roubado-em-parque-de-goiania-video.ghtml
# /tmp/ipython-input-253435095.py:63: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   scraped_at = datetime.utcnow().isoformat()
# /tmp/ipython-input-2258786332.py:47: DeprecationWarning: The default datetime adapter is deprecated as of Python 3.12; see the sqlite3 documentation for suggested replacement recipes
#   conn.execute(sql, record)
# [OK] salvo: Cantor sertanejo é roubado em parque de Goiânia; vídeo
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/12/10/caso-valerio-luiz-stj-mantem-multa-a-advogados-que-abandonaram-juri.ghtml
# [OK] salvo: Caso Valério Luiz: STJ mantém multa a advogados que abandonaram júri
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/12/10/corpo-de-jovem-que-desapareceu-apos-nadar-em-rio-e-encontrado.ghtml
# [OK] salvo: Corpo de jovem que desapareceu após nadar em rio é encontrado
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/12/10/crianca-de-10-anos-que-foi-esfaqueada-multiplas-vezes-estava-em-cima-de-pe-de-manga-antes-de-ser-atacada-diz-familia.ghtml
# [OK] salvo: Menino de 10 anos que foi esfaqueado múltiplas vezes estava em cima de pé de man
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/12/10/ex-presidente-do-sindicato-rural-de-rio-verde-e-denunciado-por-crimes-sexuais-contra-funcionarias.ghtml
# [OK] salvo: Ex-presidente do Sindicato Rural de Rio Verde é denunciado por crimes sexuais co
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/12/10/goias-tem-alerta-de-tempestade-para-mais-de-180-cidades-veja-quais.ghtml
# [OK] salvo: Goiás tem alerta de tempestade para mais de 180 cidades; veja quais
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/12/10/suposto-assassino-em-serie-e-julgado-em-rio-verde.ghtml
# [OK] salvo: Suposto assassino em série é julgado em Rio Verde
# [FEED] Baixando página de feed: https://g1.globo.com/go/goias/ultimas-noticias/index/feed/pagina-2.ghtml
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/12/09/homem-em-surto-morre-afogado-apos-fugir-de-hospital-diz-bombeiros.ghtml
# [OK] salvo: Homem em surto morre afogado após fugir de hospital, diz bombeiros
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/12/09/jovem-desaparece-ao-tomar-banho-em-rio-em-jatai.ghtml
# [OK] salvo: Jovem desaparece ao tomar banho em rio, em Jataí
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/12/09/morte-de-filha-de-missionaria-causa-comocao-em-goias.ghtml
# [OK] salvo: Morte de filha de missionária causa comoção, em Goiás
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/12/10/homicidio-trafico-de-drogas-e-roubo-veja-crimes-pelos-quais-goianos-foram-incluidos-na-lista-dos-mais-procurados-do-brasil.ghtml
# [OK] salvo: Homicídio, tráfico de drogas e roubo: veja crimes pelos quais goianos foram incl
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/12/10/jovem-que-morreu-apos-bater-em-arvore-vendia-geladinhos-feliz-com-a-independencia-financeira-diz-amigo.ghtml
# [OK] salvo: Jovem que morreu após bater em árvore vendia geladinhos: 'feliz com a independên
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/12/10/operacao-investiga-grupo-suspeito-de-aplicar-golpes-com-venda-de-carros-de-luxo-e-de-lavagem-de-dinheiro-usando-criptomoedas.ghtml
# [OK] salvo: Operação investiga grupo suspeito de aplicar golpes com venda de carros de luxo
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/12/10/prefeitura-de-bela-vista-de-goias-abre-concurso-com-quase-300-vagas-e-salarios-de-ate-r-77-mil.ghtml
# [OK] salvo: Prefeitura de Bela Vista de Goiás abre concurso com quase 300 vagas e salários d
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/12/10/video-registra-milhares-de-tartarugas-que-nasceram-as-margens-do-rio-araguaia-em-goias.ghtml
# [OK] salvo: Vídeo registra milhares de tartarugas que nasceram às margens do Rio Araguaia, e
# [FEED] Baixando página de feed: https://g1.globo.com/go/goias/ultimas-noticias/index/feed/pagina-3.ghtml
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/12/09/crianca-de-10-anos-sofre-multiplas-facadas-apos-desavenca-durante-jogo-de-futebol-diz-policia.ghtml
# [OK] salvo: Criança de 10 anos sofre múltiplas facadas após desavença durante jogo de futebo
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/12/09/homem-e-preso-suspeito-de-matar-o-primo-a-facadas-durante-discussao.ghtml
# [OK] salvo: Homem é preso suspeito de matar o primo a facadas durante discussão
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/12/09/jovem-morre-apos-sofrer-queimaduras-enquanto-fazia-cafe.ghtml
# [OK] salvo: Jovem morre após sofrer queimaduras enquanto fazia café
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/12/09/jovem-que-levou-um-tiro-na-cabeca-do-ex-tem-filha-recem-nascida.ghtml
# [OK] salvo: Jovem que levou um tiro na cabeça do ex tem filha recém-nascida
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/12/09/leonardo-faz-homenagem-apos-morte-de-assessora-cuidou-de-mim-como-filho.ghtml
# [OK] salvo: Leonardo faz homenagem após morte de assessora: 'Cuidou de mim como filho'
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/12/09/lista-com-foragidos-mais-procurados-do-brasil-tem-sete-goianos.ghtml
# [OK] salvo: Lista com foragidos mais procurados do Brasil tem sete goianos
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/12/09/maria-flor-encanta-em-video-de-blogueira-e-virginia-brinca-com-carreira-para-a-filha-vai-seguir-os-passos-da-mamae.ghtml
# [OK] salvo: Maria Flor encanta em vídeo de blogueira, e Virginia brinca: 'Vai seguir os pass
# [FEED] Baixando página de feed: https://g1.globo.com/go/goias/ultimas-noticias/index/feed/pagina-4.ghtml
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/12/09/avo-e-neta-morrem-em-acidente-e-objetos-pessoais-sao-furtados.ghtml
# [OK] salvo: Avô e neta morrem em acidente, e objetos pessoais são furtados
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/12/09/camara-de-rio-verde-abre-inscricoes-para-concurso-com-108-vagas-e-salarios-de-ate-r-76-mil.ghtml
# [OK] salvo: Câmara de Rio Verde abre inscrições para concurso com 108 vagas e salários de at
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/12/09/cantor-leonardo-teve-gastroenterite-e-deve-receber-alta-nesta-terca-feira-diz-assessoria.ghtml
# [OK] salvo: Cantor Leonardo teve gastroenterite e deve receber alta nesta terça-feira, diz a
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/12/09/caso-do-pm-indiciado-por-matar-mecanico-que-tentou-fugir-de-blitz-e-reaberto.ghtml
# [OK] salvo: Caso do PM indiciado por matar mecânico que tentou fugir de blitz é reaberto
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/12/09/empresa-de-investimentos-e-suspeita-de-dar-golpes-em-clientes-em-goias.ghtml
# [OK] salvo: Empresa de investimentos é suspeita de dar golpes em clientes, em Goiás
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/12/09/leonardo-recebe-alta-apos-ser-internado-com-gastroenterite.ghtml
# [OK] salvo: Leonardo recebe alta após ser internado com gastroenterite
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/12/09/mae-de-adolescente-desabafa-apos-filhar-ser-arrastada-por-enxurrada-e-internada-na-uti-nunca-imaginei-que-isso-poderia-acontecer.ghtml
# [OK] salvo: Mãe de adolescente desabafa após filha ser arrastada por enxurrada e internada n
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/12/09/marginal-botafogo-projeto-de-obras-tera-dois-piscinoes-para-escoar-agua-e-deve-custar-r-120-milhoes-diz-prefeito-de-goiania.ghtml
# [OK] salvo: Marginal Botafogo: projeto de obras terá dois piscinões para escoar água e deve
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/12/09/motorista-que-ficou-ilhado-em-cima-de-carro-durante-alagamento-desabafa-preciso-recuperar-a-ferramenta-de-trabalho.ghtml
# [OK] salvo: Motorista que ficou ilhado em cima de carro durante alagamento desabafa: 'Precis
# [FEED] Baixando página de feed: https://g1.globo.com/go/goias/ultimas-noticias/index/feed/pagina-5.ghtml
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/12/08/cameras-em-vestiarios-de-industria-entenda-o-que-e-permitido-pela-lei-apos-ex-funcionaria-conseguir-indenizacao-em-goias.ghtml
# [OK] salvo: Câmeras em vestiários de indústria: entenda o que é permitido pela lei após ex-f
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/12/08/cantor-leonardo-e-internado-em-goiania.ghtml
# [OK] salvo: Cantor Leonardo é internado em Goiânia
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/12/08/garota-de-programa-espancada-na-saida-de-motel-foi-agredida-na-cabeca-diz-pm.ghtml
# [OK] salvo: Garota de programa espancada na saída de motel foi agredida na cabeça, diz PM
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/12/08/homem-atira-na-cabeca-da-ex-e-morre-em-confronto-com-a-policia-diz-pm.ghtml
# [OK] salvo: Homem atira na cabeça da ex e morre em confronto com a polícia, diz PM
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/12/08/homem-desaparece-apos-sair-para-trabalhar.ghtml
# [OK] salvo: Homem desaparece após sair para trabalhar
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/12/08/mulher-e-morta-e-filha-e-marido-sao-baleados-durante-atentado-em-praca-de-rio-verde-diz-delegado.ghtml
# [OK] salvo: Mulher é morta e filha e marido são baleados durante atentado em praça de Rio Ve
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/12/08/saiba-quem-era-a-enfermeira-de-rio-verde-que-morreu-apos-acidente-na-br-060.ghtml
# [OK] salvo: Saiba quem era a enfermeira de Rio Verde que morreu após acidente na BR-060
# [FEED] Baixando página de feed: https://g1.globo.com/go/goias/ultimas-noticias/index/feed/pagina-6.ghtml
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/12/08/motorista-que-ficou-ilhado-em-alagamento-na-marginal-botafogo-diz-que-avenida-nao-tinha-barreira.ghtml
# [OK] salvo: Motorista que ficou ilhado em alagamento na Marginal Botafogo diz que avenida nã
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/12/08/namorado-aproveita-visita-a-exposicao-de-natal-para-pedir-mulher-em-casamento-e-descobre-que-vai-ser-pai.ghtml
# [OK] salvo: Namorado aproveita visita à exposição de Natal para pedir mulher em casamento e
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/12/08/pm-que-resgatou-adolescente-que-ficou-presa-embaixo-de-carro-em-enxurrada-ouviu-gritos-desesperadores-da-irma-dela.ghtml
# [OK] salvo: PM que resgatou adolescente que ficou presa embaixo de carro em enxurrada ouviu
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/12/08/pm-suspeito-de-comandar-esquema-de-agiotagem-e-tortura-usava-redes-sociais-para-destacar-fe-deus-a-frente-abrindo-portas.ghtml
# [OK] salvo: PM suspeito de comandar esquema de agiotagem e tortura usava redes sociais para
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/12/08/tempestades-e-rajadas-de-vento-acima-de-60-kmh-podem-atingir-goias-nesta-semana-diz-cimehgo.ghtml
# [OK] salvo: Tempestades e rajadas de vento acima de 60 km/h podem atingir Goiás nesta semana
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/12/08/vendedora-e-morta-a-facadas-apos-ser-seguida-pelo-ex-em-goias-diz-policia.ghtml
# [OK] salvo: Vendedora é morta a facadas após ser seguida pelo ex-marido em Goiás, diz políci
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/12/08/video-de-corretora-mostrando-elevador-para-carro-em-um-predio-de-luxo-em-goias-viraliza.ghtml
# [OK] salvo: Vídeo de corretora mostrando elevador para carro em um prédio de luxo em Goiás v
# [FEED] Baixando página de feed: https://g1.globo.com/go/goias/ultimas-noticias/index/feed/pagina-7.ghtml
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/12/07/adolescente-e-resgatada-apos-ser-arrastada-pela-enxurrada-e-ficar-embaixo-de-carro-em-goias.ghtml
# [OK] salvo: Adolescente é resgatada após ser arrastada pela enxurrada e ficar embaixo de car
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/12/07/cancelas-devem-ser-instaladas-na-marginal-botafogo-e-avenida-87-em-60-dias-diz-prefeito-de-goiania.ghtml
# [OK] salvo: Cancelas devem ser instaladas na Marginal Botafogo e Avenida 87 em 60 dias, diz
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/12/07/enfermeira-morre-apos-acidente-enquanto-ia-para-o-trabalho-em-goias.ghtml
# [OK] salvo: Enfermeira morre após acidente enquanto ia para o trabalho, em Goiás
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/12/07/filha-usa-em-baile-de-formatura-o-mesmo-vestido-que-mae-vestiu-no-baile-dela-ha-28-anos.ghtml
# [OK] salvo: Filha usa em baile de formatura o mesmo vestido que mãe vestiu no baile dela há
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/12/07/marginal-botafogo-deve-passar-por-obras-e-intervencoes-apos-chuva-forte-diz-sandro-mabel-video.ghtml
# [OK] salvo: Marginal Botafogo deve passar por obras e intervenções após chuva forte, diz pre
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/12/07/video-mostra-momento-em-que-moto-e-levada-e-entregador-por-aplicativo-e-arrastado-pela-enxurrada-em-goiania.ghtml
# [OK] salvo: Vídeo mostra momento em que moto é levada e entregador por aplicativo é arrastad
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/12/07/virginia-atrai-curiosos-com-decoracao-de-natal-impressionante-em-jardim-virou-ponto-turistico-de-goiania.ghtml
# [OK] salvo: Virginia atrai curiosos com decoração de Natal impressionante em jardim: ‘Virou
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/12/08/goias-tem-o-municipio-com-a-maior-fiscalizacao-eletronica-por-numero-de-veiculos-do-brasil-aponta-pesquisa.ghtml
# [OK] salvo: Goiás tem o município com a maior fiscalização eletrônica por número de veículos
# [FEED] Baixando página de feed: https://g1.globo.com/go/goias/ultimas-noticias/index/feed/pagina-8.ghtml
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/12/06/chuva-forte-em-goiania-fecha-ruas-e-motorista-e-resgatado-apos-carro-ficar-ilhado-na-marginal-botafogo.ghtml
# [OK] salvo: Chuva forte em Goiânia fecha ruas e motorista é resgatado após carro ficar ilhad
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/12/06/jovem-morre-apos-motocicleta-bater-contra-objeto-em-rua-de-goias.ghtml
# [OK] salvo: Jovem morre após motocicleta bater contra objeto em rua de Goiás
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/12/06/suspeitos-de-integrar-faccao-criminosa-morrem-em-confronto-dentro-de-condominio-diz-policia.ghtml
# [OK] salvo: Suspeitos de integrar facção criminosa morrem em confronto dentro de condomínio
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/12/06/video-mostra-resgate-de-motorista-que-ficou-com-carro-ilhado-na-marginal-botafogo-durante-chuva-forte.ghtml
# [OK] salvo: Vídeo mostra resgate de motorista que ficou com carro ilhado na Marginal Botafog
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/12/07/bolo-de-fuba-cremoso-jornal-do-campo-ensina-receita-facil-e-deliciosa.ghtml
# [OK] salvo: Bolo de fubá cremoso: Jornal do Campo ensina receita fácil e deliciosa
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/12/07/cesio-137-conheca-historia-da-mulher-que-evitou-que-tragedia-radioativa-em-goias-fosse-ainda-maior.ghtml
# [OK] salvo: Césio-137: Conheça história da mulher que evitou que tragédia radioativa em Goiá
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/12/07/homem-que-morreu-apos-dar-salto-mortal-foi-socorrido-por-bombeiro-de-folga.ghtml
# [OK] salvo: Homem que morreu após dar salto mortal foi socorrido por bombeiro de folga
# [FEED] Baixando página de feed: https://g1.globo.com/go/goias/ultimas-noticias/index/feed/pagina-9.ghtml
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/12/05/caiado-diz-que-mantem-pre-candidatura-a-presidencia-mesmo-apos-flavio-bolsonaro-entrar-na-disputa.ghtml
# [OK] salvo: Caiado diz que mantém pré-candidatura à Presidência mesmo após Flávio Bolsonaro
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/12/05/cpi-investiga-vereador-suspeito-de-estuprar-estagiaria.ghtml
# [OK] salvo: CPI investiga vereador suspeito de estuprar estagiária
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/12/05/novas-imagens-mostram-acao-que-levou-a-morte-de-empresario-em-pastelaria.ghtml
# [OK] salvo: Novas imagens mostram ação que levou à morte de empresário em pastelaria
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/12/06/coronel-pode-ter-prometido-promocao-para-pm-matar-empresario-em-frente-a-pastelaria-diz-policia.ghtml
# [OK] salvo: Coronel pode ter prometido promoção para PM matar empresário em frente a pastela
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/12/06/homem-que-morreu-apos-salto-mortal-em-praca-tinha-dois-empregos-e-buscava-uma-vida-melhor-diz-familia-batalhou-muito.ghtml
# [OK] salvo: Homem que morreu após salto mortal em praça tinha dois empregos e buscava uma vi
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/12/06/maternidade-dona-iris-faz-mutirao-para-vacinacao-de-gravidas.ghtml
# [OK] salvo: Maternidade Dona Iris faz mutirão para vacinação de grávidas
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/12/06/patinacao-no-gelo-e-shows-veja-as-programacoes-de-natal-em-goias.ghtml
# [OK] salvo: Patinação no gelo e shows: Veja as programações de Natal em Goiás
# [FEED] Baixando página de feed: https://g1.globo.com/go/goias/ultimas-noticias/index/feed/pagina-10.ghtml
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/12/05/homem-e-suspeito-de-matar-companheira-com-pancadas-de-barra-de-ferro-em-goias.ghtml
# [OK] salvo: Homem é suspeito de matar companheira com pancadas de barra de ferro, em Goiás
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/12/05/industria-e-condenada-a-indenizar-ex-funcionaria-apos-denuncia-de-camera-em-vestiario-em-goias.ghtml
# [OK] salvo: Indústria é condenada a indenizar ex-funcionária após denúncia de câmera em vest
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/12/05/jovem-anda-de-caiaque-em-enxurrada-e-video-diverte-a-web-pode-pescar.ghtml
# [OK] salvo: Jovem anda de caiaque em enxurrada, e vídeo diverte a web: 'Pode pescar'
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/12/05/jovem-que-morreu-em-acidente-na-go-070-era-meu-braco-direito-diz-pai.ghtml
# [OK] salvo: Jovem que morreu em acidente na GO-070 era 'meu braço direito', diz pai
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/12/05/maes-contratam-carreta-da-alegria-para-comemorar-ultimo-dia-de-aula-dos-filhos-no-ensino-fundamental.ghtml
# [OK] salvo: Mães contratam carreta da alegria para comemorar último dia de aula dos filhos n
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/12/05/motorista-morre-apos-carreta-tombar-sobre-assentamento-as-margens-da-go-174.ghtml
# [OK] salvo: Motorista morre após carreta tombar sobre assentamento às margens da GO-174
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/12/05/pai-que-canta-louvor-com-os-filhos-em-bicicleta-pedala-3-km-para-levar-criancas-na-escola-comprei-para-levar-eles.ghtml
# [OK] salvo: Pai que canta louvor com os filhos em bicicleta pedala 3 km para levar crianças
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/12/05/vinganca-por-estupro-de-parente-de-coronel-da-pm-pode-ter-motivado-assassinato-de-dono-de-pastelaria-diz-policia.ghtml
# [OK] salvo: Vingança por estupro de parente de coronel da PM pode ter motivado assassinato d
# [FEED] Baixando página de feed: https://g1.globo.com/go/goias/ultimas-noticias/index/feed/pagina-11.ghtml
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/12/04/homem-morre-apos-levar-choque-enquanto-fazia-manutencao-em-telhado-em-trindade.ghtml
# [OK] salvo: Homem morre após levar choque enquanto fazia manutenção em telhado, em Trindade
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/12/04/jogador-e-suspeito-de-dar-golpe-contra-lotericas.ghtml
# [OK] salvo: Jogador de futebol é suspeito de golpe milionário contra lotéricas e levar vida
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/12/04/lotofacil-duas-apostas-de-goias-levam-quase-um-milhao-de-reais-ao-acertar-todos-os-numeros.ghtml
# [OK] salvo: Lotofácil: Duas apostas de Goiás levam quase um milhão de reais ao acertar todos
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/12/04/torcedores-ligados-ao-comando-vermelho-sao-presos-por-espancar-rivais-em-emboscada.ghtml
# [OK] salvo: Torcedores ligados ao Comando Vermelho são presos por espancar rivais em embosca
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/12/04/vagas-do-bdg-de-dezembro.ghtml
# [OK] salvo: Empresas oferecem mais de 190 vagas de emprego em Goiás
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/12/05/homem-que-morreu-apos-dar-salto-mortal-em-goiania-era-alegre-e-brincalhao-diz-prima.ghtml
# [OK] salvo: Homem que morreu após dar salto mortal em Goiânia era alegre e brincalhão, diz p
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/12/05/prefeitura-em-goias-abre-concurso-com-mais-de-80-vagas-e-salarios-de-ate-r-34-mil-veja-como-se-inscrever.ghtml
# [OK] salvo: Prefeitura em Goiás abre concurso com mais de 80 vagas e salários de até R$ 3,4
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/12/05/vacina-contra-bronquiolite-em-goias-quem-pode-tomar-e-quando.ghtml
# [OK] salvo: Vacina contra bronquiolite em Goiás: quem pode tomar e quando?
# [FEED] Baixando página de feed: https://g1.globo.com/go/goias/ultimas-noticias/index/feed/pagina-12.ghtml
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/12/04/acusado-de-assassinar-jovem-que-filmou-a-propria-morte-e-julgado-em-jatai.ghtml
# [OK] salvo: Acusado de assassinar jovem que filmou a própria morte é julgado em Jataí
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/12/04/homem-morre-apos-tentar-tomar-direcao-de-onibus-diz-policia.ghtml
# [OK] salvo: Homem morre após tentar tomar direção de ônibus, diz polícia
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/12/04/pms-sao-presos-em-operacao-que-investiga-morte-de-empresario-assassinado-a-tiros-em-frente-a-pastelaria.ghtml
# [OK] salvo: PMs são presos em operação que investiga morte de empresário assassinado a tiros
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/12/04/tio-de-advogada-suspeita-de-tortura-teve-nome-usado-para-abertura-de-conta-bancaria-apos-nao-pagar-emprestimo-dizem-familiares.ghtml
# [OK] salvo: Tio de advogada suspeita de tortura teve nome usado para abertura de conta bancá
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/12/04/virginia-impressiona-com-decoracao-de-natal-video.ghtml
# [OK] salvo: Virginia impressiona com decoração de Natal; vídeo
# [FEED] Baixando página de feed: https://g1.globo.com/go/goias/ultimas-noticias/index/feed/pagina-13.ghtml
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/12/03/goiana-e-finalista-de-concurso-que-elege-o-jardim-mais-bonito-do-brasil.ghtml
# [OK] salvo: Goiana é finalista de concurso que elege o jardim mais bonito do Brasil
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/12/03/homem-invade-casa-e-mata-duas-pessoas-em-maurilandia.ghtml
# [OK] salvo: Homem invade casa e mata duas pessoas, em Maurilândia
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/12/03/pm-de-goias-e-preso-suspeito-de-tentar-comprar-bebes-no-para.ghtml
# [OK] salvo: PM de Goiás é preso suspeito de tentar comprar bebês no Pará
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/12/03/vereador-denunciado-por-estupro-de-estagiaria-e-expulso-do-mdb.ghtml
# [OK] salvo: Vereador denunciado por estupro de estagiária é expulso do MDB
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/12/04/homem-que-morreu-ao-dar-salto-mortal-brincava-com-o-filho-em-parque-diz-familia.ghtml
# [OK] salvo: Homem que morreu ao dar salto mortal brincava com o filho em parque, diz família
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/12/04/professora-de-educacao-fisica-de-mineiros-que-morreu-estava-gravida-quando-descobriu-cancer.ghtml
# [OK] salvo: Professora de educação física de Mineiros que morreu estava grávida quando desco
# [FEED] Baixando página de feed: https://g1.globo.com/go/goias/ultimas-noticias/index/feed/pagina-14.ghtml
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/12/03/adolescente-desaparece-apos-sair-de-casa-para-vender-doces-em-goiania.ghtml
# [OK] salvo: Adolescente desaparece após sair de casa para vender doces, em Goiânia
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/12/03/adolescente-morre-com-tiro-no-peito-ao-jogar-roleta-russa-em-goias-diz-policia.ghtml
# [OK] salvo: Adolescente morre com tiro no peito ao jogar roleta-russa em Goiás, diz polícia
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/12/03/advogada-suspeita-de-tortura-extorsao-e-agiotagem-foi-presidente-da-comissao-de-direitos-humanos-da-oab.ghtml
# [OK] salvo: Advogada suspeita de tortura, extorsão e agiotagem foi presidente da comissão de
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/12/03/homem-e-condenado-por-matar-a-namorada-e-ex-com-golpes-de-espada.ghtml
# [OK] salvo: Jovem é condenado por matar a namorada e ex com golpes de espada
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/12/03/pai-canta-louvor-enquanto-leva-os-tres-filhos-em-bicicleta-para-a-escola-e-video-emociona.ghtml
# [OK] salvo: Pai canta louvor enquanto leva os três filhos em bicicleta para a escola, e víde
# [FEED] Baixando página de feed: https://g1.globo.com/go/goias/ultimas-noticias/index/feed/pagina-15.ghtml
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/12/02/acusado-de-chefiar-organizacao-criminosa-em-goias-se-entrega-a-policia.ghtml
# [OK] salvo: Acusado de chefiar organização criminosa em Goiás se entrega à polícia
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/12/02/ex-de-cachoeira-e-levada-a-delegacia-apos-invadir-escritorio-de-advocacia-em-goiania.ghtml
# [OK] salvo: Ex de Carlinhos Cachoeira é levada à delegacia após invadir escritório de advoca
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/12/02/homem-e-preso-suspeito-de-matar-a-ex-namorada-e-ligar-para-a-familia-dela-para-contar-o-crime.ghtml
# [OK] salvo: Homem é preso suspeito de matar a ex-namorada e ligar para a família dela para c
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/12/03/dermatologista-que-colhia-pequi-em-goias-conta-como-se-tornou-dr-colageno-e-socio-de-ana-hickmann.ghtml
# [OK] salvo: Dermatologista que colhia pequi em Goiás conta como se tornou Dr. Colágeno e sóc
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/12/03/filha-de-empresarios-morre-apos-carro-capotar-na-go-070-e-gera-comocao-em-cidade-de-goias.ghtml
# [OK] salvo: Filha de empresários morre após carro capotar na GO-070 e gera comoção em Goiás
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/12/03/garota-de-programa-espancada-na-saida-de-motel-foi-agredida-com-socos-e-garrafadas-diz-pm.ghtml
# [OK] salvo: Garota de programa espancada na saída de motel foi agredida com socos e garrafad
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/12/03/pedido-de-passagem-e-queda-entenda-caso-da-fa-que-deve-ser-indenizada-apos-ser-agredida-depois-de-show-de-henrique-e-juliano.ghtml
# [OK] salvo: Pedido de passagem e queda: entenda caso da fã que deve ser indenizada após ser
# [FEED] Baixando página de feed: https://g1.globo.com/go/goias/ultimas-noticias/index/feed/pagina-16.ghtml
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/12/02/casa-de-candomble-e-incendiada-em-goias-video.ghtml
# [OK] salvo: Casa de Candomblé é incendiada em Goiás; vídeo
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/12/02/casal-e-preso-suspeito-de-espancar-filho-apos-denuncia-de-vizinhos-em-rio-verde.ghtml
# [OK] salvo: Casal é preso suspeito de espancar filho após denúncia de vizinhos, em Rio Verde
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/12/02/corpos-sao-encontrados-em-rio-onde-aconteceu-acidente-em-ponte-em-goias.ghtml
# [OK] salvo: Três corpos são encontrados em rio onde aconteceu acidente em ponte, em Goiás
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/12/02/garota-de-programa-e-espancada-na-saida-de-motel-e-suspeito-morre-em-confronto-com-pm-diz-policia.ghtml
# [OK] salvo: Garota de programa é espancada na saída de motel, e suspeito morre em confronto
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/12/02/homem-e-preso-suspeito-de-estuprar-a-enteada-de-13-anos-em-anapolis.ghtml
# [OK] salvo: Homem é preso suspeito de estuprar a enteada de 13 anos, em Anápolis
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/12/02/mae-de-uma-bebe-alegre-e-incentivadora-veja-quem-era-a-professora-de-educacao-fisica-que-morreu-em-mineiros.ghtml
# [OK] salvo: Mãe de uma bebê, alegre e incentivadora: veja quem era a professora de educação
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/12/02/taco-de-beisebol-arma-na-cabeca-e-espancamento-veja-como-agiam-advogada-pms-e-empresarios-em-esquema-de-tortura-e-agiotagem.ghtml
# [OK] salvo: Taco de beisebol, arma na cabeça e espancamento: veja como agiam advogada, PMs e
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/12/02/tecnica-de-enfermagem-morta-em-distribuidora-tinha-se-mudado-para-casa-de-amiga-por-medo-do-ex.ghtml
# [OK] salvo: Técnica de enfermagem morta em distribuidora tinha se mudado para casa de amiga
# [FEED] Baixando página de feed: https://g1.globo.com/go/goias/ultimas-noticias/index/feed/pagina-17.ghtml
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/12/01/advogada-envolvida-em-esquema-de-agiotagem-e-tortura-com-pms-faz-oracao-sobre-dinheiro-agradeco-senhor-pela-prosperidade-video.ghtml
# [OK] salvo: Advogada envolvida em esquema de agiotagem e tortura com PMs faz oração sobre di
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/12/01/empresa-de-henrique-e-juliano-e-condenada-a-indenizar-fa-agredida-por-seguranca-apos-show.ghtml
# [OK] salvo: Empresa de Henrique e Juliano é condenada a indenizar fã agredida por segurança
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/12/01/ex-prefeito-de-ipora-nacoitan-leite-e-condenado-por-defender-eliminar-moraes-e-lula.ghtml
# [OK] salvo: Ex-prefeito de Iporá, Naçoitan Leite é condenado por defender ‘eliminar’ Moraes
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/12/01/filho-de-jorge-da-dupla-com-mateus-surpreende-ao-cantar-em-apresentacao.ghtml
# [OK] salvo: Filho de Jorge, da dupla com Mateus, surpreende ao cantar em apresentação
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/12/01/filho-que-emocionou-mae-em-video-se-mudou-para-londres-para-dar-vida-melhor-aos-pais-dar-oportunidades-para-eles.ghtml
# [OK] salvo: Filho que emocionou mãe em vídeo se mudou para Londres para dar vida melhor aos
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/12/01/homem-e-morto-a-tiros-dentro-de-casa-por-criminoso-encapuzado.ghtml
# [OK] salvo: Homem é morto a tiros dentro de casa por criminoso encapuzado
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/12/01/raro-e-impressionante-conheca-o-pequi-branco-encontrado-em-goias.ghtml
# [OK] salvo: Raro e impressionante: conheça o pequi branco encontrado em Goiás
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/12/02/mae-fala-de-emocao-ao-buscar-filho-pela-ultima-vez-em-escola-entreguei-um-menino-e-busquei-um-homem.ghtml
# [OK] salvo: Mãe fala de emoção ao buscar filho pela última vez em escola: ‘Entreguei um meni
# [FEED] Baixando página de feed: https://g1.globo.com/go/goias/ultimas-noticias/index/feed/pagina-18.ghtml
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/12/01/adolescente-morre-afogado-em-rio-em-aparecida-de-goiania.ghtml
# [OK] salvo: Adolescente morre afogado em rio, em Aparecida de Goiânia
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/12/01/dois-servidores-da-comurg-morrem-apos-baterem-moto-em-carro-em-goiania.ghtml
# [OK] salvo: Dois servidores da Comurg morrem após baterem moto em carro, em Goiânia
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/12/01/entenda-o-caso-da-advogada-e-dos-pms-presos-suspeitos-de-tortura-extorsao-e-agiotagem.ghtml
# [OK] salvo: Entenda o caso da advogada e dos PMs presos suspeitos de agiotagem, extorsão e l
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/12/01/homem-e-assassinado-durante-briga-por-jogo-de-sinuca-em-goiania-diz-pm.ghtml
# [OK] salvo: Homem é assassinado durante briga por jogo de sinuca em Goiânia, diz PM
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/12/01/mae-e-presa-suspeita-de-abandono-de-incapaz-apos-quatro-criancas-serem-encontradas-trancadas-e-sem-comida.ghtml
# [OK] salvo: Mãe é presa suspeita de abandono de incapaz após quatro crianças serem encontrad
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/12/01/tecnica-de-enfermagem-morta-pelo-ex-pediu-medida-protetiva-dias-antes-do-crime-diz-policia.ghtml
# [OK] salvo: Técnica de enfermagem morta pelo ex pediu medida protetiva dias antes do crime,
# [FEED] Baixando página de feed: https://g1.globo.com/go/goias/ultimas-noticias/index/feed/pagina-19.ghtml
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/11/30/amigos-espalham-fotos-de-palmeirenses-desaparecidos-apos-a-final-da-libertadores-e-video-diverte-a-web.ghtml
# [OK] salvo: Amigos espalham fotos de palmeirenses 'desaparecidos' após a final da Libertador
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/11/30/filho-que-mora-em-londres-emociona-mae-ao-voltar-para-casa-de-surpresa-video.ghtml
# [OK] salvo: Filho que mora em Londres emociona mãe ao voltar para casa de surpresa; vídeo
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/11/30/goiano-que-morreu-em-queda-de-aviao-em-mt-tinha-realizado-sonho-de-se-tornar-piloto.ghtml
# [OK] salvo: Goiano que morreu em queda de avião em MT tinha realizado sonho de se tornar pil
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/11/30/homem-e-preso-suspeito-de-matar-enteado-com-mais-de-30-facadas-em-itumbiara.ghtml
# [OK] salvo: Homem é preso suspeito de matar enteado com mais de 30 facadas, em Itumbiara
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/11/30/mae-de-bebe-entregue-para-adocao-de-forma-ilegal-quer-recem-nascido-de-volta-quero-justica.ghtml
# [OK] salvo: Mãe de bebê entregue para adoção de forma ilegal quer recém-nascido de volta: ‘Q
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/11/30/mega-sena-apostas-de-goias-acertam-cinco-numeros-e-levam-juntas-mais-de-r-100-mil.ghtml
# [OK] salvo: Mega-Sena: apostas de Goiás acertam cinco números e levam juntas mais de R$ 100
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/11/30/morte-de-professora-de-natacao-causa-comocao-em-mineiros.ghtml
# [OK] salvo: Morte de professora de educação física causa comoção, em Goiás
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/11/30/video-de-meninos-abracando-e-beijando-ferrari-em-goias-emociona-a-web-se-voce-pode-tocar-voce-pode-ter.ghtml
# [OK] salvo: Vídeo de meninos abraçando e beijando Ferrari em Goiás emociona a web: ‘Se você
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/12/01/mais-de-70-cidades-tem-alerta-de-tempestade-em-goias.ghtml
# [OK] salvo: Mais de 70 cidades têm alerta de tempestade, em Goiás; veja quais
# [FEED] Baixando página de feed: https://g1.globo.com/go/goias/ultimas-noticias/index/feed/pagina-20.ghtml
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/11/29/atleta-do-goias-que-morreu-em-acidente-de-quadriciclo-e-homenageado-em-conquista-de-campeonato.ghtml
# [OK] salvo: Atleta do Goiás que morreu em acidente de quadriciclo é homenageado em conquista
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/11/29/estudante-de-medicina-e-preso-suspeito-de-venda-ilegal-de-remedios-para-emagrecer.ghtml
# [OK] salvo: Estudante de medicina é preso suspeito de venda ilegal de remédios para emagrece
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/11/29/influenciador-emociona-ao-presentear-irmaos-com-dois-carros-em-anapolis.ghtml
# [OK] salvo: Influenciador emociona ao presentear irmãos com dois carros, em Anápolis
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/11/29/lotofacil-aposta-de-goias-leva-mais-de-r-770-mil.ghtml
# [OK] salvo: Lotofácil: Aposta de Goiás leva mais de R$ 770 mil
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/11/29/mulher-e-morta-pelo-ex-com-tiros-a-queima-roupa-em-distribuidora-de-bebidas-em-goias.ghtml
# [OK] salvo: Técnica em enfermagem é morta pelo ex com tiros à queima roupa em distribuidora
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/11/29/pais-se-emocionam-ao-buscar-os-filhos-pela-ultima-vez-em-escola-de-ensino-medio-em-goias-video.ghtml
# [OK] salvo: Pais se emocionam ao buscar os filhos pela última vez em escola de ensino médio,
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/11/29/piloto-goiano-esta-entre-as-vitimas-de-aviao-que-caiu-no-mt.ghtml
# [OK] salvo: Piloto goiano está entre as vítimas de avião que caiu no MT
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/11/29/radares-de-goiania-param-de-funcionar-por-falta-de-pagamento-diz-consorcio.ghtml
# [OK] salvo: Consórcio suspende radares de Goiânia por falta de pagamento
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/11/29/zelador-que-pediu-demissao-apos-sofrer-racismo-trabalhava-ha-poucos-meses-na-escola-e-ja-tinha-sido-promovido-duas-vezes.ghtml
# [OK] salvo: Zelador que pediu demissão após sofrer racismo trabalhava há poucos meses na esc
# [FEED] Baixando página de feed: https://g1.globo.com/go/goias/ultimas-noticias/index/feed/pagina-21.ghtml
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/11/28/filhos-sao-indiciados-por-mandar-matar-fazendeiro-para-ficar-com-heranca-bilionaria.ghtml
# [OK] salvo: Filhos são indiciados por mandar matar fazendeiro para ficar com herança bilioná
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/11/28/foto-inedita-de-cristiano-araujo-e-publicada-por-fotografo.ghtml
# [OK] salvo: Foto inédita de Cristiano Araújo é publicada por fotógrafo
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/11/28/menino-morre-afogado-em-represa-de-goias.ghtml
# [OK] salvo: Menino morre afogado em represa de Goiás
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/11/28/veja-o-que-se-sabe-sobre-o-caso-do-bebe-entregue-para-adocao-de-forma-ilegal-em-goias.ghtml
# [OK] salvo: Veja o que se sabe sobre o caso do bebê entregue para adoção de forma ilegal, em
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/11/28/zelador-de-colegio-pede-demissao-apos-receber-bilhete-racista-nojo-da-sua-raca.ghtml
# [OK] salvo: Zelador de colégio pede demissão após receber bilhete racista: 'Nojo da sua raça
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/11/29/catarata-dos-couros-conheca-complexo-de-cachoeiras-que-esta-entre-os-mais-visitados-da-chapada-dos-veadeiros.ghtml
# [OK] salvo: Catarata dos Couros: conheça complexo de cachoeiras que está entre os mais visit
# [FEED] Baixando página de feed: https://g1.globo.com/go/goias/ultimas-noticias/index/feed/pagina-22.ghtml
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/11/28/estagiaria-denuncia-vereador-de-urutai-por-estupro.ghtml
# [OK] salvo: Estagiária denuncia vereador de Urutaí por estupro
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/11/28/fraudes-em-manutencao-de-ambulancias-do-samu-entre-2022-e-2024-incluiu-abastecimento-e-lavagem-a-veiculos-sucateados-dizem-pf-e-cgu.ghtml
# [OK] salvo: Fraude em manutenção de ambulâncias do Samu entre 2022 e 2024 incluiu abastecime
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/11/28/homem-e-condenado-a-33-anos-de-prisao-por-matar-soldado-da-base-aerea-de-anapolis-que-reagiu-a-assalto-em-padaria.ghtml
# [OK] salvo: Homem é condenado a 33 anos de prisão por matar soldado da Base Aérea de Anápoli
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/11/28/jovem-desaparece-apos-fugir-de-clinica-psiquiatrica-em-aparecida-de-goiania.ghtml
# [OK] salvo: Jovem desaparece após fugir de clínica psiquiátrica, em Aparecida de Goiânia
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/11/28/norte-americana-que-morreu-em-goiania-tinha-problemas-de-saude-e-nao-sofreu-violencia-sexual-diz-policia.ghtml
# [OK] salvo: Norte-americana que morreu em Goiânia tinha problemas de saúde e não sofreu viol
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/11/28/tecnica-de-enfermagem-denuncia-que-foi-agredida-por-mae-de-paciente-durante-vacinacao-video.ghtml
# [OK] salvo: Técnica de enfermagem denuncia que foi agredida por mãe de paciente durante vaci
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/11/28/virgina-recebe-buque-gigante-de-vini-jr-ao-completarem-um-mes-de-namoro-1-mes-de-muitos-que-virao.ghtml
# [OK] salvo: Virginia recebe buquê gigante de Vini Jr ao completarem um mês de namoro: ‘1° mê
# [FEED] Baixando página de feed: https://g1.globo.com/go/goias/ultimas-noticias/index/feed/pagina-23.ghtml
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/11/28/conheca-cidade-goiana-que-tem-mais-de-mil-industrias-e-e-considerada-a-capital-do-jeans.ghtml
# [OK] salvo: Conheça cidade goiana que tem mais de mil indústrias e é considerada a capital d
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/11/28/falsos-representantes-da-caixa-sao-suspeitos-de-desviar-cerca-de-r-26-milhoes-de-prefeitura-diz-policia.ghtml
# [OK] salvo: Falsos representantes da Caixa são suspeitos de desviar cerca de R$ 2,6 milhões
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/11/28/mae-de-recem-nascido-adotado-irregularmente-passou-procuracao-para-casal-diz-conselho.ghtml
# [OK] salvo: Mãe de bebê entregue à adoção de forma ilegal passou procuração para casal, diz
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/11/28/marido-e-preso-suspeito-de-espancar-gravida-de-8-meses.ghtml
# [OK] salvo: Marido é preso suspeito de espancar grávida de 8 meses
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/11/28/nota-goiana-moradora-de-goiania-leva-r-50-mil-em-premio-veja-lista-ganhadores.ghtml
# [OK] salvo: Nota Goiana: Moradora de Goiânia leva R$ 50 mil em prêmio; veja lista ganhadores
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/11/28/operacao-mira-fraudes-em-contratos-de-ambulancias-do-samu-em-goiania.ghtml
# [OK] salvo: Operação mira fraudes em contratos de ambulâncias do Samu em Goiânia entre 2022
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/11/28/pe-de-pequi-no-meio-da-rua-impressiona-e-encanta-moradores-em-goias.ghtml
# [OK] salvo: Pé de pequi no meio da rua impressiona e encanta moradores, em Goiás
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/11/28/veja-quem-era-a-cantora-gospel-que-morreu-e-causou-comocao-em-goias.ghtml
# [OK] salvo: Veja quem era a cantora gospel que morreu e causou comoção, em Goiás
# [FEED] Baixando página de feed: https://g1.globo.com/go/goias/ultimas-noticias/index/feed/pagina-24.ghtml
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/11/27/delegado-humberto-teofilo-comenta-perseguicoes-em-video-em-que-comunicou-afastamento-nao-prendi-so-ladrao-de-galinha.ghtml
# [OK] salvo: Delegado Humberto Teófilo comenta ‘perseguições’ em vídeo em que comunicou afast
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/11/27/mae-de-menino-que-morreu-apos-ser-picado-por-abelhas-desabafa-sobre-ultimos-minutos-fiquei-do-lado-ate-a-ultima-batida-do-coracao.ghtml
# [OK] salvo: Mãe de menino que morreu após ser picado por abelhas desabafa sobre últimos minu
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/11/27/medica-e-agredida-por-paciente-dentro-de-upa-em-aparecida-de-goiania.ghtml
# [OK] salvo: Médica é agredida por paciente dentro de UPA, em Aparecida de Goiânia
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/11/27/morre-professor-negro-que-serviu-de-modelo-para-o-monumento-as-tres-racas-em-goiania.ghtml
# [OK] salvo: Morre professor negro que serviu de modelo para o Monumento às Três Raças, em Go
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/11/27/pastor-que-dizia-incorporar-anjos-para-abusar-sexualmente-de-fieis-e-condenado-a-mais-de-100-anos.ghtml
# [OK] salvo: Pastor que dizia incorporar anjos para abusar sexualmente de fiéis é condenado a
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/11/27/ponte-entre-go-e-mt-impressiona-por-altura-e-vista-privilegiada-do-rio-araguaia.ghtml
# [OK] salvo: Ponte entre GO e MT impressiona por altura e vista privilegiada do Rio Araguaia
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/11/27/semelhanca-entre-marilia-mendonca-e-atriz-leandra-leal-impressiona-fas.ghtml
# [OK] salvo: Semelhança entre Marília Mendonça e atriz Leandra Leal impressiona fãs
# [FEED] Baixando página de feed: https://g1.globo.com/go/goias/ultimas-noticias/index/feed/pagina-25.ghtml
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/11/27/20o-feirao-classi-reune-mais-de-600-veiculos-em-mega-black-friday.ghtml
# [OK] salvo: 20º Feirão Classi reúne mais de 600 veículos em mega Black Friday
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/11/27/casa-com-neve-na-decoracao-de-natal-chama-a-atencao-em-senador-canedo-video.ghtml
# [OK] salvo: Casa com neve na decoração de Natal chama a atenção em Senador Canedo; vídeo
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/11/27/ex-candidato-a-prefeito-e-preso-em-apartamento-de-luxo-apos-ser-condenado-por-matar-seguranca-de-boate.ghtml
# [OK] salvo: Ex-candidato a prefeito é preso em apartamento de luxo após ser condenado por ma
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/11/27/jovem-diverte-a-web-com-video-bem-humorado-sobre-momento-em-que-foi-arrastada-por-enxurrada-em-goias-blogueira-cai-dentro-de-bueiro.ghtml
# [OK] salvo: Jovem diverte a web com vídeo bem-humorado sobre momento em que foi arrastada po
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/11/27/jovem-que-surpreendeu-juiza-ao-reaparecer-em-audiencia-e-foi-morto-em-confronto-tinha-passagens-por-homicidio-roubo-e-trafico-diz-policia-militar.ghtml
# [OK] salvo: Jovem que surpreendeu juíza ao reaparecer em audiência e foi morto em confronto
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/11/27/morre-idosa-norte-americana-que-teria-sofrido-abuso-sexual-em-goiania.ghtml
# [OK] salvo: Morre idosa norte-americana que teria sofrido abuso sexual em Goiânia
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/11/27/novas-tecnologias-e-formacao-de-jovens-para-aprimorar-o-trabalho-no-campo-sao-apostas-do-senar-em-goias.ghtml
# [OK] salvo: Novas tecnologias e formação de jovens para aprimorar o trabalho no campo são ap
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/11/27/quanto-custa-morrer-em-goiania-veja-o-preco-dos-itens-de-funeral-e-enterro.ghtml
# [OK] salvo: Quanto custa morrer em Goiânia? Veja o preço dos itens de funeral e enterro
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/11/27/tortura-e-tentativa-de-estupro-entenda-crimes-pelos-quais-trisal-que-manteve-adolescente-em-carcere-foi-indiciado.ghtml
# [OK] salvo: Tortura e tentativa de estupro: entenda crimes pelos quais trisal que manteve ad
# [FEED] Baixando página de feed: https://g1.globo.com/go/goias/ultimas-noticias/index/feed/pagina-26.ghtml
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/11/26/caiado-recebe-alta-apos-ficar-internado-para-tratar-arritmia.ghtml
# [OK] salvo: Caiado recebe alta após ficar internado para tratar arritmia
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/11/26/cantor-e-condenado-por-espancar-parceira-de-dupla-sertaneja.ghtml
# [OK] salvo: Cantor é condenado por espancar parceira de dupla sertaneja
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/11/26/cuidadora-filho-e-nora-sao-suspeitos-de-furtar-mais-de-r-100-mil-de-casal-de-idosos.ghtml
# [OK] salvo: Cuidadora, filho e nora são suspeitos de furtar mais de R$ 100 mil de casal de i
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/11/26/goias-tem-novo-alerta-de-tempestade-e-chuva-com-granizo-para-mais-de-200-cidades-veja-lista.ghtml
# [OK] salvo: Goiás tem novo alerta de tempestade e chuva com granizo para mais de 200 cidades
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/11/26/homem-e-preso-suspeito-de-matar-amigo-envenenado-e-enterrar-o-corpo-no-quintal-de-casa.ghtml
# [OK] salvo: Homem é preso suspeito de matar amigo envenenado e enterrar o corpo no quintal d
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/11/26/morre-jovem-que-surpreendeu-juiza-ao-reaparecer-em-audiencia-de-custodia.ghtml
# [OK] salvo: Morre jovem que surpreendeu juíza ao reaparecer em audiência de custódia: 'Você
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/11/26/morte-de-cantora-gospel-causa-comocao-em-niquelandia.ghtml
# [OK] salvo: Morte de cantora gospel causa comoção, em Niquelândia
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/11/26/recem-nascido-e-resgatado-apos-ser-entregue-para-adocao-de-forma-ilegal-em-goias.ghtml
# [OK] salvo: Recém-nascido é resgatado após ser entregue para adoção de forma ilegal, em Goiá
# [FEED] Baixando página de feed: https://g1.globo.com/go/goias/ultimas-noticias/index/feed/pagina-27.ghtml
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/11/26/advogado-morre-apos-carro-bater-e-pegar-fogo-em-catalao.ghtml
# [OK] salvo: Advogado morre após carro bater e pegar fogo, em Catalão
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/11/26/clinica-de-medico-suspeito-de-ameacar-servidora-ja-havia-sido-fiscalizada-por-medicamentos-vencidos-e-local-insalubre-diz-delegado.ghtml
# [OK] salvo: Clínica de médico suspeito de ameaçar servidora já havia sido interditada outras
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/11/26/delegado-humberto-teofilo-anuncia-afastamento-por-questoes-pessoais-e-cita-processos-na-corregedoria-muitas-perseguicoes.ghtml
# [OK] salvo: Delegado Humberto Teófilo anuncia afastamento por questões pessoais e cita proce
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/11/26/duas-pessoas-morrem-apos-batida-entre-onibus-e-caminhao.ghtml
# [OK] salvo: Duas pessoas morrem após batida entre ônibus e caminhão na BR-153
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/11/26/imoveis-abandonados-em-goiania-podem-ser-tomados-pela-prefeitura-com-publicacao-de-decreto-veja-quais-se-enquadram.ghtml
# [OK] salvo: Imóveis abandonados em Goiânia podem ser tomados pela prefeitura, com publicação
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/11/26/terceiro-desmoronamento-em-lixao-volta-a-contaminar-corrego-em-padre-bernardo.ghtml
# [OK] salvo: Terceiro desmoronamento em lixão volta a contaminar córrego, em Padre Bernardo
# [FEED] Baixando página de feed: https://g1.globo.com/go/goias/ultimas-noticias/index/feed/pagina-28.ghtml
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/11/25/g1-transmite-ao-vivo-a-cantata-de-natal-do-grupo-jaime-camara.ghtml
# [OK] salvo: G1 transmite ao vivo a Cantata de Natal do Grupo Jaime Câmara
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/11/25/influenciadora-se-surpreende-com-fachada-de-shopping-em-goias-parece-miami-video.ghtml
# [OK] salvo: Influenciadora se surpreende com fachada de shopping em Goiás: 'Parece Miami'; v
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/11/25/menino-recebe-alta-apos-passar-mais-de-400-dias-em-hospital-e-vai-para-casa-pela-primeira-vez.ghtml
# [OK] salvo: Bebê com doença rara recebe alta após passar mais de 400 dias em hospital e vai
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/11/25/morte-de-menino-picado-por-abelhas-causa-comocao-nas-redes-sociais-cheio-de-aventuras.ghtml
# [OK] salvo: Morte de menino picado por abelhas causa comoção nas redes sociais: 'Cheio de av
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/11/26/condominio-de-alto-padrao-e-construido-em-meio-a-sitios-arqueologicos-em-pirenopolis-e-mp-investiga-licencas.ghtml
# [OK] salvo: Condomínio de alto padrão é construído em meio a sítios arqueológicos em Pirenóp
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/11/26/conheca-a-historia-de-uma-das-casas-mais-antigas-de-goiania-que-e-mais-velha-que-a-capital.ghtml
# [OK] salvo: Conheça a história de uma das casas mais antigas de Goiânia, que é mais velha qu
# [ARTICLE] Baixando: https://g1.globo.com/go/goias/noticia/2025/11/26/fisiculturista-goiana-vence-campeonato-mundial-na-espanha.ghtml
# [OK] salvo: Fisiculturista goiana vence campeonato mundial na Espanha
# [DONE] Processadas 28 páginas de feed.

# %%
import pandas as pd

conn = get_conn()
df = pd.read_sql_query("SELECT * FROM g1_goias_news", conn)
conn.close()

print(f"DataFrame criado com {len(df)} notícias.")
display(df.head())
# Out:
# DataFrame criado com 204 notícias.
#    id                                              title  \
# 0   1  Cantor sertanejo é roubado em parque de Goiâni...
# 1   2  Caso Valério Luiz: STJ mantém multa a advogado...
# 2   3  Corpo de jovem que desapareceu após nadar em r...
# 3   4  Menino de 10 anos que foi esfaqueado múltiplas...
# 4   5  Ex-presidente do Sindicato Rural de Rio Verde ...
#
#                                             subtitle  \
# 0  Segundo João Victor, uma corrente de ouro foi ...
# 1  Tribunal entendeu que lei que proíbe multa a d...
# 2  Rafael Campos havia entrado no Rio Claro para ...
# 3  Segundo a Polícia Civil, o suspeito de ter gol...
# 4  Olávio Teles Fonseca foi denunciado por estupr...
#
#                                                  url section  city author  \
# 0  https://g1.globo.com/go/goias/noticia/2025/12/...    None  None
# 1  https://g1.globo.com/go/goias/noticia/2025/12/...    None  None
# 2  https://g1.globo.com/go/goias/noticia/2025/12/...    None  None
# 3  https://g1.globo.com/go/goias/noticia/2025/12/...    None  None
# 4  https://g1.globo.com/go/goias/noticia/2025/12/...    None  None
#
#                        published_at                        updated_at  \
# 0  2025-12-10 13:06:34.597000-03:00  2025-12-10 13:30:15.949000-03:00
# 1  2025-12-10 13:12:02.461000-03:00  2025-12-10 13:12:36.910000-03:00
# 2  2025-12-10 13:58:56.218000-03:00  2025-12-10 14:10:38.305000-03:00
# 3  2025-12-10 11:00:23.139000-03:00  2025-12-10 11:50:03.234000-03:00
# 4  2025-12-10 14:02:27.903000-03:00  2025-12-10 14:20:36.273000-03:00
#
#                                                 text  tags  \
# 0  Por Letícia Fiuza , g1 Goiás\n10/12/2025 13h06...  None
# 1  Por Addan Vieira , g1 Goiás\n10/12/2025 13h12 ...  None
# 2  Por Rafaella Barros, g1 Goiás\n10/12/2025 13h5...  None
# 3  Por Yanca Cristina , g1 Goiás\n10/12/2025 11h0...  None
# 4  Por Yanca Cristina , Honório Jacometto, g1 Goi...  None
#
#                                             raw_html  \
# 0  <!DOCTYPE HTML>\n<html class="bs-channel-deskt...
# 1  <!DOCTYPE HTML>\n<html class="bs-channel-deskt...
# 2  <!DOCTYPE HTML>\n<html class="bs-channel-deskt...
# 3  <!DOCTYPE HTML>\n<html class="bs-channel-deskt...
# 4  <!DOCTYPE HTML>\n<html class="bs-channel-deskt...
#
#                    scraped_at
# 0  2025-12-10T20:16:26.954073
# 1  2025-12-10T20:16:29.060369
# 2  2025-12-10T20:16:31.200642
# 3  2025-12-10T20:16:33.514851
# 4  2025-12-10T20:16:35.774122

# %%
df = df.drop(columns=["raw_html"])

# %%
display(df.info(memory_usage='deep'))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 204 entries, 0 to 203
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            204 non-null    int64
#  1   title         204 non-null    object
#  2   subtitle      204 non-null    object
#  3   url           204 non-null    object
#  4   section       0 non-null      object
#  5   city          0 non-null      object
#  6   author        204 non-null    object
#  7   published_at  204 non-null    object
#  8   updated_at    204 non-null    object
#  9   text          204 non-null    object
#  10  tags          0 non-null      object
#  11  scraped_at    204 non-null    object
# dtypes: int64(1), object(11)
# memory usage: 3.3 MB
# None

# %%
df.to_csv('dataset_noticias_g1.csv')
