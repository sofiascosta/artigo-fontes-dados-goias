# %% [markdown]
# # Instalar dependências

# %%
# !pip install requests beautifulsoup4 lxml pandas python-dateutil
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (2.32.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (4.13.5)
# Requirement already satisfied: lxml in /usr/local/lib/python3.12/dist-packages (6.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.12/dist-packages (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests) (2025.11.12)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4) (4.15.0)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil) (1.17.0)

# %% [markdown]
# # Banco de dados (SQLite)

# %%
import sqlite3
from pathlib import Path

DB_PATH = Path("/content/jornalopcao_reportagens.db")

CREATE_TABLE_JO = """
CREATE TABLE IF NOT EXISTS jornalopcao_reportagens (
    id INTEGER PRIMARY KEY AUTOINCREMENT,
    title TEXT NOT NULL,
    subtitle TEXT,
    url TEXT NOT NULL UNIQUE,
    section TEXT,
    city TEXT,
    author TEXT,
    published_at TEXT,
    updated_at TEXT,
    text TEXT,
    tags TEXT,
    raw_html TEXT,
    scraped_at TEXT NOT NULL
);
"""

def get_conn():
    DB_PATH.parent.mkdir(parents=True, exist_ok=True)
    conn = sqlite3.connect(DB_PATH)
    conn.execute("PRAGMA journal_mode=WAL;")
    conn.execute("PRAGMA foreign_keys = ON;")
    return conn

def init_db_jornalopcao():
    conn = get_conn()
    with conn:
        conn.execute(CREATE_TABLE_JO)
    conn.close()

def insert_jornalopcao(conn, record: dict):
    """
    record deve ter as chaves:
      title, subtitle, url, section, city, author,
      published_at, updated_at, text, tags, raw_html, scraped_at
    """
    sql = """
    INSERT OR IGNORE INTO jornalopcao_reportagens
    (title, subtitle, url, section, city, author,
     published_at, updated_at, text, tags, raw_html, scraped_at)
    VALUES (:title, :subtitle, :url, :section, :city, :author,
            :published_at, :updated_at, :text, :tags, :raw_html, :scraped_at)
    """
    with conn:
        conn.execute(sql, record)

# %% [markdown]
# # Helpers de HTTP + parse de data

# %%
import requests
from bs4 import BeautifulSoup
from dateutil import parser as dateparser
from datetime import datetime, timedelta
import time
import json

HEADERS = {
    "User-Agent": "Mozilla/5.0 (compatible; JornalOpcaoScraper/1.0; +https://seu-email-ou-site)"
}

MONTHS_PT = [
    "janeiro", "fevereiro", "março", "marco", "abril", "maio",
    "junho", "julho", "agosto", "setembro", "outubro", "novembro", "dezembro"
]

def get_soup(url: str) -> BeautifulSoup:
    resp = requests.get(url, headers=HEADERS, timeout=10)
    resp.raise_for_status()
    return BeautifulSoup(resp.text, "lxml")

def parse_datetime(text: str):
    if not text:
        return None
    try:
        return dateparser.parse(text)
    except Exception:
        return None

def extract_date_text(soup: BeautifulSoup):
    """
    Procura algo tipo '06 dezembro 2025 às 21h21'
    dentro da matéria.
    """
    for s in soup.stripped_strings:
        txt = s.strip()
        lower = txt.lower()
        if any(m in lower for m in MONTHS_PT) and any(ch.isdigit() for ch in lower):
            return txt
    return None

from bs4 import BeautifulSoup
from bs4.element import NavigableString
import re

def extract_author_jornalopcao(soup: BeautifulSoup):
    """
    Extrai o autor numa página de reportagem do Jornal Opção.

    Estratégia:
    1) Tenta seletores "óbvios" (rel='author', classes, etc)
    2) Se não achar:
       - pega o <h1> (título)
       - varre os elementos SEGUINTES ao <h1>
       - o primeiro texto 'tipo nome' ANTES da data é o autor
    """

    # 1) seletores comuns (caso mudem o tema no futuro)
    selector_candidates = [
        'a[rel="author"]',
        'span[rel="author"]',
        '[itemprop="author"]',
        '.author',
        '.post-author',
        '.entry-author',
        '.single__author',
        '.meta-author',
    ]
    for sel in selector_candidates:
        el = soup.select_one(sel)
        if el:
            txt = el.get_text(strip=True)
            if txt:
                return txt

    # 2) pegar data como âncora de parada
    date_txt = extract_date_text(soup)

    # 3) pegar <h1> (título da matéria)
    title_tag = soup.find("h1")
    if not title_tag:
        return None

    # 4) varrer elementos após o <h1> até chegar na data
    for el in title_tag.next_elements:
        # Se for a própria string da data -> paramos
        if isinstance(el, NavigableString):
            txt = el.strip()
            if not txt:
                continue

            # se esse texto é igual à data, ou contém mês + número, paramos
            lower = txt.lower()
            if (date_txt and date_txt.strip() == txt.strip()) or (
                any(m in lower for m in MONTHS_PT) and any(ch.isdigit() for ch in lower)
            ):
                break

            # se for algo tipo "COMPARTILHAR" / "RELACIONADAS", paramos a busca
            if any(p in lower for p in ["compartilhar", "relacionadas"]):
                break

            # ignora coisas com número (ex: "49 ANOS")
            if any(ch.isdigit() for ch in txt):
                continue

            # ignora palavras de navegação
            if lower in {"início", "inicio", "reportagens"}:
                continue

            # heurística simples de "parece nome"
            if 2 <= len(txt) <= 60:
                return txt

            continue

        # Se for uma tag (a, span, etc.)
        if hasattr(el, "get_text"):
            txt = el.get_text(strip=True)
            if not txt:
                continue

            lower = txt.lower()

            # se chegou na data, paramos
            if (date_txt and date_txt.strip() == txt.strip()) or (
                any(m in lower for m in MONTHS_PT) and any(ch.isdigit() for ch in lower)
            ):
                break

            # parar se bater num bloco de compartilhamento
            if any(p in lower for p in ["compartilhar", "relacionadas"]):
                break

            # pular texto com números (49 ANOS, etc.)
            if any(ch.isdigit() for ch in txt):
                continue

            if lower in {"início", "inicio", "reportagens"}:
                continue

            # aqui é o candidato a autor: primeiro texto curto, sem número, logo após o h1
            if 2 <= len(txt) <= 60:
                return txt

    return None


def extract_section(soup: BeautifulSoup):
    """
    Pega algo tipo 'Política', 'História', etc.
    Se não tiver nada confiável, volta 'Reportagens'.
    """
    # tentativa simples: olhar breadcrumbs
    strings = list(soup.stripped_strings)
    for i, s in enumerate(strings):
        if s.strip() == "Reportagens" and i > 0:
            prev = strings[i - 1].strip()
            if prev not in {"Início", "Reportagens", "Últimas notícias"}:
                return prev
    return "Reportagens"

def extract_tags(soup: BeautifulSoup):
    """
    Usa links /assunto/ como tags.
    """
    tags = []
    for a in soup.select("a[href*='/assunto/']"):
        txt = a.get_text(strip=True)
        if txt:
            tags.append(txt)
    # remove duplicados mantendo ordem
    return list(dict.fromkeys(tags))

def extract_city_from_text(paragraphs):
    """
    Igual G1: tenta encontrar 'Cidade - ' na primeira linha.
    Se não achar nada, retorna None.
    """
    if not paragraphs:
        return None
    first_line = paragraphs[0]
    if " - " in first_line:
        maybe_city = first_line.split(" - ")[0]
        if len(maybe_city.split()) <= 4:
            return maybe_city
    return None


from bs4 import BeautifulSoup

def extract_text_jornalopcao(soup: BeautifulSoup) -> str:
    """
    Extrai o texto principal da reportagem do Jornal Opção,
    tentando imitar o comportamento do G1 (só o corpo da matéria).
    """

    # 1) Tenta pegar o <article> (WordPress costuma usar isso)
    article = soup.find("article")

    # 2) Se não achar, tenta alguns contêineres comuns
    if not article:
        for cls in ["single__content", "entry-content", "post-content"]:
            article = soup.find("div", class_=cls)
            if article:
                break

    # 3) Se ainda não achar, faz um fallback pro site inteiro (melhor que nada)
    container = article if article else soup

    paragraphs = []
    for el in container.find_all(["p", "h2", "h3"], recursive=True):
        txt = el.get_text(" ", strip=True)
        if not txt:
            continue

        lower = txt.lower()

        # Cortar na parte de "leia também" / rodapé
        if "leia também" in lower:
            break
        if "49 anos" in lower and "jornal opção" in lower:
            break

        # Ignorar coisas de navegação/compartilhamento
        if any(w in lower for w in ["compartilhar", "relacionadas", "colunas e blogs"]):
            continue

        paragraphs.append(txt)

    # Remover duplicatas mantendo ordem
    if not paragraphs:
        return None

    # Usa "\n\n" pra ficar legível tipo parágrafo
    text = "\n\n".join(dict.fromkeys(paragraphs))
    return text

# %% [markdown]
# # Listagem de reportagens por página

# %%
def fetch_jornalopcao_article(url: str) -> dict:
    """
    Baixa e extrai dados de uma reportagem do Jornal Opção
    no mesmo formato da tabela do G1.
    """
    print(f"[ARTICLE] Baixando: {url}")
    soup = get_soup(url)

    # Título
    title_tag = soup.find("h1")
    title = title_tag.get_text(strip=True) if title_tag else None

    # Não parece ter subtítulo separado na maioria das matérias;
    # se quiser depois, dá pra tentar pegar o primeiro <h2> ou um <p> destacado.
    subtitle = None

    # Autor
    author = extract_author_jornalopcao(soup)

    # Data
    published_raw = extract_date_text(soup)
    published_iso = None
    dt = parse_datetime(published_raw) if published_raw else None
    if dt is not None:
        published_iso = dt.isoformat()

    # Normalmente não há data de atualização explícita
    updated_at = None

    # Seção
    section = extract_section(soup)

    # Corpo do texto: todos os <p>
    paragraphs = [p.get_text(" ", strip=True) for p in soup.find_all("p")]
    text = extract_text_jornalopcao(soup)

    # Cidade (heurística igual G1)
    city = extract_city_from_text(paragraphs)

    # Tags
    tags_list = extract_tags(soup)
    tags_str = json.dumps(tags_list, ensure_ascii=False) if tags_list else None

    raw_html = str(soup)
    scraped_at = datetime.utcnow().isoformat()

    return {
        "title": title,
        "subtitle": subtitle,
        "url": url,
        "section": section,
        "city": city,
        "author": author,
        "published_at": published_iso or published_raw,
        "updated_at": updated_at,
        "text": text,
        "tags": tags_str,
        "raw_html": raw_html,
        "scraped_at": scraped_at,
    }

# %% [markdown]
# A categoria tem essa cara:
#
# * https://www.jornalopcao.com.br/categoria/reportagens/
#
# * https://www.jornalopcao.com.br/categoria/reportagens/page/2/
#
# * https://www.jornalopcao.com.br/categoria/reportagens/page/3/
#
# com as reportagens em forma de cards.
#
# Vamos pegar os links que apontam para matérias (tipicamente /ultimas-noticias/... ou /reportagens/...).

# %%
BASE_JO_URL = "https://www.jornalopcao.com.br/categoria/reportagens/"

def fetch_jornalopcao_listing(page: int):
    if page == 1:
        url = BASE_JO_URL
    else:
        url = f"{BASE_JO_URL}page/{page}/"

    print(f"[LIST] Página {page}: {url}")
    soup = get_soup(url)

    urls = set()

    for a in soup.select("a"):
        href = a.get("href") or ""
        if not href.startswith("https://www.jornalopcao.com.br/"):
            continue

        if "/categoria/" in href or "/assunto/" in href or "/page/" in href:
            continue

        if "/ultimas-noticias/" in href or "/reportagens/" in href:
            urls.add(href)

    urls = sorted(urls)
    print(f"[LIST] Encontradas {len(urls)} URLs de matérias na página {page}.")
    return urls

# %%
def crawl_jornalopcao_reportagens(max_pages: int = 50, months: int = 6):
    """
    Percorre as páginas da categoria 'Reportagens' e salva apenas
    matérias dos últimos `months` meses (aprox), usando o mesmo
    esquema de colunas do G1.
    """
    init_db_jornalopcao()
    conn = get_conn()

    cutoff = datetime.now() - timedelta(days=30 * months)
    print(f"[INFO] Data de corte aproximada: {cutoff.date()} (últimos {months} meses)")

    seen = set()
    pages_only_old = 0

    for page in range(1, max_pages + 1):
        try:
            article_urls = fetch_jornalopcao_listing(page)
        except Exception as e:
            print(f"[STOP] Erro ao listar página {page}: {e}")
            break

        if not article_urls:
            print(f"[STOP] Página {page} veio sem matérias, encerrando.")
            break

        page_has_newer = False

        for url in article_urls:
            if url in seen:
                continue
            seen.add(url)

            try:
                record = fetch_jornalopcao_article(url)
            except Exception as e:
                print(f"[ERROR] {url}: {e}")
                continue

            if not record.get("title") or not record.get("text"):
                print(f"[WARN] Sem título ou texto, pulando: {url}")
                continue

            # filtro de data
            pub_str = record.get("published_at")
            pub_dt = parse_datetime(pub_str) if pub_str else None

            if pub_dt is not None:
                if pub_dt.date() < cutoff.date():
                    print(
                        f"[SKIP old] {record['title'][:60]}... "
                        f"({pub_dt.date()}) < corte ({cutoff.date()})"
                    )
                    continue
                else:
                    page_has_newer = True
            else:
                # se não tem data parseável, eu salvo mesmo assim
                page_has_newer = True

            insert_jornalopcao(conn, record)
            print(f"[OK] {record['title'][:80]}")
            time.sleep(1)

        if not page_has_newer:
            pages_only_old += 1
            print(f"[INFO] Página {page} só tinha notícia velha.")
            if pages_only_old >= 3:
                print(
                    f"[STOP] {pages_only_old} páginas seguidas só com notícia < corte. Encerrando."
                )
                break
        else:
            pages_only_old = 0

        time.sleep(1)

    conn.close()
    print("[DONE] Crawl Jornal Opção finalizado.")

# %% [markdown]
# Mude aqui para a quantidade de páginas, ou o tanto de meses que você quer que ele pegue

# %%
crawl_jornalopcao_reportagens(max_pages=20, months=6)
# Out:
# [INFO] Data de corte aproximada: 2025-06-16 (últimos 6 meses)
# [LIST] Página 1: https://www.jornalopcao.com.br/categoria/reportagens/
# [LIST] Encontradas 10 URLs de matérias na página 1.
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/construida-por-missionario-alemao-casa-mais-antiga-de-goiania-completa-100-anos-763925/
# /tmp/ipython-input-3419327968.py:45: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   scraped_at = datetime.utcnow().isoformat()
# [OK] Construída por missionário alemão, casa mais antiga de Goiânia completa 100 anos
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/goias-na-encruzilhada-fiscal-como-jose-eliton-recebeu-o-estado-de-marconi-e-como-o-entregou-para-caiado-766995/
# [OK] Goiás na encruzilhada fiscal: como José Eliton recebeu o Estado de Marconi e com
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/pl-avanca-na-formacao-das-chapas-para-2026-em-goias-772230/
# [OK] PL avança na formação das chapas para 2026 em Goiás
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/ultimas-noticias/autoestima-e-poder-mundial-o-exemplo-dos-estados-unidos-serve-para-a-china-772591/
# [OK] Autoestima e poder mundial: o exemplo dos Estados Unidos serve para a China?
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/ultimas-noticias/conheca-5-empresas-que-estao-transformando-o-mercado-da-inteligencia-artificial-em-goias-763944/
# [OK] Conheça 5 empresas que estão transformando o mercado da Inteligência Artificial
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/ultimas-noticias/hannah-arendt-a-filosofa-judia-alema-que-enfrentou-o-autoritarismo-e-rejeitou-rotulos-772570/
# [OK] Hannah Arendt, a filósofa judia-alemã que enfrentou o autoritarismo e rejeitou r
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/ultimas-noticias/homens-vivem-menos-entenda-quais-fatores-explicam-a-expectativa-de-vida-deles-ser-de-ate-seis-anos-menor-que-a-das-mulheres-770108/
# [OK] Homens vivem menos: entenda por que a expectativa de vida deles é de até seis an
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/ultimas-noticias/relator-diz-que-fara-endurecimento-em-regras-penais-na-pec-da-seguranca-761295/
# [OK] Relator diz que fará endurecimento em regras penais na PEC da Segurança
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/ultimas-noticias/setor-produtivo-goiano-revela-expectativas-para-os-nove-meses-da-gestao-daniel-vilela-em-2026-771304/
# [OK] Setor produtivo goiano revela expectativas para os nove meses da gestão Daniel V
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/ultimas-noticias/vereadores-e-deputados-em-goias-tem-risco-de-perda-de-mandato-antes-de-2026-765091/
# [OK] Vereadores e deputados em Goiás têm risco de perda de mandato antes de 2026
# [LIST] Página 2: https://www.jornalopcao.com.br/categoria/reportagens/page/2/
# [LIST] Encontradas 12 URLs de matérias na página 2.
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/aparecida-de-goiania-tera-o-maior-aeroporto-executivo-do-centro-oeste-757219/
# [OK] Polo Antares deve colocar Goiás na rota da mobilidade aérea
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/cancer-de-mama-masculino-e-raro-mas-numero-de-mortes-aumenta-em-goias-759067/
# [OK] Câncer de mama masculino é raro, mas número de mortes aumenta em Goiás
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/com-o-dna-do-baru-ao-das-oncas-cientistas-criam-solucoes-geneticas-para-enfrentar-mudancas-ambientais-755038/
# [OK] Do DNA do baru ao das onças: cientistas criam soluções genéticas para mudanças a
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/conheca-o-grupo-goiano-que-lutou-pela-construcao-de-brasilia-403942/
# [OK] Os goianos que sonharam Brasília: a história do grupo que mudou o destino da cap
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/enquanto-brasil-se-prepara-para-a-cop-30-conheca-iniciativas-sustentaveis-goianas-761331/
# [OK] Enquanto Brasil se prepara para a COP 30, conheça iniciativas sustentáveis goian
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/moradores-denunciam-inseguranca-e-abandono-em-area-do-antigo-cras-na-vila-finsocial-757274/
# [OK] Moradores denunciam insegurança e abandono em área do antigo CRAS na Vila Finsoc
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/nos-lembramos-que-somos-gente-de-novo-presos-em-aparecida-reconstroem-novas-historias-atraves-da-educacao-761596/
# [OK] “Nos lembramos que somos gente de novo”: presos em Aparecida reconstroem novas h
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/o-fator-caiado-entenda-por-que-o-governador-de-goias-pode-ser-o-candidato-mais-viavel-da-direita-em-2026-755143/
# [OK] O “fator Caiado”: entenda por que o governador de Goiás pode ser o candidato viá
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/recusa-das-familias-para-doacao-de-orgaos-e-acima-da-media-nacional-em-goias-758532/
# [OK] Recusa das famílias para doação de órgãos é acima da média nacional em Goiás
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/ultimas-noticias/ex-prefeitos-e-suplentes-articulam-chapinhas-para-disputar-a-alego-em-2026-e-escapar-do-canibalismo-eleitoral-757404/
# [OK] Ex-prefeitos e suplentes articulam ‘chapinhas’ para disputar a Alego em 2026 e e
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/ultimas-noticias/periodo-pre-eleitoral-industria-do-cafe-e-carne-forcaram-recuo-tatico-das-relacoes-entre-brasil-e-eua-754993/
# [OK] Período pré-eleitoral, indústria do café e carne forçaram recuo tático das relaç
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/ultimas-noticias/saiba-por-que-prefeitos-estao-preferindo-manter-os-cargos-do-que-se-candidatar-a-deputado-758560/
# [OK] Saiba por que prefeitos estão preferindo manter os cargos do que se candidatar a
# [LIST] Página 3: https://www.jornalopcao.com.br/categoria/reportagens/page/3/
# [LIST] Encontradas 15 URLs de matérias na página 3.
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/a-dificil-ascensao-do-futebol-goiano-por-que-os-clubes-da-capital-nao-se-firmam-na-elite-750086/
# [OK] A difícil ascensão do futebol goiano: por que os clubes da capital não se firmam
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/cerrado-entra-em-disputa-entre-a-urgencia-ambiental-e-a-sobrevivencia-economica-entenda-o-debate-747355/
# [OK] Cerrado entra em disputa entre a urgência ambiental e a sobrevivência econômica;
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/comercio-cultura-e-moradia-impulsionam-nova-fase-do-centro-750037/
# [OK] Comércio, cultura e moradia impulsionam nova fase do Centro
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/declinio-do-turismo-em-caldas-novas-se-deve-ao-modelo-disney-dos-resorts1-374450/
# [OK] Declínio do turismo em Caldas Novas se deve ao ‘modelo Disney’ dos resorts
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/fentanil-e-nitazenos-a-ameaca-que-se-espalha-do-norte-dos-eua-para-a-america-latina-747491/
# [OK] Fentanil e nitazenos: a ameaça que se espalha do Norte dos EUA para a América La
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/goiania-discute-novo-plano-de-educacao-universalizacao-do-ensino-participacao-social-e-sintonia-com-planos-estadual-e-nacional-745319/
# [OK] Goiânia discute novo Plano de Educação: universalização, participação social e s
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/houve-tentativa-de-golpe-a-democracia-tem-mecanismos-de-defesa-diz-professora-de-direito-bartira-macedo-744684/
# [OK] ‘Houve tentativa de golpe. A democracia tem mecanismos de defesa’, diz professor
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/lojistas-da-bernardo-sayao-resistem-com-vendas-online-e-lembrancas-do-auge-comercial-747456/
# [OK] Lojistas da Bernardo Sayão resistem com vendas online e lembranças do auge comer
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/mulheres-esquecidas-o-retrato-das-maes-e-filhas-no-sistema-prisional-752430/
# [OK] Mulheres esquecidas: o retrato das mães e filhas no sistema prisional
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/nao-houve-tentativa-de-golpe-stf-ignora-lei-loman-diz-professor-de-direito-pedro-sergio-dos-santos-744697/
# [OK] ‘Não houve tentativa de golpe. STF ignora Lei Loman’, diz professor de direito P
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/o-tenente-do-cesio-memorias-de-um-sobrevivente-da-tragedia-em-goiania-744120/
# [OK] O Tenente do Césio: as memórias de um sobrevivente da tragédia em Goiânia
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/pec-da-seguranca-reacende-embate-entre-uniao-e-estados-sobre-controle-das-policias-perfumaria-critica-oposicao-749951/
# [OK] PEC da Segurança reacende embate entre União e estados sobre controle das políci
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/vale-do-araguaia-desponta-como-nova-fronteira-agricola-mas-enfrenta-gargalos-de-energia-e-logistica-752490/
# [OK] Vale do Araguaia desponta como nova fronteira agrícola, mas enfrenta gargalos de
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/ultimas-noticias/descumprimento-de-cotas-e-desigualdade-no-fundo-partidario-limitam-eleicao-de-mulheres-aponta-pesquisa-746888/
# [OK] Descumprimento de cotas e desigualdade no fundo partidário limitam eleição de mu
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/ultimas-noticias/partidos-em-goias-se-articulam-para-2026-e-enfrentam-dilemas-de-chapas-federacoes-e-risco-de-canibalismo-eleitoral-749642/
# [OK] Partidos em Goiás se articulam para 2026 e enfrentam dilemas de chapas, federaçõ
# [LIST] Página 4: https://www.jornalopcao.com.br/categoria/reportagens/page/4/
# [LIST] Encontradas 11 URLs de matérias na página 4.
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/attilio-e-armando-os-homens-que-pensaram-e-inventaram-goiania-valem-um-museu-ou-nao-737179/
# [OK] Attilio e Armando, os homens que pensaram e inventaram Goiânia. Valem um museu o
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/entenda-por-que-maioria-dos-pre-candidatos-do-sudoeste-aposta-em-daniel-vilela-para-governador-742229/
# [OK] Entenda por que maioria dos pré-candidatos do Sudoeste aposta em Daniel Vilela p
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/exclusivo-saiba-por-que-a-china-esta-de-olho-na-pequena-cidade-goiana-de-barro-alto-739950/
# [OK] Exclusivo: saiba por que a China está de olho na cidade goiana de Barro Alto
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/o-8-de-janeiro-segundo-ato-740217/
# [OK] O 8 de Janeiro – segundo ato
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/rede-de-policlinicas-garante-atendimento-especializado-e-transforma-saude-no-interior-de-goias-737405/
# [OK] Rede de policlínicas garante atendimento especializado e transforma saúde no int
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/retrato-falado-conheca-o-minucioso-trabalho-policial-de-identificar-pessoas-740014/
# [OK] Retrato falado: conheça o minucioso trabalho policial de identificar pessoas
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/ultimas-noticias/de-cidade-dormitorio-a-capital-da-fe-e-da-industria-trindade-completa-105-anos-em-transformacao-739686/
# [OK] De cidade-dormitório a capital da fé e da indústria: Trindade completa 105 anos
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/ultimas-noticias/entenda-o-jogo-politico-no-entorno-regiao-chave-que-pode-definir-eleicoes-em-2026-737717/
# [OK] Entenda o jogo político no Entorno, região-chave que pode definir eleições em 20
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/ultimas-noticias/entenda-por-que-daniel-vilela-e-o-preferido-dos-lideres-evangelicos-para-governador-de-goias-735054/
# [OK] Entenda por que Daniel Vilela é o preferido dos líderes evangélicos para governa
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/ultimas-noticias/plano-diretor-da-regiao-metropolitana-de-goiania-o-que-muda-como-foi-feito-e-para-onde-aponta-737679/
# [OK] Plano Diretor da Região Metropolitana de Goiânia: o que muda, como foi feito e p
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/ultimas-noticias/saiba-quem-sao-os-politicos-que-devem-mudar-de-partido-para-disputar-as-eleicoes-de-2026-738648/
# [OK] Saiba quem são os políticos que devem mudar de partido para disputar as eleições
# [LIST] Página 5: https://www.jornalopcao.com.br/categoria/reportagens/page/5/
# [LIST] Encontradas 14 URLs de matérias na página 5.
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/apenas-9-das-emendas-indicadas-por-deputados-de-goias-foram-pagos-ate-julho-726968/
# [OK] Apenas 9% das emendas indicadas por deputados federais goianos foram pagas até j
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/brasil-excluiu-modernismos-da-semana-de-22-382906/
# [OK] ‘Brasil tem muitos modernismos excluídos pela Semana de 1922’, diz Luís Augusto
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/com-heranca-de-caos-fiscal-anapolis-corta-gastos-firma-parcerias-e-inova-em-gestao-para-realizar-entregas-728614/
# [OK] Com herança de caos fiscal, Anápolis corta gastos, firma parcerias e inova em ge
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/conheca-as-cartas-na-manga-de-ronaldo-caiado-para-disputa-presidencial-em-2026-730847/
# [OK] Saiba quais são as ‘cartas na manga’ de Ronaldo Caiado para a disputa presidenci
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/entenda-por-que-catalao-se-tornou-a-5a-cidade-mais-rica-de-goias-e-uma-das-mais-ricas-do-brasil-732984/
# [OK] Entenda por que Catalão se tornou a 5ª cidade mais rica de Goiás e uma das mais
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/fome-nao-mapeada-conheca-a-realidade-de-familias-que-lutam-para-se-alimentar-730690/
# [OK] Fome não mapeada: conheça a realidade de famílias que lutam para se alimentar
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/maioria-dos-politicos-goianos-e-favoravel-a-anistia-de-bolsonaro-e-dos-presos-no-8-de-janeiro-728764/
# [OK] Maioria dos políticos goianos é favorável à anistia de Bolsonaro e dos presos no
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/rede-de-saude-mental-enfrenta-preconceito-abandono-historico-e-baixo-investimento-embora-resista-com-cuidado-humanizado-728661/
# [OK] Rede de saúde mental sofre com preconceito e abandono histórico, mas resiste com
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/rota-caipira-o-caminho-do-trafico-em-goias-730811/
# [OK] ‘Rota Caipira’: o caminho do tráfico em Goiás
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/ultimas-noticias/futuro-do-transporte-publico-em-goiania-bndes-aponta-que-numero-de-usuarios-pode-triplicar-em-30-anos-730979/
# [OK] Futuro do transporte público em Goiânia: BNDES aponta que número de usuários pod
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/ultimas-noticias/maquinas-caca-niqueis-sao-impulsionadas-por-jogos-de-azar-como-tigrinho-728681/
# [OK] Máquinas caça-níqueis são impulsionadas por jogos de azar como “Tigrinho”
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/ultimas-noticias/medicos-brasileiros-formados-no-exterior-enfrentam-desafios-para-atuar-no-pais-730967/
# [OK] Médicos brasileiros formados no exterior relatam desafios para atuar no país
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/ultimas-noticias/o-solo-que-move-o-futuro-como-a-exploracao-de-terras-raras-pode-transformar-goias-e-o-mundo-733130/
# [OK] O solo que move o futuro: como a exploração de terras raras pode transformar Goi
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/ultimas-noticias/saiba-quem-sao-os-secretarios-de-goiania-aparecida-anapolis-e-do-estado-que-podem-ser-candidatos-em-2026-731818/
# [OK] Saiba quem são os secretários de Goiânia, Aparecida, Anápolis e do Estado que po
# [LIST] Página 6: https://www.jornalopcao.com.br/categoria/reportagens/page/6/
# [LIST] Encontradas 13 URLs de matérias na página 6.
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/com-lula-enfraquecido-centro-ensaia-desembarque-e-articula-por-protagonismo-nas-eleicoes-de-2026-722815/
# [OK] Com Lula enfraquecido, centro ensaia desembarque e articula por protagonismo nas
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/conheca-apore-a-cidade-com-renda-media-de-r-8-mil-tem-realidade-muito-diferente-da-retratada-pela-estatistica-724727/
# [OK] Conheça Aporé: a cidade com renda média de R$ 8 mil tem realidade muito diferent
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/conheca-as-novas-ferrovias-que-vao-consolidar-goias-como-polo-logisticos-do-brasil-722567/
# [OK] Conheça as novas ferrovias que vão consolidar Goiás como polo logístico do Brasi
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/em-2026-psb-apoiara-daniel-vilela-em-goias-e-a-reeleicao-de-lula-diz-elias-vaz-724935/
# [OK] Em 2026, PSB apoiará Daniel Vilela em Goiás e a reeleição de Lula, diz Elias Vaz
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/partidos-se-movimentam-para-driblar-clausula-de-barreira-e-ganhar-forca-em-2026-720270/
# [OK] Partidos se movimentam para driblar cláusula de barreira e ganhar força em 2026
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/ultimas-noticias/cibercriminosos-vendem-dados-sigilosos-para-aplicar-golpes-na-internet-724918/
# [OK] Cibercriminosos vendem dados sigilosos para aplicar golpes na internet
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/ultimas-noticias/condominios-redesenharam-goiania-mas-bairros-tradicionais-tem-ganhado-valor-722576/
# [OK] Condomínios redesenharam Goiânia, mas bairros tradicionais têm ganhado valor
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/ultimas-noticias/de-vereadora-a-majoritaria-aava-santiago-ensaia-salto-na-centro-esquerda-goiana-722793/
# [OK] De vereadora à majoritária? Aava Santiago ensaia salto na centro-esquerda goiana
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/ultimas-noticias/envelhecimento-lgbt-em-goiania-comunidade-mais-velha-relata-isolamento-e-exclusao-720635/
# [OK] Envelhecimento LGBT+ em Goiânia: comunidade mais velha relata isolamento e exclu
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/ultimas-noticias/goias-estrutura-ecossistema-de-inovacao-mas-ainda-enfrenta-desafios-de-interiorizacao-e-maturidade-das-startups-724667/
# [OK] Com hubs e capital em expansão, Goiás fortalece ecossistema de inovação e mira i
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/ultimas-noticias/golpe-do-falso-advogado-cibercriminosos-miram-pms-com-processos-em-curso-em-goias-724094/
# [OK] ‘Golpe do falso advogado’: cibercriminosos miram PMs com processos em curso em G
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/ultimas-noticias/rebite-redes-sociais-sao-principal-ferramenta-para-venda-ilegal-726893/
# [OK] ‘Rebite’: redes sociais são principal ferramenta para venda ilegal
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/ultimas-noticias/traficantes-usam-redes-sociais-para-comercializar-armas-722330/
# [OK] Traficantes usam redes sociais para comercializar munição e armas restritas a mi
# [LIST] Página 7: https://www.jornalopcao.com.br/categoria/reportagens/page/7/
# [LIST] Encontradas 13 URLs de matérias na página 7.
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/acidente-de-transito-veja-relatos-de-motociclistas-sobreviventes-716154/
# [OK] Acidente de trânsito: veja relatos de motociclistas sobreviventes
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/ataques-a-usinas-nucleares-dao-recado-terrivel-sobre-o-futuro-da-seguranca-global-dizem-pesquisadores-720718/
# [OK] Ataques à usinas nucleares dão ‘recado terrível’ sobre o futuro da segurança glo
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/conheca-a-historia-dos-maiores-sequestros-de-goias-544864/
# [OK] Conheça a história dos maiores sequestros de Goiás
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/conselho-aprova-modelo-de-contratacao-sem-licitacao-para-acelerar-obras-com-recursos-do-fundeinfra-717315/
# [OK] Conselho aprova modelo de contratação sem licitação para acelerar obras com recu
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/em-2025-estado-deve-pagar-quase-r-800-milhoes-para-antecipar-parcelas-de-precatorios-716361/
# [OK] Em 2025, Estado deve pagar quase R$ 800 milhões para antecipar parcelas de preca
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/inovacao-que-reduz-burocracia-e-aumenta-eficiencia-diz-procurador-geral-rafael-arruda-sobre-fundeinfra-718171/
# [OK] Inovação que reduz burocracia e aumenta eficiência, diz procurador-geral Rafael
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/margot-fonteyn-e-david-wall-dancaram-no-teatro-goiania-que-irapuan-costa-jr-restaurou-714018/
# [OK] Margot Fonteyn e David Wall dançaram no Teatro Goiânia que Irapuan Costa Jr. res
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/no-sexto-mes-de-gestao-goiania-e-aparecida-seguem-regidas-pelas-dividas-herdadas-dos-antigos-prefeitos-714352/
# [OK] No sexto mês de gestão, Goiânia e Aparecida seguem lutando com dívidas herdadas
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/proibir-pessoas-em-situacao-de-rua-com-tornozeleira-eletronica-nos-abrigos-e-possivel-entenda-a-proposta-714231/
# [OK] Proibir pessoas em situação de rua com tornozeleira eletrônica nos abrigos é pos
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/ultimas-noticias/esquerda-em-movimento-pt-busca-fortalecimento-em-goias-e-avalia-aliancas-para-2026-716455/
# [OK] Esquerda em movimento: PT busca fortalecimento em Goiás e avalia alianças para 2
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/ultimas-noticias/mesmo-apos-caso-de-gripe-aviaria-goias-deve-superar-recorde-historico-de-exportacao-de-carne-de-frango-718410/
# [OK] Mesmo após caso de gripe aviária, Goiás deve superar recorde histórico de export
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/ultimas-noticias/nao-publicar-narcotrafico-migra-para-internet-e-faccoes-se-fortalecem-por-meio-de-redes-sociais-720143/
# [OK] Narcotráfico migra para internet e facções se fortalecem por meio de redes socia
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/ultimas-noticias/saiba-como-os-exercitos-eleitorais-se-preparam-para-a-disputa-de-2026-em-goias-718353/
# [OK] Saiba como os exércitos eleitorais se preparam para a disputa de 2026 em Goiás
# [LIST] Página 8: https://www.jornalopcao.com.br/categoria/reportagens/page/8/
# [LIST] Encontradas 12 URLs de matérias na página 8.
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/conheca-alto-horizonte-9o-maior-produtor-de-cobre-e-ouro-do-brasil-e-saiba-o-que-aconteceria-com-a-economia-se-a-mineracao-acabasse-hoje-712369/
# [OK] Conheça Alto Horizonte, a cidade de Goiás que mais produz cobre no Brasil
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/da-romaria-ao-culto-moderno-a-revolucao-religiosa-em-goias-707833/
# [OK] Da romaria ao culto moderno: a revolução religiosa em Goiás
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/disque-drogas-criminosos-usam-uber-indrive-e-99-pop-para-fazer-trafico-delivery-705030/
# [OK] Disque-drogas: criminosos usam Uber, inDrive e 99 Pop para fazer ‘tráfico delive
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/economistas-criticam-proposta-de-congelar-salario-minimo-para-conter-inflacao-e-penalizar-ainda-mais-quem-ja-esta-sobrecarregado-712140/
# [OK] Economistas criticam proposta de congelar salário mínimo para conter inflação: ‘
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/fe-em-disputa-igreja-catolica-mantem-maioria-em-goias-mas-ve-avanco-evangelico-707866/
# [OK] Fé em disputa: Igreja Católica mantém maioria em Goiás, mas vê avanço evangélico
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/ilegal-goias-virou-rota-para-contrabando-de-cigarros-eletronicos-712356/
# [OK] Goiás na rota do contrabando de cigarros eletrônicos
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/medico-goiano-quer-transformar-porangatu-em-polo-de-biotecnologia-para-produzir-biocombustivel-e-grafeno-com-babacu-709782/
# [OK] Médico goiano quer transformar Porangatu em polo de biotecnologia para produzir
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/mesa-onde-pedro-assinou-decreto-da-transferencia-da-capital-sera-instalada-em-goiania-712544/
# [OK] Mesa onde Pedro assinou decreto da transferência da capital será instalada em Go
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/octo-marques-dedicou-a-vida-a-retratar-vila-boa-mas-foi-considerado-incomodo-por-ela-480896/
# [OK] Octo Marques dedicou a vida a retratar Vila Boa, mas foi considerado incômodo po
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/primeiro-edificio-da-assembleia-legislativa-no-centro-de-goiania-deveria-virar-museu-710262/
# [OK] Primeiro edifício da Assembleia Legislativa, no Centro de Goiânia, deveria virar
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/ultimas-noticias/entenda-qual-e-o-peso-das-regioes-nas-eleicoes-de-goias-e-quais-sao-seus-lideres-decisivos-712114/
# [OK] Entenda qual é o peso das regiões nas eleições de Goiás e quais são seus líderes
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/ultimas-noticias/esboco-do-estatuto-da-federacao-ub-pp-define-regras-para-formacao-de-chapas-tempo-de-tv-e-distribuicao-do-fundo-eleitoral-707766/
# [OK] Esboço do estatuto da federação UB/PP define regras para formação de chapas, tem
# [LIST] Página 9: https://www.jornalopcao.com.br/categoria/reportagens/page/9/
# [LIST] Encontradas 15 URLs de matérias na página 9.
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/83-das-pontes-de-goiania-tem-deterioracao-estrutural-quatro-estao-em-estado-muito-critico-701024/
# [OK] 83% das pontes de Goiânia têm deterioração estrutural, quatro estão em estado ‘m
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/a-outra-cara-da-velhice-o-drama-de-familiares-que-se-tornaram-cuidadores-dos-proprios-idosos-703008/
# [OK] A outra cara da velhice: o drama de familiares que se tornaram cuidadores dos pr
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/a-serie-adolescencia-e-o-conflito-entre-educacao-e-redes-sociais-705331/
# [OK] A série Adolescência e o conflito entre educação e redes sociais
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/cursos-de-medicina-privados-carecem-de-estrutura-e-professores-qualificados-em-goias1-603127/
# [OK] Cursos de medicina privados carecem de estrutura e professores qualificados em G
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/dependente-da-china-agronegocio-brasileiro-arrisca-futuro-sem-acordos-estrategicos-705167/
# [OK] Dependente da China, agronegócio brasileiro arrisca futuro sem acordos estratégi
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/ele-nao-e-so-de-gabinete-avalia-populacao-de-anapolis-sobre-os-quatro-meses-de-gestao-de-marcio-correa-702886/
# [OK] ‘Ele não é só de gabinete’, avalia população de Anápolis sobre os quatro meses d
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/escandalo-do-inss-e-o-valor-dos-sindicatos-serios-para-os-trabalhadores-705502/
# [OK] Escândalo do INSS e o valor dos sindicatos sérios para os trabalhadores
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/goiania-esta-trocando-art-deco-por-arranha-ceus-de-aco-e-vidro-arquitetos-comentam1-618353/
# [OK] Goiânia está trocando Art Déco por arranha-céus de aço e vidro? Arquitetos comen
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/jeferson-vieira-contesta-rubens-barbosa-brasil-esta-ativo-nas-negociacoes-comerciais-705203/
# [OK] Economista Jeferson Vieira contesta embaixador Rubens Barbosa: “Brasil está ativ
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/ministerio-publico-cobra-respostas-da-prefeitura-de-goiania-sobre-avarias-em-pontes-701341/
# [OK] Ministério Público cobra respostas da prefeitura de Goiânia sobre avarias em pon
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/ultima-carta-para-o-mundo-do-papa-francisco-705529/
# [OK] Última carta para o mundo do papa Francisco
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/veja-como-deve-ficar-a-base-de-apoio-de-daniel-vilela-nas-eleicoes-de-2026-em-goias-703111/
# [OK] Veja como deve ficar a base de Daniel Vilela para as Eleições de 2026
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/ultimas-noticias/conheca-o-mercado-de-inteligencia-artificial-startup-goiana-quer-lancar-200-robos-autonomos-em-2025-703000/
# [OK] Conheça o mercado de inteligência artificial: startup goiana quer lançar 200 rob
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/ultimas-noticias/fusao-e-federacao-partidaria-mudam-divisao-de-verbas-e-tempo-de-tv-para-as-eleicoes-de-2026-704303/
# [OK] Fusão e federação partidária mudam divisão de verbas e tempo de TV para as eleiç
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/ultimas-noticias/previdencia-municipal-busca-novos-caminhos-para-contornar-deficit-atuarial-de-r-12-bi-705383/
# [OK] Previdência municipal busca novos caminhos para contornar déficit atuarial de R$
# [LIST] Página 10: https://www.jornalopcao.com.br/categoria/reportagens/page/10/
# [LIST] Encontradas 13 URLs de matérias na página 10.
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/altar-ou-palanque-veja-o-que-pensam-os-evangelicos-sobre-a-participacao-da-igreja-e-de-seus-lideres-na-politica-695042/
# [OK] Altar ou palanque: Veja o que pensam os evangélicos sobre a participação da igre
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/angelita-lima-faz-balanco-da-uf-697335/
# [OK] ‘Orgulhosa porque a UFG se manteve firme e crescendo em tempos difíceis’, diz re
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/duplicacao-br-153-696927/
# [OK] Duplicação da BR-153 deve desalojar vendedores às margens da rodovia; comerciant
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/em-alta-na-logistica-hidrolandia-prepara-abertura-de-dois-polos-industriais-e-ja-mira-salto-no-pib-697360/
# [OK] Em alta na logística, Hidrolândia prepara abertura de dois polos industriais e j
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/inconfidencia-em-goias-da-casa-de-cora-a-vinda-dos-descendentes-de-tiradentes-ao-estado1-484388/
# [OK] Inconfidência em Goiás: da casa de Cora à vinda dos descendentes de Tiradentes a
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/jesus-cristo-o-subversivo-do-amor-e-a-verdadeira-essencia-do-cristianismo-699284/
# [OK] Jesus Cristo: o subversivo do amor e a verdadeira essência do Cristianismo
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/soja-rompe-barreiras-e-plantacoes-invadem-area-urbana-de-goiania-698647/
# [OK] Soja rompe barreiras e plantações invadem área urbana de Goiânia
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/ultimas-noticias/bosque-dos-buritis-vira-atracao-sexual-para-casais-que-buscam-contato-rapido-com-desconhecidos-699133/
# [OK] Bosque dos Buritis vira atração sexual para casais que buscam contato rápido com
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/ultimas-noticias/entenda-como-partidos-mudaram-para-se-adaptar-a-nova-regra-eleitoral-que-vai-aniquilar-os-pequenos-700969/
# [OK] Entenda como partidos mudaram para se adaptar à nova regra eleitoral que vai ‘an
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/ultimas-noticias/goias-e-um-dos-estados-que-mais-investe-em-cultura-diz-presidente-do-conselho-de-cultura-do-estado-leis-de-incentivo-sao-oportunidade-de-melhoria-de-vida-para-populacao-697132/
# [OK] Entenda as falhas da Lei Rouanet, os problemas da Lei Aldir Blanc e o sucesso da
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/ultimas-noticias/injecao-de-credito-por-meio-de-emprestimo-ao-trabalhador-piora-inflacao-mas-pode-frear-rejeicao-a-lula-695280/
# [OK] Injeção de crédito para estimular consumo piora inflação, mas pode frear rejeiçã
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/ultimas-noticias/motoristas-relatam-melhora-apos-mudancas-no-transito-de-goiania-698893/
# [OK] Motoristas relatam melhora após mudanças no trânsito de Goiânia
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/ultimas-noticias/projeto-de-novo-codigo-civil-obriga-reconhecimento-de-paternidade-em-caso-de-recusa-de-dna-700968/
# [OK] Projeto de Novo Código Civil obriga reconhecimento de paternidade em caso de rec
# [LIST] Página 11: https://www.jornalopcao.com.br/categoria/reportagens/page/11/
# [LIST] Encontradas 12 URLs de matérias na página 11.
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/com-problemas-estruturais-ponte-affonso-penna-preocupa-moradores-e-deve-ser-reformada-690598/
# [OK] Com problemas estruturais, ponte Affonso Penna preocupa moradores e deve ser ref
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/conheca-os-3-trunfos-de-caiado-na-corrida-presidencial-e-saiba-por-que-ele-e-um-candidato-viavel-para-2026-695388/
# [OK] Conheça os 3 trunfos de Caiado na corrida presidencial e saiba por que ele é um
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/das-manifestacoes-civicas-por-eleicoes-diretas-e-o-aniversario-de-40-anos-da-redemocratizacao-690367/
# [OK] Das manifestações cívicas por eleições diretas e o aniversário de 40 anos da red
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/de-jango-a-castelo-branco-o-caminho-da-republica-ditadura-e-redemocratizacao-no-brasil-686429/
# [OK] De Jango a Castelo Branco: o caminho de República à ditadura no Brasil
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/inedito-no-pais-entenda-como-vai-funcionar-o-fundo-de-estabilizacao-economica-criado-por-caiado-693200/
# [OK] Inédito no País, entenda como vai funcionar o Fundo de Estabilização Econômica c
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/ja-lider-no-centro-oeste-em-industrializacao-goias-busca-novos-investimentos-para-crescer-ainda-mais-686513/
# [OK] Líder no Centro-Oeste em industrialização, Goiás busca novos investimentos para
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/novo-modelo-para-contratar-obras-rodoviarias-pode-ser-mais-agil-e-seguro-que-o-tradicional-688903/
# [OK] Novo modelo para contratar obras rodoviárias pode ser mais ágil e seguro que o t
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/os-principais-nomes-em-goias-que-podem-puxar-votos-para-deputado-federal-em-2026-690592/
# [OK] Os principais nomes em Goiás que podem puxar votos para deputado federal em 2026
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/sem-habitat-animais-se-arriscam-em-redes-de-alta-tensao-e-morrem-vitimas-choque-eletrico-em-goias-688749/
# [OK] Sem habitat, animais se arriscam em redes de alta tensão e morrem vítimas choque
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/ultimas-noticias/centro-de-goiania-apresenta-insuficiencia-de-lixeiras-com-1-a-cada-2-500-m%c2%b2-aponta-pesquisa-do-jornal-opcao-692865/
# [OK] Centro de Goiânia tem apenas uma lixeira a cada 2.500 m², mostra levantamento do
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/ultimas-noticias/de-castello-branco-a-medici-os-primeiros-governos-da-ditadura-e-a-violenta-repressao-688515/
# [OK] De Castello Branco à Medici, os primeiros governos da Ditadura e a violenta repr
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/ultimas-noticias/prefeitos-em-goias-deixam-pl-de-lado-para-apoiar-daniel-vilela-em-2026-692784/
# [OK] Prefeitos em Goiás deixam PL de lado para apoiar Daniel Vilela em 2026
# [LIST] Página 12: https://www.jornalopcao.com.br/categoria/reportagens/page/12/
# [LIST] Encontradas 13 URLs de matérias na página 12.
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/a-curiosa-historia-das-jazidas-de-esmeraldas-em-goias-680418/
# [OK] A curiosa história das jazidas de esmeraldas em Goiás
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/falta-de-pulso-e-compromisso-fiscal-de-lula-3-pode-levar-a-crescimento-voo-de-galinha-apontam-economistas-goianos-682384/
# [OK] Falta de pulso e compromisso fiscal de Lula 3 pode levar a crescimento “voo de g
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/para-produtores-de-soja-de-goias-precos-atuais-e-juros-altos-podem-prejudicar-economia-do-brasil-em-2025-apesar-de-safra-recorde-682466/
# [OK] Para produtores de soja de Goiás, preços atuais e juros altos podem prejudicar e
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/ponte-sobre-o-rio-das-almas-prestes-a-cair-quem-sera-o-responsavel-pela-tragedia-anunciada-dnit-ou-ecovia-araguaia-686600/
# [OK] Ponte sobre o Rio das Almas pode cair: “Será uma tragédia anunciada”, alertam mo
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/producao-de-soja-em-catalao-esta-boa-mas-custo-e-endividamento-preocupam-682820/
# [OK] Produção de soja em Catalão está boa, mas custo e endividamento preocupam
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/quem-substituira-bolsonaro-direita-e-especialistas-goianos-apontam-caminhos-para-2026-682545/
# [OK] Quem substituirá Bolsonaro? Direita e especialistas goianos apontam caminhos par
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/risco-de-perda-e-cuidado-com-golpe-veja-como-funciona-o-mercado-de-criptomoedas-682325/
# [OK] Risco de perda e cuidado com golpe: veja como funciona o mercado de criptomoedas
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/seguranca-publica-saude-e-politica-o-que-qualifica-caiado-para-a-candidatura-a-presidente-684621/
# [OK] Segurança Pública, Saúde e política: o que qualifica Caiado para a candidatura à
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/superavit-de-bolsonaro-e-fruto-de-calote-em-precatorios-reducao-de-investimentos-e-despesas-nao-pagas-apontam-economistas-680376/
# [OK] “Superávit” de Bolsonaro é fruto de calote em precatórios, redução de investimen
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/ultimas-noticias/federacao-espirita-de-goias-comenta-relacao-entre-genetica-e-mediunidade-682091/
# [OK] Federação Espírita de Goiás comenta relação entre genética e mediunidade
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/ultimas-noticias/investidor-goiano-esta-mais-arrojado-ou-ainda-e-conservador-economistas-avaliam-o-comportamento-684565/
# [OK] Investidor goiano está mais arrojado ou ainda é conservador? Economistas avaliam
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/ultimas-noticias/lei-da-ficha-limpa-os-15-anos-de-impacto-e-a-polemica-da-proposta-de-alteracao-684452/
# [OK] Lei da Ficha Limpa: os 15 anos de impacto e a polêmica da proposta de alteração
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/ultimas-noticias/oka-demolicao-de-um-icone-da-arquitetura-moderna-entenda-o-contexto-da-antiga-sede-da-celg-684252/
# [OK] A demolição de um ícone da arquitetura moderna; entenda o contexto da antiga sed
# [LIST] Página 13: https://www.jornalopcao.com.br/categoria/reportagens/page/13/
# [LIST] Encontradas 11 URLs de matérias na página 13.
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/como-documentario-sobre-brasilia-roteirizado-por-goiano-causou-guerra-judicial-com-acusacoes-de-plagio-e-difamacao-674442/
# [OK] Como documentário sobre Brasília roteirizado por goiano causou guerra judicial c
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/em-cenario-de-dificuldades-orcamentarias-ufg-se-aproxima-de-consulta-para-nova-reitoria-672647/
# [OK] Em cenário de dificuldades orçamentárias, UFG se aproxima de consulta para nova
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/guerra-da-ia-americana-openai-tenta-manter-hegemonia-enquanto-chinesa-deepseek-surge-como-competidora-feroz-678385/
# [OK] Guerra da IA: americana OpenAI tenta manter hegemonia, enquanto chinesa DeepSeek
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/lei-de-responsabilidade-fiscal-o-que-aguarda-prefeitos-que-deixaram-dividas-e-nao-prestaram-contas-672183/
# [OK] Lei de Responsabilidade Fiscal: o que aguarda prefeitos que deixaram dívidas e n
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/mark-zuckerberg-pode-estar-prestes-a-aprender-uma-licao-ensinada-a-elon-musk-no-brasil-672731/
# [OK] Mark Zuckerberg pode estar prestes a aprender uma lição que o Brasil já ensinou
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/pesquisadoras-da-ufg-desenvolvem-tecnica-para-limpar-agua-de-esgoto-devolvida-ao-meio-ambiente-678058/
# [OK] Pesquisadoras da UFG desenvolvem técnica para limpar água de esgoto devolvida ao
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/politicos-analisam-chances-da-direita-sem-bolsonaro-vencer-lula-da-silva-em-2026-674149/
# [OK] Políticos analisam chances da direita sem Bolsonaro vencer Lula da Silva em 2026
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/por-que-em-goiania-existem-tantas-igrejas-evangelicas-entenda-676266/
# [OK] Entenda por que existem tantas igrejas evangélicas em Goiânia
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/vetos-de-lula-a-reforma-tributaria-podem-causar-reducao-de-investimentos-aponta-especialista-674270/
# [OK] Vetos de Lula a reforma tributária podem causar redução de investimentos, aponta
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/ultimas-noticias/a-imponderavel-flor-de-girassol-na-politica-do-tocantins-676105/
# [OK] A imponderável flor de girassol na política do Tocantins
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/ultimas-noticias/raio-x-do-legislativo-mdb-ub-e-pp-comandam-as-camaras-nas-maiores-cidades-de-goias-676540/
# [OK] Raio-X do Legislativo: MDB, UB e PP comandam as câmaras nas maiores cidades de G
# [LIST] Página 14: https://www.jornalopcao.com.br/categoria/reportagens/page/14/
# [LIST] Encontradas 15 URLs de matérias na página 14.
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/aumento-de-acidentes-com-onibus-nas-rodovias-brasileiras-fatores-de-risco-e-consequencias-tragicas-670594/
# [OK] Aumento de acidentes com ônibus nas rodovias brasileiras: fatores de risco e con
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/com-70-das-obras-concluidas-cora-deve-ser-inaugurado-no-primeiro-semestre-de-2025-e-se-tornar-referencia-no-tratamento-oncologico-668702/
# [OK] Com 70% das obras concluídas, CORA deve ser inaugurado no primeiro semestre de 2
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/comercio-de-goiania-espera-crescimento-nas-vendas-de-fim-de-ano-apesar-dos-desafios-economicos-663852/
# [OK] Comércio de Goiânia espera crescimento nas vendas de fim de ano, apesar dos desa
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/como-jales-mendonca-assumiu-o-ihgg-fechado-e-o-transformou-em-uma-das-maiores-instituicoes-culturais-de-goias-670746/
# [OK] Como Jales Mendonça assumiu o IHGG ‘fechado’ e o transformou em uma das maiores
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/crise-na-aviacao-mundial-escassez-de-pilotos-pecas-e-desafios-pos-pandemia-668501/
# [OK] Crise na aviação mundial: escassez de pilotos, peças e desafios pós-pandemia
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/em-desentendimento-com-governo-federal-caiado-apresenta-contraproposta-para-pec-da-seguranca-publica-667197/
# [OK] Em desentendimento com governo federal, Caiado apresenta contraproposta para PEC
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/endividadas-prefeituras-apontam-heranca-maldita-deixada-por-gestoes-anteriores-670841/
# [OK] Endividadas, prefeituras apontam “herança maldita” deixada por gestões anteriore
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/entenda-as-medidas-e-os-resultados-da-intervencao-na-saude-de-goiania-665889/
# [OK] Entenda as medidas e os resultados da intervenção na Saúde de Goiânia
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/entenda-o-jogo-de-forcas-na-camara-de-goiania-durante-o-governo-de-sandro-mabel-668491/
# [OK] Entenda o jogo de forças na Câmara de Goiânia durante o governo de Sandro Mabel
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/goias-em-alerta-colapso-no-maranhao-aumenta-preocupacao-com-a-seguranca-das-pontes-no-brasil-667092/
# [OK] Goiás em Alerta: Colapso no Maranhão aumenta preocupação com a segurança das pon
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/moradores-de-campinas-lamentam-abandono-do-bairro-mais-antigo-de-goiania-664151/
# [OK] Moradores de Campinas lamentam abandono do bairro mais antigo de Goiânia
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/perdas-marcantes-goias-despede-se-de-figuras-iconicas-em-2024-667311/
# [OK] Perdas Marcantes: Goiás despede-se de figuras icônicas em 2024
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/prefeitura-de-aparecida-de-goiania-deve-mais-de-r-40-milhoes-ao-hmap-665835/
# [OK] Prefeitura de Aparecida de Goiânia atrasa repasses para HMAP e pode ter crise pa
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/ultimas-noticias/economistas-explicam-os-sinais-contraditorios-do-crescimento-do-pib-e-da-crise-fiscal-no-brasil-665678/
# [OK] Economistas explicam os sinais contraditórios do crescimento do PIB e da crise f
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/ultimas-noticias/eleicoes-do-pt-comecam-a-se-desenhar-com-articulacoes-locais-e-nacionais-confira-situacao-de-outros-partidos-663560/
# [OK] Entenda as articulações para as eleições das presidências dos partidos em Goiás
# [LIST] Página 15: https://www.jornalopcao.com.br/categoria/reportagens/page/15/
# [LIST] Encontradas 15 URLs de matérias na página 15.
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/a-crise-energetica-e-os-limites-dos-ganhos-de-produtividade-no-setor-eletrico-660727/
# [OK] A crise energética e os limites dos ganhos de produtividade no setor elétrico
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/boicote-do-carrefour-a-carne-do-mercosul-tera-impacto-em-goias-entenda-658470/
# [OK] Entenda os impactos do boicote do Carrefour ao Mercosul para Goiás
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/conheca-a-mamacadela-planta-do-cerrado-usada-para-tratar-vitiligo-653151/
# [OK] Conheça a Mamacadela, planta do cerrado usada para tratar vitiligo
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/entenda-como-vai-funcionar-a-transferencia-do-eja-de-goiania-para-o-estado-de-goias-661974/
# [OK] Entenda como vai funcionar a transferência do EJA de Goiânia para o Estado de Go
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/entenda-o-implante-hormonal-tratamento-com-comprovacao-cientifica-mas-mal-compreendido-pelo-termo-chip-da-beleza-657025/
# [OK] Entenda o implante hormonal, tratamento com comprovação científica, mas mal comp
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/florestamento-em-goias-diversas-pessoas-entidades-ongs-associacoes-empresas-alem-dos-poderes-publicos-estaduais-e-municipais-promovem-e-realizam-acoes-voltadas-ao-ref-654826/
# [OK] Reflorestando Goiás: conheça as iniciativas para restaurar a vegetação nativa do
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/goias-conecta-prefeitos-e-faz-forca-tarefa-para-vencer-deficit-habitacional-658813/
# [OK] Goiás conecta prefeitos e faz força tarefa para vencer déficit habitacional
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/goias-social-leva-atendimento-gratuito-e-acolhedor-a-populacao-do-estado-653133/
# [OK] Goiás Social leva atendimento gratuito e acolhedor à população do estado
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/grupo-porto-seco-centro-oeste-e-aurora-aedi-disputam-na-justica-administracao-do-porto-seco-de-anapolis-entenda-660585/
# ...
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/entenda-por-que-pablo-marcal-e-a-antitese-que-se-espera-de-um-prefeito-640070/
# [OK] Entenda por que Pablo Marçal é a antítese que se espera de um prefeito
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/favelas-em-goiania-conheca-as-areas-onde-a-populacao-vive-sem-infraestrutura-basica-ou-documentos-642102/
# [OK] Favelas em Goiânia: conheça as áreas onde a população vive sem infraestrutura bá
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/goiania-em-chamas-cidade-sofre-com-alta-incidencia-de-incendios-644184/
# [OK] Goiânia em chamas: cidade sofre com alta incidência de incêndios
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/mp-estadual-e-federal-semad-e-alego-investigam-denuncia-de-captacao-de-agua-do-rio-araguaia-para-resort-de-fundador-da-jbs-639803/
# [OK] MP estadual e federal, Semad e Alego investigam denúncia de captação de água do
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/vicio-em-jogos-eletronicos-se-torna-problema-social-e-criminal-646578/
# [OK] Vício em Jogos Eletrônicos se torna problema social e criminal
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/ultimas-noticias/goias-intensifica-producao-da-valiosa-baunilha-do-cerrado-650738/
# [OK] Goiás intensifica produção da valiosa Baunilha do Cerrado
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/ultimas-noticias/prefeitas-eleitas-em-goias-destacam-importancia-da-representatividade-feminina-646199/
# [OK] Prefeitas eleitas em Goiás destacam importância da representatividade feminina
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/ultimas-noticias/psicologia-das-bets-atendimentos-a-viciados-em-apostas-crescem-180-644533/
# [OK] Psicologia das bets: atendimentos a viciados em apostas crescem 180%
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/ultimas-noticias/raio-x-da-democracia-saiba-tudo-sobre-o-processo-eleitoral-brasileiro-643905/
# [OK] Raio-x da democracia: conheça tudo sobre o processo eleitoral brasileiro
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/ultimas-noticias/regulamentacao-das-redes-sociais-ganha-forca-no-exterior-mas-segue-pausada-no-brasil-648969/
# [OK] Regulamentação das redes sociais ganha força no exterior, mas segue pausada no B
# [LIST] Página 17: https://www.jornalopcao.com.br/categoria/reportagens/page/17/
# [LIST] Encontradas 14 URLs de matérias na página 17.
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/eleitorado-jovem-e-um-desafio-para-candidatos-muitos-nao-sabem-o-nome-do-prefeito-633749/
# [OK] Eleitorado jovem é um desafio para candidatos; muitos não sabem o nome do prefei
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/modalidade-olimpica-basquete-3x3-ganha-espaco-em-goias-com-jogo-rapido-e-dinamico-634162/
# [OK] Modalidade olímpica, basquete 3×3 ganha espaço em Goiás com jogo rápido e dinâmi
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/movimento-liderado-por-marcal-mistura-teologia-da-prosperidade-com-politica-e-pode-polarizar-com-bolsonarismo-diz-cientista-goiano-640225/
# [OK] Movimento liderado por Marçal mistura “teologia da prosperidade” com política e
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/nao-valia-nada-dizem-moradores-de-caldazinha-sobre-asfalto-da-codevasf-638226/
# [OK] ‘Não valia nada’, dizem moradores de Caldazinha sobre asfalto da Codevasf
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/psdb-nao-tem-candidatos-a-prefeito-em-16-das-20-cidades-com-60-do-eleitorado-de-goias-631947/
# [OK] PSDB não tem candidatos a prefeito em 12 das 20 cidades com 60% do eleitorado de
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/saiba-quais-foram-os-7-homens-de-ouro-da-camara-municipal-de-goiania-631524/
# [OK] Saiba quais foram os 7 homens de ouro da Câmara Municipal de Goiânia
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/stf-deixaria-alcides-ser-candidato-em-aparecida-nao-mas-mp-se-omitiu-e-ele-vai-disputar-a-prefeitura-639609/
# [OK] STF deixaria Alcides ser candidato em Aparecida? Não. Mas MP se “omitiu” e ele v
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/video-expoe-suposta-captacao-irregular-de-agua-para-fazenda-de-ze-mineiro-fundador-do-grupo-jbs-637949/
# [OK] Vídeo expõe suposta captação irregular de água para fazenda de Zé Mineiro, funda
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/ultimas-noticias/com-vices-sem-experiencia-pre-candidatos-a-prefeito-de-goiania-nao-aprenderam-licao-deixada-por-maguito-vilela-632056/
# [OK] Com vices sem experiência, pré-candidatos a prefeito de Goiânia não aprenderam l
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/ultimas-noticias/crescendo-nas-pesquisas-leandro-vilela-ve-possibilidade-de-vencer-em-aparecida-de-goiania-638113/
# [OK] Crescendo nas pesquisas, Leandro Vilela vê possibilidade de vencer em Aparecida
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/ultimas-noticias/ha-um-mes-da-eleicao-candidatos-de-goiania-definem-propostas-de-governo-635904/
# [OK] A um mês da eleição, candidatos de Goiânia definem propostas de governo
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/ultimas-noticias/nova-direita-bolsonarismo-pode-ser-devorado-pelo-radicalismo-que-ele-pariu-636140/
# [OK] Nova direita: Bolsonarismo pode ser devorado pelo radicalismo que ele pariu?
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/ultimas-noticias/porque-o-brasileiro-sente-que-a-economia-nao-vai-bem-apesar-de-melhora-dos-indicadores-636040/
# [OK] Por que o brasileiro sente que a economia não vai bem, apesar de melhora dos ind
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/ultimas-noticias/tv-x-rede-social-quem-influencia-mais-na-campanha-politica-633157/
# [OK] TV x rede social: quem influencia mais na campanha política?
# [LIST] Página 18: https://www.jornalopcao.com.br/categoria/reportagens/page/18/
# [LIST] Encontradas 15 URLs de matérias na página 18.
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/autonomia-pode-beneficiar-banco-central-instituicao-que-acudiu-economia-em-tempos-de-hiperinflacao-622157/
# [OK] Autonomia pode beneficiar Banco Central, instituição que acudiu economia em temp
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/como-vivem-profissionais-com-mais-de-oitenta-anos-que-ainda-trabalham-confira-622402/
# [OK] Como vivem profissionais com mais de oitenta anos que ainda trabalham; confira
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/conheca-rodrigo-riera-prefeito-de-itajuba-que-pode-ser-bom-exemplo-para-prefeitos-goianos-628482/
# [OK] Conheça Rodrigo Riera, prefeito de Itajubá, que pode ser bom exemplo para prefei
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/entenda-as-raizes-do-antipetismo-em-goiania-e-goias-631561/
# [OK] Entenda as raízes do antipetismo em Goiânia e Goiás
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/entenda-por-que-prefeitos-costumam-se-reeleger-ou-garantir-a-eleicao-de-um-sucessor-624144/
# [OK] Entenda por que prefeitos costumam se reeleger ou garantir a eleição de um suces
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/goias-na-rota-do-trafico-de-animais-silvestres-crime-que-movimenta-u-10-bilhoes-por-ano-629863/
# [OK] Goiás na rota do tráfico de animais silvestres, crime que movimenta U$ 10 bilhõe
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/nem-a-direita-e-nem-a-esquerda-futuro-da-politica-goiana-pode-estar-ao-centro-624519/
# [OK] Nem à direita e nem à esquerda: futuro da política goiana pode estar ao centro
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/o-legado-de-delfim-netto-o-mao-de-ferro-da-economia-brasileira-na-ditadura-629743/
# [OK] Economistas goianos analisam o legado de Delfim Netto, a mão de ferro da economi
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/o-que-as-pesquisas-qualitativas-revelam-sobre-os-motes-que-vao-nortear-as-eleicoes-em-goiania-624145/
# [OK] O que as pesquisas qualitativas revelam sobre os motes que vão nortear as eleiçõ
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/veja-quem-sao-os-candidatos-a-prefeito-sem-adversarios-em-goias-625480/
# [OK] Veja quem são os candidatos a prefeito “sem adversários” em Goiás
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/ultimas-noticias/area-criminal-nao-esta-pronta-para-lidar-com-crimes-praticados-com-uso-de-ia-na-guerra-aponta-estudo-da-ufg-626344/
# [OK] Área criminal não está pronta para lidar com crimes praticados com uso de IA na
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/ultimas-noticias/confira-os-candidatos-de-cada-partido-nos-246-municipios-de-goias-627587/
# [OK] Confira os candidatos de cada partido nos 246 municípios de Goiás
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/ultimas-noticias/conheca-a-biografia-dos-candidatos-a-vice-prefeito-de-goiania-628371/
# [OK] Conheça a biografia dos candidatos a vice-prefeito de Goiânia
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/ultimas-noticias/conheca-as-goianas-que-dominaram-o-instagram-626208/
# [OK] Conheça as goianas que dominaram o Instagram
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/ultimas-noticias/veja-obras-de-r-30-milhoes-em-goias-pela-codevasf-estatal-denunciada-por-superfaturar-r-73-milhoes-628363/
# [OK] Veja obras de R$ 30 milhões em Goiás pela Codevasf, estatal denunciada por super
# [LIST] Página 19: https://www.jornalopcao.com.br/categoria/reportagens/page/19/
# [LIST] Encontradas 15 URLs de matérias na página 19.
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/1conheca-os-avancos-no-diagnostico-e-tratamento-do-autismo-478968/
# [OK] Conheça os avanços no diagnóstico e tratamento do autismo
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/agro-feminino-conheca-cinco-produtoras-e-trabalhadoras-rurais-que-gostam-do-desafio-614956/
# [OK] Agro Feminino: Conheça cinco produtoras e trabalhadoras rurais que gostam do des
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/areas-publicas-se-tornam-alvo-de-disputa-entre-executivo-legislativo-e-ate-o-setor-privado-614395/
# [OK] Áreas públicas se tornam alvo de disputa entre Executivo, Legislativo, e até o s
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/campanha-eleitoral-o-que-funciona-e-o-que-nao-funciona-mais-nas-redes-sociais-622359/
# [OK] Campanha eleitoral: o que funciona, e o que não funciona mais nas redes sociais?
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/cerrado-goiano-produz-vinhos-premiados-confira-616644/
# [OK] Cerrado goiano produz vinhos premiados; confira
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/conheca-o-goiano-que-se-tornou-barao-na-escocia-618321/
# [OK] Conheça o goiano que se tornou barão na Escócia
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/conheca-os-pre-candidatos-a-prefeito-de-porangatu-uruacu-niquelandia-ceres-e-rialma-619885/
# [OK] Conheça os pré-candidatos a prefeito de Porangatu, Uruaçu, Niquelândia, Ceres e
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/conheca-os-pre-candidatos-de-santa-helena-de-goias-e-mineiros-e-seus-projetos-para-as-cidades-614823/
# [OK] Conheça os pré-candidatos de Santa Helena de Goiás e Mineiros e seus projetos pa
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/haley-margon-o-empreendedor-social-que-usa-sua-fortuna-pra-levar-educacao-aos-estudantes-de-catalao-614415/
# [OK] Haley Margon: o empreendedor social que usa sua fortuna pra levar Educação aos e
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/igreja-assembleia-de-deus-foi-fundada-ha-113-anos-em-goias-ha-88-anos-confira-sua-historia-616806/
# [OK] Igreja Assembleia de Deus foi fundada há 113 anos. Em Goiás há 88 anos. Confira
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/jk-60-anos-da-cassacao-do-senador-por-goias-616310/
# [OK] JK: 60 anos da cassação do senador por Goiás
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/reciclagem-no-brasil-engatinha-por-falta-de-politicas-publicas-para-catadores-e-cooperativas-620249/
# [OK] Reciclagem no Brasil engatinha por falta de políticas públicas para catadores e
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/sem-regras-de-distribuicao-interna-fundo-eleitoral-fortalece-politicos-tradicionais-e-cria-barreira-para-novatos-616946/
# [OK] Sem regras de distribuição interna, Fundo Eleitoral fortalece políticos tradicio
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/ufg-e-tjgo-usam-inteligencia-artificial-para-simplificar-o-juridiques-618429/
# [OK] UFG e TJGO usam Inteligência Artificial para simplificar o ‘juridiquês’
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/veja-quem-sao-os-pre-candidatos-de-seis-cidades-turisticas-de-goias-e-suas-propostas-618099/
# [OK] Veja quem são os pré-candidatos de seis cidades turísticas de Goiás e suas propo
# [LIST] Página 20: https://www.jornalopcao.com.br/categoria/reportagens/page/20/
# [LIST] Encontradas 12 URLs de matérias na página 20.
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/as-marcas-e-licoes-seis-anos-apos-atentado-no-colegio-goyases-613175/
# [OK] As marcas e lições seis anos após atentado no Colégio Goyases
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/entenda-por-que-precos-cairam-mas-consumo-interno-de-carne-ainda-e-baixo-602899/
# [OK] Entenda por que preços caíram, mas consumo interno de carne ainda é baixo
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/luiz-claudio-veiga-braga-goias-esta-na-vanguarda-do-combate-as-fake-news-613103/
# [OK] Luiz Cláudio Veiga Braga: “Goiás está na vanguarda do combate às fake news”
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/pl-opera-formatacao-de-base-anti-caiado-e-anti-daniel-em-grandes-cidades-de-goias-611322/
# [OK] PL opera formatação de base anti-Caiado e anti-Daniel em grandes cidades de Goiá
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/por-que-o-transito-em-goiania-esta-ficando-cada-vez-mais-congestionado-especialistas-explicam-609309/
# [OK] Por que o trânsito em Goiânia está ficando cada vez mais congestionado? Especial
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/somos-apenas-resultado-de-geracoes-mais-transgressoras-avalia-pesquisador-goiano-sobre-geracao-z-608026/
# [OK] “É a primeira geração que quer conhecer o mundo, não dominá-lo”, avalia pesquisa
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/veja-quem-sao-os-pre-candidatos-a-prefeito-de-catalao-e-conheca-seus-projetos-para-a-cidade-612793/
# [OK] Veja quem são os pré-candidatos a prefeito de Catalão e conheça seus projetos pa
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/reportagens/veja-quem-sao-os-pre-candidatos-a-prefeito-de-rio-verde-jatai-e-quirinopolis-e-quais-os-seus-projetos-611186/
# [OK] Veja quem são os pré-candidatos a prefeito de Rio Verde, Jataí e Quirinópolis, e
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/ultimas-noticias/doacao-da-antiga-sede-da-alego-para-o-tcm-go-vira-disputa-na-justica-604749/
# [OK] Doação da antiga sede da Alego para o TCM-GO vira disputa na Justiça
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/ultimas-noticias/em-31-anos-goias-registrou-47-enchentes-e-inundacoes-que-desabrigaram-4-mil-moradores-604821/
# [OK] Em 31 anos, Goiás registrou 47 enchentes e inundações que desabrigaram 4 mil mor
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/ultimas-noticias/em-goiania-lideres-evangelicos-se-dividem-em-apoio-a-pre-candidatos-mabel-sai-na-frente-606737/
# [OK] Em Goiânia, líderes evangélicos se dividem em apoio a pré-candidatos; Mabel sai
# [ARTICLE] Baixando: https://www.jornalopcao.com.br/ultimas-noticias/entenda-avancos-e-mudancas-que-plano-diretor-de-arborizacao-urbana-trouxe-para-goiania-604971/
# [OK] Entenda avanços e mudanças que Plano Diretor de Arborização Urbana trouxe para G
# [DONE] Crawl Jornal Opção finalizado.

# %%
import pandas as pd

conn = get_conn()
df = pd.read_sql_query("""
    SELECT *
    FROM jornalopcao_reportagens
    ORDER BY id ASC
""", conn)
conn.close()

df
# Out:
#       id                                              title subtitle  \
# 0      1  Construída por missionário alemão, casa mais a...     None
# 1      2  Goiás na encruzilhada fiscal: como José Eliton...     None
# 2      3  PL avança na formação das chapas para 2026 em ...     None
# 3      4  Autoestima e poder mundial: o exemplo dos Esta...     None
# 4      5  Conheça 5 empresas que estão transformando o m...     None
# ..   ...                                                ...      ...
# 259  260  Veja quem são os pré-candidatos a prefeito de ...     None
# 260  261  Doação da antiga sede da Alego para o TCM-GO v...     None
# 261  262  Em 31 anos, Goiás registrou 47 enchentes e inu...     None
# 262  263  Em Goiânia, líderes evangélicos se dividem em ...     None
# 263  264  Entenda avanços e mudanças que Plano Diretor d...     None
#
#                                                    url     section  city  \
# 0    https://www.jornalopcao.com.br/reportagens/con...  Opção Play  None
# 1    https://www.jornalopcao.com.br/reportagens/goi...  Opção Play  None
# 2    https://www.jornalopcao.com.br/reportagens/pl-...  Opção Play  None
# 3    https://www.jornalopcao.com.br/ultimas-noticia...  Opção Play  None
# 4    https://www.jornalopcao.com.br/ultimas-noticia...  Opção Play  None
# ..                                                 ...         ...   ...
# 259  https://www.jornalopcao.com.br/reportagens/vej...  Opção Play  None
# 260  https://www.jornalopcao.com.br/ultimas-noticia...  Opção Play  None
# 261  https://www.jornalopcao.com.br/ultimas-noticia...  Opção Play  None
# 262  https://www.jornalopcao.com.br/ultimas-noticia...  Opção Play  None
# 263  https://www.jornalopcao.com.br/ultimas-noticia...  Opção Play  None
#
#               author               published_at updated_at  \
# 0     Herbert Moraes  08 novembro 2025 às 21h00       None
# 1      Cilas Gontijo  22 novembro 2025 às 21h00       None
# 2      Cilas Gontijo  06 dezembro 2025 às 21h00       None
# 3            Redação  06 dezembro 2025 às 21h21       None
# 4      Tathyane Melo  08 novembro 2025 às 21h00       None
# ..               ...                        ...        ...
# 259    Cilas Gontijo     09 junho 2024 às 00h00       None
# 260    Cilas Gontijo      12 maio 2024 às 00h00       None
# 261  Raphael Bezerra      11 maio 2024 às 09h35       None
# 262        Ton Paulo      19 maio 2024 às 00h00       None
# 263  Giovanna Campos      12 maio 2024 às 00h00       None
#
#                                                   text  \
# 0    Dona Aparecida tem 62 anos e, desde pequena, p...
# 1    O Governo de Goiás encerrou o exercício de 202...
# 2    A direção do Partido Liberal (PL) em Goiás con...
# 3    J. C. Guimarães\n\nEspecial para o Jornal Opçã...
# 4    *Colaboração de Amanda Costa\n\nLonge do merca...
# ..                                                 ...
# 259  Das cinco maiores cidades do sudoeste goiano, ...
# 260  Os membros fundadores da Associação dos Protet...
# 261  Eventos climáticos como as inundações em Alago...
# 262  “Nunca se soube de um cenário eleitoral tão ab...
# 263  O Plano Diretor de Arborização Urbana (PDAU) t...
#
#                                                   tags  \
# 0                                                 None
# 1    ["Contas", "Goiás", "marconi", "Perillo", "Zé ...
# 2                    ["Goiás", "PL", "Pré-candidatos"]
# 3                                                 None
# 4    ["Goiânia", "Goiás", "IA", "Inovação", "Inteli...
# ..                                                 ...
# 259  ["Cidades", "Goiano", "Pré-candidatos", "Prefe...
# 260  ["Ação", "Alego", "Justiça", "Leonardo Rizzo",...
# 261  ["Chuva", "desabrigado", "Enchente", "Goiás", ...
# 262                                               None
# 263                                  ["Plano Diretor"]
#
#                                               raw_html  \
# 0    <!DOCTYPE html>\n<html lang="pt-BR">\n<head>\n...
# 1    <!DOCTYPE html>\n<html lang="pt-BR">\n<head>\n...
# 2    <!DOCTYPE html>\n<html lang="pt-BR">\n<head>\n...
# 3    <!DOCTYPE html>\n<html lang="pt-BR">\n<head>\n...
# 4    <!DOCTYPE html>\n<html lang="pt-BR">\n<head>\n...
# ..                                                 ...
# 259  <!DOCTYPE html>\n<html lang="pt-BR">\n<head>\n...
# 260  <!DOCTYPE html>\n<html lang="pt-BR">\n<head>\n...
# 261  <!DOCTYPE html>\n<html lang="pt-BR">\n<head>\n...
# 262  <!DOCTYPE html>\n<html lang="pt-BR">\n<head>\n...
# 263  <!DOCTYPE html>\n<html lang="pt-BR">\n<head>\n...
#
#                      scraped_at
# 0    2025-12-13T20:17:07.277208
# 1    2025-12-13T20:17:08.452268
# 2    2025-12-13T20:17:09.654087
# 3    2025-12-13T20:17:10.916280
# 4    2025-12-13T20:17:12.420623
# ..                          ...
# 259  2025-12-13T20:23:44.515589
# 260  2025-12-13T20:23:45.790617
# 261  2025-12-13T20:23:47.185834
# 262  2025-12-13T20:23:48.758654
# 263  2025-12-13T20:23:50.072726
#
# [264 rows x 13 columns]

# %%
df.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 264 entries, 0 to 263
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            264 non-null    int64
#  1   title         264 non-null    object
#  2   subtitle      0 non-null      object
#  3   url           264 non-null    object
#  4   section       264 non-null    object
#  5   city          0 non-null      object
#  6   author        264 non-null    object
#  7   published_at  264 non-null    object
#  8   updated_at    0 non-null      object
#  9   text          264 non-null    object
#  10  tags          184 non-null    object
#  11  raw_html      264 non-null    object
#  12  scraped_at    264 non-null    object
# dtypes: int64(1), object(12)
# memory usage: 145.8 MB

# %%
df = df.drop(columns=['raw_html'])
display(df.info(memory_usage='deep'))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 264 entries, 0 to 263
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            264 non-null    int64
#  1   title         264 non-null    object
#  2   subtitle      0 non-null      object
#  3   url           264 non-null    object
#  4   section       264 non-null    object
#  5   city          0 non-null      object
#  6   author        264 non-null    object
#  7   published_at  264 non-null    object
#  8   updated_at    0 non-null      object
#  9   text          264 non-null    object
#  10  tags          184 non-null    object
#  11  scraped_at    264 non-null    object
# dtypes: int64(1), object(11)
# memory usage: 9.6 MB
# None

# %%
df.to_csv("jornal_opcao_noticias.csv")
