# %% [markdown]
# # Instalar dependências

# %%
# !pip install requests beautifulsoup4 lxml pandas python-dateutil
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (2.32.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (4.13.5)
# Requirement already satisfied: lxml in /usr/local/lib/python3.12/dist-packages (6.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.12/dist-packages (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests) (2025.11.12)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4) (4.15.0)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil) (1.17.0)

# %% [markdown]
# # Banco de dados (SQLite)

# %%
import sqlite3
from pathlib import Path

DB_PATH = Path("/content/labnoticias_reportagens.db")

CREATE_TABLE_SQL = """
CREATE TABLE IF NOT EXISTS labnoticias_reportagens (
    id INTEGER PRIMARY KEY AUTOINCREMENT,
    title TEXT NOT NULL,
    subtitle TEXT,
    url TEXT NOT NULL UNIQUE,
    section TEXT,
    city TEXT,
    author TEXT,
    published_at TEXT,
    updated_at TEXT,
    text TEXT,
    tags TEXT,
    raw_html TEXT,
    scraped_at TEXT NOT NULL
);
"""

def get_conn():
    DB_PATH.parent.mkdir(parents=True, exist_ok=True)
    conn = sqlite3.connect(DB_PATH)
    conn.execute("PRAGMA journal_mode=WAL;")
    conn.execute("PRAGMA foreign_keys = ON;")
    return conn

def init_db():
    conn = get_conn()
    with conn:
        conn.execute(CREATE_TABLE_SQL)
    conn.close()

def insert_labnoticias(conn, record: dict):
    sql = """
    INSERT OR IGNORE INTO labnoticias_reportagens
    (title, subtitle, url, section, city, author,
     published_at, updated_at, text, tags, raw_html, scraped_at)
    VALUES (:title, :subtitle, :url, :section, :city, :author,
            :published_at, :updated_at, :text, :tags, :raw_html, :scraped_at)
    """
    with conn:
        conn.execute(sql, record)

# %% [markdown]
# # HTTP + parse de datas

# %%
import requests
from bs4 import BeautifulSoup
from dateutil import parser as dateparser
from datetime import datetime, timedelta, timezone
import time
import json

HEADERS = {
    "User-Agent": "Mozilla/5.0 (compatible; LabNoticiasScraper/1.0; +https://seu-email-ou-site)"
}

MONTHS_PT = [
    "janeiro", "fevereiro", "março", "marco", "abril", "maio",
    "junho", "julho", "agosto", "setembro", "outubro", "novembro", "dezembro"
]

def get_soup(url: str) -> BeautifulSoup:
    resp = requests.get(url, headers=HEADERS, timeout=15)
    resp.raise_for_status()
    return BeautifulSoup(resp.text, "lxml")

def parse_datetime(text: str):
    if not text:
        return None
    try:
        return dateparser.parse(text)
    except Exception:
        return None

def extract_date_text(soup: BeautifulSoup):
    """
    Tenta achar data em <time> ou em texto com mês por extenso.
    """
    # tenta primeiro <time>
    time_tag = soup.find("time")
    if time_tag:
        if time_tag.has_attr("datetime"):
            return time_tag["datetime"]
        txt = time_tag.get_text(strip=True)
        if txt:
            return txt

    # fallback: qualquer string com mês + número
    for s in soup.stripped_strings:
        txt = s.strip()
        lower = txt.lower()
        if any(m in lower for m in MONTHS_PT) and any(ch.isdigit() for ch in lower):
            return txt
    return None

# %% [markdown]
# # Helpers: autor, texto, tags, cidade

# %%
from bs4.element import NavigableString
import re

def extract_author_lab(soup: BeautifulSoup):
    """
    Estratégia:
    1) a[rel='author'] / span[rel='author'] / .author etc.
    2) Byline perto do título e da data.
    """
    selector_candidates = [
        'a[rel="author"]',
        'span[rel="author"]',
        '[itemprop="author"]',
        '.author',
        '.post-author',
        '.entry-author',
        '.single__author',
        '.meta-author',
    ]
    for sel in selector_candidates:
        el = soup.select_one(sel)
        if el:
            txt = el.get_text(strip=True)
            if txt:
                return txt

    date_txt = extract_date_text(soup)
    title_tag = soup.find("h1")
    if not title_tag:
        return None

    for el in title_tag.next_elements:
        if isinstance(el, NavigableString):
            txt = el.strip()
            if not txt:
                continue
            lower = txt.lower()

            if date_txt and txt.strip() == date_txt.strip():
                break
            if any(m in lower for m in MONTHS_PT) and any(ch.isdigit() for ch in lower):
                break

            if any(w in lower for w in ["compartilhar", "comentários", "comments"]):
                break

            if any(ch.isdigit() for ch in txt):
                continue

            if 2 <= len(txt) <= 60:
                return txt

        elif hasattr(el, "get_text"):
            txt = el.get_text(strip=True)
            if not txt:
                continue
            lower = txt.lower()

            if date_txt and txt.strip() == date_txt.strip():
                break
            if any(m in lower for m in MONTHS_PT) and any(ch.isdigit() for ch in lower):
                break

            if any(w in lower for w in ["compartilhar", "comentários", "comments"]):
                break

            if any(ch.isdigit() for ch in txt):
                continue

            if 2 <= len(txt) <= 60:
                return txt

    return None


def extract_text_lab(soup: BeautifulSoup) -> str | None:
    """
    Extrai o corpo da reportagem.
    Tenta:
      - <article> com .entry-content
      - ou div.entry-content
      - fallback: site inteiro (melhor que nada)
    """
    article = soup.find("article")
    container = None

    if article:
        # tenta um filho com classe comum
        for cls in ["entry-content", "post-content", "single-content", "content-area"]:
            div = article.find("div", class_=cls)
            if div:
                container = div
                break

    if not container:
        for cls in ["entry-content", "post-content", "single-content", "content-area"]:
            div = soup.find("div", class_=cls)
            if div:
                container = div
                break

    if not container:
        container = article or soup

    paragraphs = []
    for el in container.find_all(["p", "h2", "h3"], recursive=True):
        txt = el.get_text(" ", strip=True)
        if not txt:
            continue
        lower = txt.lower()

        if "leia também" in lower:
            break
        if any(w in lower for w in ["compartilhar", "comentários", "comments"]):
            continue

        paragraphs.append(txt)

    if not paragraphs:
        return None

    text = "\n\n".join(dict.fromkeys(paragraphs))
    return text


def extract_tags_lab(soup: BeautifulSoup):
    """
    Tags a partir de:
      - rel='tag'
      - ou links /tag/
    """
    tags = []
    for a in soup.select("a[rel='tag'], a[href*='/tag/']"):
        txt = a.get_text(strip=True)
        if txt:
            tags.append(txt)
    return list(dict.fromkeys(tags))


def extract_city_from_text(paragraphs):
    """
    Igual G1/Jornal Opção: tenta 'Cidade - ' na primeira linha.
    """
    if not paragraphs:
        return None
    first_line = paragraphs[0]
    if " - " in first_line:
        maybe = first_line.split(" - ")[0]
        if len(maybe.split()) <= 4:
            return maybe
    return None

# %% [markdown]
# # Listagem de reportagens /page/N/

# %% [markdown]
# A categoria de reportagens provavelmente funciona assim:
#
# https://labnoticias.jor.br/category/reportagens/
#
# https://labnoticias.jor.br/category/reportagens/page/2/
#
# https://labnoticias.jor.br/category/reportagens/page/3/
#
# etc.

# %%
BASE_LAB_URL = "https://labnoticias.jor.br/category/reportagens/"

def fetch_lab_listing(page: int):
    """
    Devolve lista de URLs de reportagens em uma página do arquivo.

    page=1 -> /category/reportagens/
    page>1 -> /category/reportagens/page/{page}/
    """
    if page == 1:
        url = BASE_LAB_URL
    else:
        url = f"{BASE_LAB_URL}page/{page}/"

    print(f"[LIST] Página {page}: {url}")
    soup = get_soup(url)

    urls = set()

    # 1) Tenta pegar os cards de post via <article> + título
    for art in soup.find_all("article"):
        h = art.find(["h2", "h3"])
        if not h:
            continue
        a = h.find("a")
        if not a or not a.get("href"):
            continue
        href = a["href"].strip()

        # só URLs do próprio site
        if not href.startswith("https://labnoticias.jor.br/"):
            continue

        # DESCARTA coisas que não são post de reportagem:
        # - páginas de autor, categoria, tag, paginação etc.
        if any(p in href for p in ["/author/", "/category/", "/tag/", "/page/"]):
            continue

        urls.add(href)

    # 2) Fallback: se por algum motivo não veio nada, fazer uma varredura genérica,
    #    mas SEM /author/, /category/, /tag/, /page/
    if not urls:
        for a in soup.select("a"):
            href = (a.get("href") or "").strip()
            if not href.startswith("https://labnoticias.jor.br/"):
                continue
            if any(p in href for p in ["/author/", "/category/", "/tag/", "/page/"]):
                continue
            urls.add(href)

    urls = sorted(urls)
    print(f"[LIST] Encontradas {len(urls)} URLs de matérias na página {page}.")
    return urls

# %% [markdown]
# # Extrair uma reportagem (record completo)

# %%
def fetch_lab_article(url: str) -> dict:
    """
    Baixa e extrai dados de uma reportagem do Lab Notícias
    no mesmo esquema de colunas do G1.
    """
    print(f"[ARTICLE] Baixando: {url}")
    soup = get_soup(url)

    # título
    title_tag = soup.find("h1")
    title = title_tag.get_text(strip=True) if title_tag else None

    # subtítulo (se tiver, pode ser em h2 ou parágrafo destacado;
    # por enquanto deixo None; se achar padrão depois, dá pra ajustar)
    subtitle = None

    # autor
    author = extract_author_lab(soup)

    # data
    published_raw = extract_date_text(soup)
    published_iso = None
    dt = parse_datetime(published_raw) if published_raw else None
    if dt is not None:
        published_iso = dt.isoformat()

    updated_at = None  # se o site marcar atualização, dá pra estender depois

    # seção (é sempre Reportagens aqui)
    section = "Reportagens"

    # texto
    text = extract_text_lab(soup)

    # city (heurística)
    paragraphs = text.split("\n\n") if text else []
    city = extract_city_from_text(paragraphs)

    # tags
    tags_list = extract_tags_lab(soup)
    tags_str = json.dumps(tags_list, ensure_ascii=False) if tags_list else None

    raw_html = str(soup)
    scraped_at = datetime.now(timezone.utc).isoformat()

    return {
        "title": title,
        "subtitle": subtitle,
        "url": url,
        "section": section,
        "city": city,
        "author": author,
        "published_at": published_iso or published_raw,
        "updated_at": updated_at,
        "text": text,
        "tags": tags_str,
        "raw_html": raw_html,
        "scraped_at": scraped_at,
    }

# %% [markdown]
# # Crawler principal (com corte de meses, se quiser)

# %%
def crawl_labnoticias_reportagens(max_pages: int = 30, months: int = 6):
    """
    Percorre as páginas da categoria 'Reportagens' do Lab Notícias
    e salva apenas matérias dos últimos `months` meses (aprox).
    """
    init_db()
    conn = get_conn()

    cutoff = datetime.now(timezone.utc) - timedelta(days=30 * months)
    print(f"[INFO] Data de corte aproximada: {cutoff.date()} (últimos {months} meses)")

    seen = set()
    pages_only_old = 0

    for page in range(1, max_pages + 1):
        try:
            article_urls = fetch_lab_listing(page)
        except Exception as e:
            print(f"[STOP] Erro ao listar página {page}: {e}")
            break

        if not article_urls:
            print(f"[STOP] Página {page} sem matérias, encerrando.")
            break

        page_has_newer = False

        for url in article_urls:
            if url in seen:
                continue
            seen.add(url)

            try:
                record = fetch_lab_article(url)
            except Exception as e:
                print(f"[ERROR] {url}: {e}")
                continue

            if not record.get("title") or not record.get("text"):
                print(f"[WARN] Sem título ou texto, pulando: {url}")
                continue

            pub_str = record.get("published_at")
            pub_dt = parse_datetime(pub_str) if pub_str else None

            if pub_dt is not None:
                if pub_dt.date() < cutoff.date():
                    print(
                        f"[SKIP old] {record['title'][:60]}... "
                        f"({pub_dt.date()}) < corte ({cutoff.date()})"
                    )
                    continue
                else:
                    page_has_newer = True
            else:
                page_has_newer = True  # sem data parseável, guardo mesmo assim

            insert_labnoticias(conn, record)
            print(f"[OK] {record['title'][:80]}")
            time.sleep(1)

        if not page_has_newer:
            pages_only_old += 1
            print(f"[INFO] Página {page} só com notícia velha.")
            if pages_only_old >= 3:
                print(
                    f"[STOP] {pages_only_old} páginas seguidas só com notícia < corte. Encerrando."
                )
                break
        else:
            pages_only_old = 0

        time.sleep(1)

    conn.close()
    print("[DONE] Crawl Lab Notícias finalizado.")

# %% [markdown]
# # Para rodar

# %%
crawl_labnoticias_reportagens(max_pages=20, months=6)
# Out:
# [INFO] Data de corte aproximada: 2025-06-13 (últimos 6 meses)
# [LIST] Página 1: https://labnoticias.jor.br/category/reportagens/
# [LIST] Encontradas 15 URLs de matérias na página 1.
# [ARTICLE] Baixando: https://labnoticias.jor.br/
# [OK] Lab Notícias
# [ARTICLE] Baixando: https://labnoticias.jor.br/2025/11/
# [OK] Mês:novembro 2025
# [ARTICLE] Baixando: https://labnoticias.jor.br/2025/11/28/a-floresta-que-vale-bilhoes-como-o-mercado-de-creditos-de-carbono-virou-desejo-empresarial/
# [OK] A floresta que vale bilhões: como o mercado de créditos de carbono virou desejo
# [ARTICLE] Baixando: https://labnoticias.jor.br/2025/11/28/aparecida-de-goiania-62-anos-de-emancipacao-da-segunda-maior-cidade-de-goias/
# [OK] Aparecida de Goiânia: 62 anos de emancipação da segunda maior cidade de Goiás
# [ARTICLE] Baixando: https://labnoticias.jor.br/2025/11/28/entre-o-25-de-marco-e-o-20-de-novembro-o-ceara-celebra-sua-abolicao-pioneira-mas-a-populacao-sabe-disso/
# [OK] Entre o 25 de março e o 20 de novembro: o Ceará celebra sua abolição pioneira, m
# [ARTICLE] Baixando: https://labnoticias.jor.br/2025/11/28/fim-da-obrigatoriedade-das-autoescolas-proposta-do-governo-se-mostra-polemica-e-preocupa-especialistas/
# [OK] Fim da obrigatoriedade das autoescolas: proposta do governo se mostra polêmica e
# [ARTICLE] Baixando: https://labnoticias.jor.br/2025/11/28/futebol-e-emocao-a-realidade-da-saude-mental-nas-categorias-de-base-goianas/
# [OK] Futebol e Emoção: A Realidade da Saúde Mental nas categorias de base goianas
# [ARTICLE] Baixando: https://labnoticias.jor.br/2025/11/28/goiania-se-torna-referencia-nacional-em-transporte-publico-com-modernizacao-investimentos-e-aumento-da-demanda/
# [OK] Goiânia se torna referência nacional em transporte público com modernização, inv
# [ARTICLE] Baixando: https://labnoticias.jor.br/2025/11/28/lei-n-11-459-a-restricao-como-medida-para-reducao-da-criminalidade-e-realmente-eficaz/
# [OK] Lei n° 11.459: a restrição como medida para redução da criminalidade
# [ARTICLE] Baixando: https://labnoticias.jor.br/2025/11/28/mecanizacao-do-campo-transforma-mercado-e-emprego-no-brasil/
# [OK] Mecanização do campo transforma mercado e emprego no Brasil
# [ARTICLE] Baixando: https://labnoticias.jor.br/2025/11/28/misoginia-e-violencia-verbal-como-situacoes-de-micro-agressao-contra-mulheres-se-tornou-algo-normalizado-no-cotidiano/
# [OK] Misoginia e violência verbal: Como situações de micro agressão contra mulheres s
# [ARTICLE] Baixando: https://labnoticias.jor.br/2025/11/28/uniao-entre-vila-e-goias-conheca-mais-sobre-o-goianos-fa-e-o-futebol-americano-nacional/
# [OK] União entre Vila e Goiás? Conheça mais sobre o Goianos FA e o futebol americano
# [ARTICLE] Baixando: https://labnoticias.jor.br/?page_id=31
# [WARN] Sem título ou texto, pulando: https://labnoticias.jor.br/?page_id=31
# [ARTICLE] Baixando: https://labnoticias.jor.br/expediente/
# [OK] Expediente
# [ARTICLE] Baixando: https://labnoticias.jor.br/sobre/
# [OK] Sobre
# [LIST] Página 2: https://labnoticias.jor.br/category/reportagens/page/2/
# [LIST] Encontradas 19 URLs de matérias na página 2.
# [ARTICLE] Baixando: https://labnoticias.jor.br/2025/11/04/celebridades-e-representacao-qual-e-o-papel-de-grandes-figuras-publicas-no-acolhimento-de-pessoas-lgbtqiapn/
# [OK] Celebridades e representação: qual é o papel de grandes figuras publicas no acol
# [ARTICLE] Baixando: https://labnoticias.jor.br/2025/11/04/consequencias-erosao-da-confianca-e-fragilidade-democratica/
# [OK] Como a desinformação afeta o voto e enfraquece a confiança no governo
# [ARTICLE] Baixando: https://labnoticias.jor.br/2025/11/04/crise-do-metanol-como-uma-substancia-pode-afetar-a-sociedade/
# [OK] Crise do Metanol: como uma substância pode afetar a sociedade
# [ARTICLE] Baixando: https://labnoticias.jor.br/2025/11/04/defesa-civil-alerta-saiba-tudo-sobre-essa-ferramenta-para-alertar-sobre-os-desastre-relacionados-as-mudancas-climaticas/
# [OK] Defesa Civil Alerta: saiba tudo sobre a ferramenta que emite alertas de desastre
# [ARTICLE] Baixando: https://labnoticias.jor.br/2025/11/04/faco-porque-e-obrigado-nao-tem-apelo-apesar-de-evolucao-o-futebol-femino-ainda-luta-para-crescer-no-goias/
# [OK] ‘Aqui em Goiás as pessoas não acreditam no feminino’: Apesar de evolução, futebo
# [ARTICLE] Baixando: https://labnoticias.jor.br/2025/11/04/infraestrutura-de-goiania-nao-suporta-chuvas-e-nao-da-sinais-de-melhora/
# [OK] Infraestrutura de Goiânia não suporta chuvas e não dá sinais de melhora
# [ARTICLE] Baixando: https://labnoticias.jor.br/2025/11/05/revitalizacao-do-centro-de-goiania-entre-planos-promessas-e-reocupacoes/
# [OK] Revitalização do centro de Goiânia: entre planos, promessas e reocupações
# [ARTICLE] Baixando: https://labnoticias.jor.br/2025/11/12/perspectivas-do-acesso-cultural-em-goiania-onde-ele-esta-e-quais-seus-agentes/
# [OK] Perspectivas do acesso cultural em Goiânia: onde ele está e quem são seus agente
# [ARTICLE] Baixando: https://labnoticias.jor.br/2025/11/25/comunidade-e-cultura-na-vera/
# [OK] Pela transmissão de valores e histórias, a cultura no bairro Vera Cruz perpetua
# [ARTICLE] Baixando: https://labnoticias.jor.br/2025/11/25/energia-solar-avanca-no-brasil-recorde-de-instalacoes-transforma-residencias-e-empresas/
# [OK] Energia solar avança no Brasil: recorde de instalações transforma residências e
# [LIST] Página 3: https://labnoticias.jor.br/category/reportagens/page/3/
# [LIST] Encontradas 20 URLs de matérias na página 3.
# [ARTICLE] Baixando: https://labnoticias.jor.br/2025/10/
# [OK] Mês:outubro 2025
# [ARTICLE] Baixando: https://labnoticias.jor.br/2025/10/26/cop-30-reacende-debate-sobre-o-cerrado-bioma-esquecido-pode-definir-o-futuro-climatico-do-brasil/
# [OK] COP 30 reacende debate sobre o Cerrado: bioma esquecido pode definir o futuro cl
# [ARTICLE] Baixando: https://labnoticias.jor.br/2025/11/04/a-nova-onda-do-tabagismo-entre-jovens-glamour-ou-reflexo-social/
# [OK] A nova onda do tabagismo entre jovens: glamour ou reflexo social?
# [ARTICLE] Baixando: https://labnoticias.jor.br/2025/11/04/desemprego-crise-e-abandono-por-que-ha-cada-vez-mais-pessoas-vivendo-nas-ruas-de-goiania/
# [OK] Desemprego, crise e abandono: por que há cada vez mais pessoas vivendo nas ruas
# [ARTICLE] Baixando: https://labnoticias.jor.br/2025/11/04/fios-soltos-em-goiania-expoem-falhas-no-planejamento-urbano/
# [OK] Fios soltos expõem falhas no planejamento urbano de Goiânia
# [ARTICLE] Baixando: https://labnoticias.jor.br/2025/11/04/goiania-apresenta-aumento-em-acidentes-de-transito-envolvendo-motociclistas/
# [OK] Goiânia apresenta aumento em acidentes de trânsito envolvendo motociclistas
# [ARTICLE] Baixando: https://labnoticias.jor.br/2025/11/04/igualdade-de-genero-no-meio-da-tecnologia-como-anda-e-expectativas-para-o-futuro/
# [OK] Igualdade de gênero no setor de tecnologia: o estado atual e as expectativas par
# [ARTICLE] Baixando: https://labnoticias.jor.br/2025/11/04/maternidade-e-mercado-de-trabalho/
# [OK] Maternidade e Mercado de Trabalho
# [ARTICLE] Baixando: https://labnoticias.jor.br/2025/11/04/metanol-em-bebidas-especialista-detalha-riscos-processos-de-controle-e-responsabilidade-da-industria/
# [OK] Metanol em bebidas: especialista detalha riscos, processos de controle e respons
# [ARTICLE] Baixando: https://labnoticias.jor.br/2025/11/04/mulheres-negras-nas-feiras-livres-de-goiania-resistencia-trabalho-e-identidade/
# [OK] Mulheres negras nas feiras livres de Goiânia: resistência, trabalho e identidade
# [ARTICLE] Baixando: https://labnoticias.jor.br/2025/11/04/prefeitura-de-goiania-planeja-concessao-de-parques-a-iniciativa-privada/
# [OK] Prefeitura de Goiânia planeja concessão de parques à iniciativa privada
# [LIST] Página 4: https://labnoticias.jor.br/category/reportagens/page/4/
# [LIST] Encontradas 21 URLs de matérias na página 4.
# [ARTICLE] Baixando: https://labnoticias.jor.br/2025/06/
# [OK] Mês:junho 2025
# [ARTICLE] Baixando: https://labnoticias.jor.br/2025/06/23/saiba-como-a-leishmaniose-manipula-o-sistema-de-defesa-do-corpo-humano/
# [OK] Saiba como a leishmaniose manipula o sistema de defesa do corpo humano
# [ARTICLE] Baixando: https://labnoticias.jor.br/2025/06/24/festival-fica-comemora-26-anos-com-obras-sobre-cerrado-mineracao-e-pertencimento/
# [OK] Festival FICA comemora 26 anos com obras sobre Cerrado, pertencimento e goianida
# [ARTICLE] Baixando: https://labnoticias.jor.br/2025/06/24/fica-o-festival-que-une-cinema-cultura-e-meio-ambiente-na-cidade-de-goias/
# [OK] FICA: O festival que une cinema, cultura e meio ambiente na Cidade de Goiás
# [ARTICLE] Baixando: https://labnoticias.jor.br/2025/06/24/low-carb-e-desinformacao-o-impacto-das-dietas-restritivas-na-saude/
# [OK] Low Carb e Desinformação: O Impacto das Dietas Restritivas na Saúde
# [ARTICLE] Baixando: https://labnoticias.jor.br/2025/06/24/nintendo-switch-2-comeca-sua-era-de-maneira-incrivel/
# [OK] Nintendo Switch 2 começa sua era de maneira incrível
# [ARTICLE] Baixando: https://labnoticias.jor.br/2025/06/24/quase-metade-dos-adultos-goianos-nao-concluiu-a-educacao-basica/
# [OK] Quase metade dos adultos goianos não concluiu a educação básica
# [ARTICLE] Baixando: https://labnoticias.jor.br/2025/06/25/gripe-aviaria-h5n1-brasil-controla-focos-goias-exportacao/
# [OK] Gripe Aviária (H5N1): Brasil controla focos em Goiás e no Sul e recupera mercado
# [ARTICLE] Baixando: https://labnoticias.jor.br/2025/06/25/km2-como-resistencia-novo-album-de-ebony-e-a-musica-como-espelho-social/
# [OK] KM2 como resistência: Novo álbum de Ebony e a música como espelho social
# [ARTICLE] Baixando: https://labnoticias.jor.br/2025/06/25/o-abandono-de-animais-o-cenario-do-descaso-nas-ruas-de-goiania/
# [OK] O abandono de animais: o cenário do descaso nas ruas de Goiânia
# [ARTICLE] Baixando: https://labnoticias.jor.br/2025/08/
# [OK] Mês:agosto 2025
# [ARTICLE] Baixando: https://labnoticias.jor.br/2025/08/30/crescimento-desordenado-da-rmg-provoca-desigualdades-aponta-especialista/
# [OK] Cresce a cidade, encolhe a dignidade: o custo da periferização na Grande Goiânia
# [LIST] Página 5: https://labnoticias.jor.br/category/reportagens/page/5/
# [LIST] Encontradas 21 URLs de matérias na página 5.
# [ARTICLE] Baixando: https://labnoticias.jor.br/2025/05/
# [OK] Mês:maio 2025
# [ARTICLE] Baixando: https://labnoticias.jor.br/2025/05/10/goias-em-cartaz-uma-pratica-em-constante-movimento/
# [OK] Goiás em cartaz: uma prática em constante movimento
# [ARTICLE] Baixando: https://labnoticias.jor.br/2025/05/10/imposto-de-renda-quem-pagar-2025/
# [OK] Imposto de renda desmistificado: quem tem que pagar o leão em 2025?
# [ARTICLE] Baixando: https://labnoticias.jor.br/2025/05/11/uma-alternativa-ao-plastico-de-uso-unico-materias-primas-biodegradaveis-se-consolidam-no-mercado-de-embalagens/
# [OK] Alternativa ao plástico de uso único: matérias-primas biodegradáveis se consolid
# [ARTICLE] Baixando: https://labnoticias.jor.br/2025/05/13/onde-encontrar-a-melhor-pamonha-de-goiania/
# [OK] Onde encontrar a melhor pamonha de Goiânia?
# [ARTICLE] Baixando: https://labnoticias.jor.br/2025/05/14/estudo-indica-que-pessoas-de-baixa-renda-sao-mais-dependentes-de-ambientes-arborizados-para-manutencao-da-saude-mental/
# [OK] Estudo indica que saúde mental de pessoas de baixa renda depende mais de ambient
# [ARTICLE] Baixando: https://labnoticias.jor.br/2025/05/21/as-sequelas-do-pos-pandemia-e-o-legado-da-covid-longa/
# [OK] As sequelas do Pós-Pandemia e o legado da Covid longa
# [ARTICLE] Baixando: https://labnoticias.jor.br/2025/06/07/caliandras-mulheres-empreendedoras-de-goias/
# [OK] Caliandras: Mulheres Empreendedoras de Goiás
# [ARTICLE] Baixando: https://labnoticias.jor.br/2025/06/12/feira-agro-centro-oeste-chega-a-sua-22a-edicao-ainda-mais-forte/
# [OK] Feira Agro Centro-Oeste chega à sua 22ª edição ainda mais forte
# [ARTICLE] Baixando: https://labnoticias.jor.br/2025/06/14/regiao-da-44-a-influencia-dessa-potencia-textil-na-economia-goiana/
# [OK] Região da 44: a influência da potência têxtil na economia goiana
# [ARTICLE] Baixando: https://labnoticias.jor.br/2025/06/21/educacao-verde-impacto-do-zoologico-na-conscientizacao-ambiental-dos-cidadaos/
# [OK] Educação Verde: O impacto do zoológico na conscientização ambiental dos cidadãos
# [LIST] Página 6: https://labnoticias.jor.br/category/reportagens/page/6/
# [LIST] Encontradas 21 URLs de matérias na página 6.
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/12/
# [OK] Mês:dezembro 2024
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/12/15/leitores-sao-minoria-no-brasil-cenario-preocupa/
# [OK] Leitores em queda: Pesquisa revela que 53% dos brasileiros não leem livros
# [ARTICLE] Baixando: https://labnoticias.jor.br/2025/05/07/a-tradicao-das-feiras-que-compoem-a-historia-da-capital-goiana-existe-ha-mais-de-60-anos/
# [OK] A tradição das feiras que compõem a história da capital goiana existe há mais de
# [ARTICLE] Baixando: https://labnoticias.jor.br/2025/05/07/desmatamento-fogo-e-seca-as-crises-ambientais-em-goias/
# [OK] Desmatamento, fogo e seca: as crises ambientais em Goiás
# [ARTICLE] Baixando: https://labnoticias.jor.br/2025/05/08/estudo-associa-alimentos-ultraprocessados-a-depressao/
# [SKIP old] Estudo associa alimentos ultraprocessados à depressão... (2025-06-12) < corte (2025-06-13)
# [ARTICLE] Baixando: https://labnoticias.jor.br/2025/05/08/por-que-doencas-erradicadas-estao-voltando-e-como-pode-se-proteger/
# [OK] Por que doenças erradicadas, como o sarampo, estão voltando? Como se proteger?
# [ARTICLE] Baixando: https://labnoticias.jor.br/2025/05/09/desvendando-a-realidade-das-mulheres-presas-em-goias/
# [OK] Desvendando a Realidade das Mulheres Presas em Goiás
# [ARTICLE] Baixando: https://labnoticias.jor.br/2025/05/09/os-zoomers-realmente-nao-querem-trabalhar-ou-isso-tudo-se-trata-de-um-conflito-geracional/
# [OK] Os Zoomers realmente não querem trabalhar ou isso tudo se trata de um conflito g
# [ARTICLE] Baixando: https://labnoticias.jor.br/2025/05/09/reducao-de-danos-ciencia-e-cuidado-como-alternativa-no-brasil/
# [OK] Redução de danos: ciência e cuidado como alternativa no Brasil
# [ARTICLE] Baixando: https://labnoticias.jor.br/2025/05/09/um-adeus-a-velha-gameleira-arvore-historica-e-removida-do-centro-de-goiania/
# [OK] Um adeus à velha gameleira: árvore histórica é removida do centro de Goiânia
# [ARTICLE] Baixando: https://labnoticias.jor.br/2025/05/10/rap-goianiense-a-conquista-de-espaco-nas-ruas-de-goiania/
# [OK] Rap goianiense: A Conquista de Espaço nas Ruas de Goiânia
# [LIST] Página 7: https://labnoticias.jor.br/category/reportagens/page/7/
# [LIST] Encontradas 20 URLs de matérias na página 7.
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/12/04/como-uma-pagina-na-rede-social-conecta-as-pessoas-por-meio-de-reflexoes/
# [OK] Como uma página na rede social conecta as pessoas por meio de reflexões
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/12/04/crescimento-do-mercado-de-podcasts-no-brasil-um-novo-fenomeno-de-consumo-digital/
# [OK] Crescimento do mercado de Podcasts no Brasil: Um novo fenômeno de consumo digita
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/12/04/dengue-em-goias-crescimento-de-casos-e-desafios-no-combate-a-epidemia/
# [OK] Dengue em Goiás: Casos crescem frente aos desafios no combate à epidemia
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/12/04/escalas-de-trabalho-no-brasil-os-impactos-na-produtividade-e-qualidade-de-vida-dos-trabalhadores/
# [OK] Escalas de trabalho no Brasil: 54% dos trabalhadores defendem a redução da carga
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/12/04/goiania-registra-queda-de-10-nos-casos-de-hiv-aids-nos-primeiros-nove-meses-de-2024/
# [SKIP old] Goiânia registra queda de 10% nos casos de HIV/AIDS nos prim... (2024-12-12) < corte (2025-06-13)
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/12/04/goias-foi-pouco-impactado-pela-pandemia-devido-a-producao-do-agronegocio/
# [OK] Na Pandemia, Goiás se Destaca Entre os Grandes Estados com Menor Impacto e Recor
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/12/04/moda-consciente-brechos-ganhando-espaco-em-goiania/
# [OK] Moda consciente: brechós ganhando espaço em Goiânia
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/12/04/taxa-de-jovens-goianos-fora-da-escola-e-do-trabalho-registra-queda-nos-ultimos-10-anos/
# [OK] Taxa de jovens goianos fora da escola e do trabalho registra queda nos últimos 1
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/12/04/violencia-virtual-crimes-de-odio-na-internet-chegam-a-mais-de-76-mil-casos-em-2024/
# [OK] Violência Virtual: Crimes de Ódio na Internet Chegam a Mais de 76 Mil Casos em 2
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/12/05/pensao-militar-novos-ajustes-sao-anunciados-pelo-ministro-da-fazenda/
# [OK] Pensão militar: novos ajustes são anunciados pelo ministro da Fazenda
# [LIST] Página 8: https://labnoticias.jor.br/category/reportagens/page/8/
# [LIST] Encontradas 21 URLs de matérias na página 8.
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/11/
# [OK] Mês:novembro 2024
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/11/25/diabetes-brasil-e-top-5-em-indice-da-doenca-no-mundo/
# [OK] Diabetes: Brasil é top 5 em índice da doença no mundo
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/11/29/o-desamparo-da-musica-independente/
# [OK] O Desamparo da Música Independente
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/12/02/a-moda-em-mutacao-uma-jornada-de-30-anos/
# [OK] A Moda em Mutação: Uma Jornada de 30 Anos
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/12/02/conheca-a-luta-dos-povos-quilombolas-em-goias/
# [SKIP old] Conheça a luta dos povos Quilombolas em Goiás... (2024-12-07) < corte (2025-06-13)
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/12/02/o-fim-da-infancia-como-conhecemos/
# [OK] O fim da infância como conhecemos
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/12/02/ruim-mesmo-e-aguentar-isso-sem-nenhum-respaldo-na-lei-diz-vitima-de-violencia-psicologica-pelo-ex/
# [OK] ‘Ruim mesmo é aguentar isso sem nenhum respaldo na lei’ diz vítima de violência
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/12/03/o-fiasco-do-golpe-a-resistencia-do-brasil-e-a-forca-da-democracia/
# [OK] O Fiasco do Golpe: A Resistência do Brasil e a Força da Democracia
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/12/04/a-luta-contra-a-violencia-infantil-no-brasil/
# [OK] A luta contra a violência infantil no Brasil
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/12/04/analise-das-avaliacoes-do-kindle-80-de-satisfacao-mas-problemas-tecnicos-persistem/
# [OK] Análise das avaliações do Kindle: 80% de satisfação, mas problemas técnicos pers
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/12/04/desemprego-atinge-115-das-mulheres-enquanto-taxa-entre-homens-e-de-79/
# [OK] Desemprego atinge 11,5% das mulheres, enquanto taxa entre homens é de 7,9%
# [LIST] Página 9: https://labnoticias.jor.br/category/reportagens/page/9/
# [LIST] Encontradas 21 URLs de matérias na página 9.
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/10/
# [OK] Mês:outubro 2024
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/10/30/adeus-a-liam-payne-o-legado-e-a-dor-da-despedida-entre-os-fas-da-one-direction/
# [OK] Adeus a Liam Payne: O legado e a dor da despedida entre os fãs da One Direction
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/10/30/camara-aprova-projeto-que-proibe-o-uso-de-celulares-em-escolas/
# [SKIP old] Câmara aprova projeto que proíbe o uso de celulares em escol... (2025-02-18) < corte (2025-06-13)
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/10/30/entre-a-paixao-e-a-violencia-as-confusoes-das-torcidas-organizadas/
# [SKIP old] Entre a Paixão e a Violência: As confusões das Torcidas Orga... (2025-02-20) < corte (2025-06-13)
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/10/30/projeto-de-lei-busca-aumentar-consumo-de-livros-no-brasil/
# [OK] Projeto de lei busca aumentar consumo de livros no Brasil
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/10/31/comercio-se-prepara-para-o-fim-de-ano-com-abertura-de-110-mil-vagas-temporarias/
# [OK] Comércio se prepara para o Fim de Ano com abertura de 110 mil vagas temporárias
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/11/11/conheca-as-consequencias-psicologicas-do-enem-e-vestibulares/
# [OK] Conheça as consequências psicológicas do ENEM e Vestibulares
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/11/11/enfisema-pulmonar-e-quinta-maior-causa-de-mortes-no-pais/
# [OK] Enfisema Pulmonar é quinta maior causa de mortes no país
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/11/11/escala-6x1-como-funciona-e-possivel-fim-de-uma-era-trabalhista/
# [OK] Escala 6×1: como funciona e possível fim de uma era trabalhista
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/11/11/o-amor-pelo-futebol-da-vida-real-para-o-videogame/
# [OK] O amor pelo futebol, da vida real para o videogame
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/11/11/o-outro-lado-da-moeda-como-a-tecnologia-beneficia-o-desenvolvimento-infantil/
# [OK] O outro lado da moeda: Como a tecnologia beneficia o desenvolvimento infantil
# [LIST] Página 10: https://labnoticias.jor.br/category/reportagens/page/10/
# [LIST] Encontradas 20 URLs de matérias na página 10.
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/10/30/a-influencia-da-cultura-estadunidense-no-brasil/
# [OK] A influência da cultura estadunidense no Brasil
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/10/30/a-invisibilidade-do-fotografo-a-divulgacao-da-imagem-e-a-desvalorizacao-do-fotografo/
# [OK] A (In)Visibilidade do Fotógrafo: Entre a divulgação da imagem e a desvalorização
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/10/30/acontece-agora-o-julgamento-de-marielle-franco-e-anderson-gomes/
# [OK] São condenados os assassinos de Marielle Franco e Anderson Gomes
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/10/30/aquecimento-global-urgencia-de-acao-e-desafios-futuros/
# [OK] Aquecimento Global: urgência de ação e desafios para o futuro
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/10/30/desastre-de-mariana-julgamento-pode-finalmente-dar-fim-a-luta-por-justica-pelas-vitimas/
# [OK] Desastre de Mariana: julgamento pode finalmente dar fim à luta por justiça pelas
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/10/30/desempenho-vs-eurocentrismo-a-verdade-por-tras-da-bola-de-ouro/
# [OK] Desempenho vs. Eurocentrismo: A Verdade por Trás da Bola de Ouro
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/10/30/fred-rodrigues-polemicas-e-investigacoes-entenda-o-caso/
# [OK] Fred Rodrigues: polêmicas e investigações – entenda o caso
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/10/30/o-fenomeno-da-corrida-por-que-todo-mundo-esta-correndo/
# [OK] O fenômeno da corrida: por que todo mundo está correndo?
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/10/30/o-fim-da-moda-desperdicada-a-revolucao-necessaria-para-salvar-nosso-planeta/
# [OK] O Fim da Moda Desperdiçada: A Revolução Necessária para Salvar Nosso Planeta
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/10/30/o-novo-comportamento-e-prioridades-do-turista-brasileiro-no-pos-pandemia/
# [OK] O Novo Comportamento e Prioridades do Turista Brasileiro no Pós-Pandemia:
# [LIST] Página 11: https://labnoticias.jor.br/category/reportagens/page/11/
# [LIST] Encontradas 21 URLs de matérias na página 11.
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/09/
# [OK] Mês:setembro 2024
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/09/04/brt-em-goiania-comeca-a-operar-apos-quase-10-anos-do-inicio-das-obras-veja-como-utilizar/
# [OK] BRT começa a operar em Goiânia após quase 10 anos do início das obras
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/09/04/cat-sitters-como-garantir-o-bem-estar-do-seu-gato-enquanto-voce-esta-fora/
# [OK] Cat Sitters: como garantir o bem-estar do seu gato enquanto você está fora
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/09/05/mulheres-no-esporte-digital-preconceito-ou-percepcao/
# [OK] Mulheres no Esporte Digital: Preconceito ou Percepção?
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/10/07/a-inclusao-de-alunos-indigenas-na-rede-de-educacao-estadual-de-goias/
# [OK] A inclusão de alunos indígenas na rede de educação estadual de Goiás
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/10/07/conheca-os-riscos-do-uso-excessivo-de-descongestionantes-nasais/
# [OK] Conheça os riscos do uso excessivo de descongestionantes nasais
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/10/07/dia-das-criancas-a-alegria-de-ser-acolhido-o-papel-dos-abrigos-e-da-igreja/
# [OK] Dia das Crianças: a alegria de ser acolhido – o papel dos Abrigos e da Igreja
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/10/07/fui-alvo-de-impedimentos-e-boicotes-constantes-o-que-mostra-que-a-violencia-politica-vai-muito-alem-das-agressoes-fisicas/
# [OK] ‘Fui alvo de impedimentos e boicotes constantes, o que mostra que a violência po
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/10/07/jovem-cearense-usa-o-instagram-para-informar-a-comunidade-e-sonha-com-a-faculdade-de-jornalismo/
# [SKIP old] Jovem cearense usa o Instagram para informar a comunidade e ... (2024-10-07) < corte (2025-06-13)
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/10/07/previsao-de-chuvas-acende-alerta-para-doencas-animais/
# [OK] Previsão de chuvas acende alerta para doenças animais
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/10/27/feminicidio-ate-quando/
# [OK] Feminicídio: Até quando?
# [LIST] Página 12: https://labnoticias.jor.br/category/reportagens/page/12/
# [LIST] Encontradas 20 URLs de matérias na página 12.
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/09/04/apos-dirigir-bebado-em-seu-patinete-eletrico-suga-pede-desculpas/
# [OK] Após dirigir bêbado em seu patinete elétrico, Suga pede desculpas
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/09/04/como-os-livros-podem-ser-uma-pratica-terapeutica-para-a-saude-mental/
# [OK] Como os livros podem ser uma prática terapêutica para a saúde mental?
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/09/04/entenda-a-morte-do-jogador-que-passou-mal-durante-partida-contra-o-sao-paulo-pela-copa-libertadores/
# [OK] Entenda a morte do jogador que passou mal durante partida contra o São Paulo pel
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/09/04/entenda-como-as-queimadas-em-areas-residenciais-afetam-voce/
# [OK] Entenda como as queimadas em áreas residenciais afetam você
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/09/04/geracao-z-mal-acostumados-ou-ciente-de-seus-direitos/
# [OK] Geração Z: Mal acostumados, ou ciente de seus direitos?
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/09/04/guanacity-rimas-que-transformam-o-jardim-guanabara-e-revitalizam-o-rap-em-goiania/
# [OK] Guanacity: Rimas que transformam o Jardim Guanabara e revitalizam o Rap em Goiân
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/09/04/homens-lideram-as-mortes-em-acidentes-mas-mulheres-sofrem-mais-machismo-no-transito/
# [OK] Homens lideram as mortes em acidentes, mas mulheres sofrem mais machismo no trân
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/09/04/mpox-uma-nova-pandemia/
# [OK] MPOX é novamente emergência de saúde pública, segundo a OMS
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/09/04/tempo-seco-e-umidade-baixa-goias-entra-em-alerta-vermelho/
# [OK] Tempo seco e umidade baixa: Goiás entra em alerta vermelho
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/09/04/tranformacao-digital-na-agricultura/
# [OK] Tranformação digital na agricultura
# [LIST] Página 13: https://labnoticias.jor.br/category/reportagens/page/13/
# [LIST] Encontradas 21 URLs de matérias na página 13.
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/06/
# [OK] Mês:junho 2024
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/06/10/abuso-verbal-psicologico-e-fisico-e-normalizado-na-rotina-de-trabalho/
# [OK] Abuso verbal, psicológico e físico é normalizado na rotina de trabalho?
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/06/10/beneficios-do-autocuidado-para-a-autoestima-masculina/
# [SKIP old] Benefícios do autocuidado para a autoestima masculina... (2024-06-11) < corte (2025-06-13)
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/06/11/desafio-em-dose-dupla-mulheres-enfrentam-territorio-masculino-em-campo-dominado/
# [OK] Desafio em dose dupla: Mulheres enfrentam território masculino em campo dominado
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/06/11/estudo-sobre-os-desafios-e-pontos-de-vista-de-professores-sobre-a-educacao-do-brasil/
# [OK] Estudo sobre os desafios e pontos de vista de professores sobre a educação do Br
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/06/11/geracao-recatada-troca-o-sexo-pelo-conteudo-digital/
# [OK] Geração recatada troca o sexo pelo conteúdo digital
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/06/11/ultimos-12-meses-sao-os-mais-quentes-da-historia/
# [OK] Últimos 12 meses são os mais quentes da história
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/06/12/estudo-da-fiocruz-brasil-teve-147-698-casos-de-suicidio-entre-2011-e-2022/
# [OK] Estudo da Fiocruz: Brasil teve 147.698 casos de suicídio entre 2011 e 2022
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/06/13/e-uma-forma-de-eu-devolver-ao-mundo-essa-boa-acao-junho-vermelho-um-incentivo-para-doacao-de-sangue/
# [OK] ‘É uma forma de eu devolver ao mundo essa boa ação’: Junho Vermelho, um incentiv
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/06/28/uso-de-software-livre-aprimora-gerenciamento-de-processos-administrativos-e-legislativos-na-camara-de-goiania/
# [OK] Uso de software livre aprimora gerenciamento de processos administrativos e legi
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/09/03/taxacao-do-sol-governo-brasileiro-cobra-imposto-pelo-uso-de-energia-solar/
# [OK] Taxação do Sol: Governo Brasileiro cobra imposto pelo uso de Energia Solar
# [LIST] Página 14: https://labnoticias.jor.br/category/reportagens/page/14/
# [LIST] Encontradas 20 URLs de matérias na página 14.
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/06/10/a-ascensao-da-inteligencia-artificial-nas-estrategias-de-vendas-b2b/
# [SKIP old] A ascensão da Inteligência Artificial nas estratégias de ven... (2024-12-12) < corte (2025-06-13)
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/06/10/a-importancia-das-festas-juninas-no-fomento-a-economia-e-a-cultura-brasileira/
# [OK] A importância das festas juninas no fomento à economia e à cultura brasileira
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/06/10/aumento-de-ataques-de-caes-no-brasil/
# [SKIP old] Aumentam os registros de ataques de cães no Brasil... (2024-07-10) < corte (2025-06-13)
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/06/10/conheca-bazar-beneficente-no-asilo-solar-colombino-augusto-de-bastos/
# [OK] Conheça o bazar beneficente no Asilo Solar Colombino Augusto de Bastos
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/06/10/estrangeiros-vivendo-no-brasil-numero-de-pessoas-aumenta-a-cada-ano/
# [OK] Estrangeiros vivendo no Brasil: número de pessoas aumenta a cada ano
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/06/10/estudantes-que-moram-em-cidades-do-interior-de-goias-enfrentam-desafios-para-cursar-o-ensino-superior/
# [OK] Estudantes que moram em cidades do interior de Goiás enfrentam desafios para cur
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/06/10/junho-vermelho-o-mes-da-conscientizacao-sobre-a-doacao-de-sangue/
# [OK] Junho vermelho: mês da conscientização sobre a Doação de Sangue
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/06/10/movimentos-negros-e-a-internet-a-disseminacao-de-informacao-e-a-luta-contra-o-racismo/
# [OK] Movimentos negros e a internet: a disseminação de informação e a luta contra o r
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/06/10/o-mercado-de-jornais-no-mundo-atual/
# [OK] O mercado de jornais no mundo atual
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/06/10/sessao-azul-conheca-o-cinema-adaptado-para-acolher-criancas-autistas/
# [OK] Sessão Azul: conheça o cinema adaptado para acolher crianças autistas
# [LIST] Página 15: https://labnoticias.jor.br/category/reportagens/page/15/
# [LIST] Encontradas 21 URLs de matérias na página 15.
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/05/
# [OK] Mês:maio 2024
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/05/07/goias-apresenta-solo-fertil-para-novos-empreendedores-em-2024/
# [SKIP old] Goiás apresenta solo fértil para novos empreendedores em 202... (2024-09-11) < corte (2025-06-13)
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/05/20/mulheres-a-frente-desafios-e-conquistas-no-empreendedorismo/
# [SKIP old] Mulheres à frente: desafios e a revolução local através dos ... (2024-09-11) < corte (2025-06-13)
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/06/10/a-importancia-da-atividade-fisica-no-tratamento-da-ansiedade-e-depressao/
# [OK] A importância da atividade física no tratamento da ansiedade e depressão
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/06/10/a-prefeitura-de-goiania-tenta-trazer-o-centro-da-cidade-de-volta-a-vida/
# [OK] A Prefeitura de Goiânia tenta trazer o centro da cidade de volta à vida
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/06/10/brt-norte-sul-prefeitura-de-goiania-promete-entrega-em-breve-apos-anos-de-atraso-e-problemas-de-gestao/
# [OK] BRT Norte-Sul: Prefeitura de Goiânia promete entrega em breve após anos de atras
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/06/10/como-a-janela-de-libras-promove-acessibilidade-para-surdos-em-producoes-audiovisuais-politicas/
# [OK] Como a janela de libras promove acessibilidade para surdos em produções audiovis
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/06/10/comunidades-da-amazonia-se-unem-na-luta-contra-o-desmatamento/
# [OK] Comunidades da Amazônia se unem na luta contra o desmatamento
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/06/10/o-impacto-do-futebol-na-educacao-e-no-desenvolvimento-pessoal/
# [SKIP old] O Impacto do Futebol na Educação e no Desenvolvimento Pessoa... (2024-10-03) < corte (2025-06-13)
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/06/10/poliomielite-pode-voltar-a-circular-no-brasil-entenda-a-gravidade-da-doenca/
# [OK] Poliomielite pode voltar a circular no Brasil: entenda a gravidade da doença
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/06/10/revolucao-digital-como-a-ia-esta-transformando-o-mercado-de-trabalho/
# [SKIP old] Revolução Digital: Como a IA está transformando o mercado de... (2024-09-04) < corte (2025-06-13)
# [LIST] Página 16: https://labnoticias.jor.br/category/reportagens/page/16/
# [LIST] Encontradas 21 URLs de matérias na página 16.
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/04/
# [OK] Mês:abril 2024
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/04/29/a-importancia-de-estudar-musica-nas-escolas-e-incentivar-os-jovens-a-entrar-no-mundo-musical/
# [OK] A importância de estudar música nas escolas e incentivar os jovens a entrar no m
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/04/29/alta-demanda-e-carencia-de-estrutura-os-desafios-do-transporte-coletivo-em-goiania-2/
# [OK] Alta demanda e carência de estrutura: Os desafios do Transporte Coletivo em Goiâ
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/04/29/brasil-e-reconhecido-pela-onu-como-um-dos-melhores-formadores-de-cirurgioes-dentistas-do-mundo-saiba-como-clinicas-escola-contribuem-para-essa-conquista/
# [OK] Clínicas-escola contribuem para tornar o Brasil um dos melhores formadores de ci
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/04/29/os-impactos-das-amizades-na-saude-mental-e-fisica-das-mulheres/
# [OK] Os impactos das amizades na saúde mental e física das mulheres
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/04/30/relacao-do-uso-de-cigarro-eletronico-com-a-saude-bucal-e-os-riscos-para-a-saude-em-geral/
# [OK] Relação do uso de cigarro eletrônico com a saúde bucal e os riscos para a saúde
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/05/04/o-peso-da-questao-desafios-do-sobrepeso-na-sociedade-moderna/
# [OK] O Peso da Questão: Desafios do sobrepeso na sociedade moderna
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/05/06/os-impactos-dos-efeitos-climaticos-do-el-nino-e-la-nina-na-saude-e-na-agricultura/
# [WARN] Sem título ou texto, pulando: https://labnoticias.jor.br/2024/05/06/os-impactos-dos-efeitos-climaticos-do-el-nino-e-la-nina-na-saude-e-na-agricultura/
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/05/07/como-a-ausencia-de-dados-sobre-o-sistema-penitenciario-afeta-a-seguranca-publica-no-brasil/
# [OK] Como a ausência de dados sobre o sistema penitenciário afeta a segurança pública
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/05/07/por-que-o-army-e-considerado-o-maior-fandom-do-mundo/
# [OK] Por que o ARMY é considerado o maior fandom do mundo?
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/05/07/times-gauchos-solicitam-adiamento-de-atividades-por-20-dias/
# [OK] Times gaúchos solicitam adiamento de atividades por 20 dias
# [LIST] Página 17: https://labnoticias.jor.br/category/reportagens/page/17/
# [LIST] Encontradas 20 URLs de matérias na página 17.
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/04/29/bastidores-no-mundo-do-fisiculturismo/
# [SKIP old] Bastidores no mundo do fisiculturismo... (2024-12-25) < corte (2025-06-13)
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/04/29/descontentamento-dos-passageiros-transporte-publico-de-goiania-sofre-com-falta-de-confiabilidade-atrasos-persistentes-e-falta-de-estrutura-dos-veiculos/
# [OK] Desafios no Transporte Público: Lotação e atrasos
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/04/29/em-campo-desigual-a-luta-das-mulheres-por-mais-reconhecimento-no-jornalismo-esportivo/
# [OK] Em campo desigual: a luta das mulheres por mais reconhecimento no jornalismo esp
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/04/29/futebol-entre-as-quatro-linha-a-importancia-do-futebol-na-vida-de-um-torcedor/
# [OK] Futebol entre as quatro linhas: A importância do futebol na vida de um torcedor
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/04/29/jornalismo-e-a-graduacao-com-o-maior-indice-de-arrependimentos/
# [OK] Jornalismo é a graduação com o maior índice de  arrependimentos
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/04/29/os-beneficios-inegaveis-da-musculacao-para-o-corpo-e-a-mente/
# [OK] Os benefícios inegáveis da musculação para o corpo e a mente
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/04/29/pais-no-incentivo-da-leitura-cada-vez-que-voce-vira-a-pagina-de-um-livro-e-uma-nova-forma-de-leitura-de-voce-interpretar-o-mundo-para-a-crianca/
# [OK] Pais no incentivo da leitura:’ Cada vez que você vira a página de um livro, é um
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/04/29/quem-sonha-sempre-alcanca-o-jogo-da-vida-no-mundo-do-futebol/
# [OK] Quem sonha sempre alcança? O “jogo” da vida no mundo do futebol
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/04/29/reduzir-uso-de-veiculos-um-dos-desafios-da-mobilidade-urbana-em-goiania/
# [OK] Reduzir uso de veículos é um dos desafios da mobilidade urbana em Goiânia
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/04/29/tricampeao-goiano-vem-enfrentando-ma-fase-na-serie-a-do-campeonato-brasileiro/
# [OK] Tricampeão goiano vem enfrentando má fase na série A do campeonato brasileiro
# [LIST] Página 18: https://labnoticias.jor.br/category/reportagens/page/18/
# [LIST] Encontradas 21 URLs de matérias na página 18.
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/03/
# [OK] Mês:março 2024
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/03/13/o-silencio-das-patinhas-e-o-barulho-mais-alto-da-crueldade-humana/
# [OK] O silêncio das patinhas é o barulho mais alto da crueldade humana
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/04/29/a-baixa-atuacao-das-mulheres-na-politica-e-os-aspectos-negativos-de-candidatas-laranja/
# [OK] A baixa atuação das mulheres na política e os aspectos negativos de candidatas “
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/04/29/agindo-contra-os-acidentes-de-trabalho-goias-em-destaque-no-abril-verde/
# [OK] Agindo contra os acidentes de trabalho: Goiás em destaque no Abril Verde
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/04/29/carros-eletricos-x-convencionais-qual-a-melhor-escolha/
# [OK] ‘Carros elétricos x convencionais’: qual a melhor escolha?
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/04/29/estudantes-de-administracao-estao-aprendendo-na-pratica-com-entrega-de-marmitas-para-pessoas-em-situacao-de-rua/
# [OK] Estudantes de Administração estão aprendendo na prática com entrega de marmitas
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/04/29/evangelizacao-infantil-moldando-o-futuro-atraves-do-evangelho/
# [OK] Evangelização Infantil: Moldando o futuro através do evangelho
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/04/29/os-desafios-enfrentados-por-artistas-independentes-na-industria-musical/
# [OK] Os desafios enfrentados por artistas independentes na indústria musical
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/04/29/os-desafios-na-busca-de-um-diagnostico-autista-para-pessoas-carentes/
# [OK] Os desafios na busca de um diagnóstico autista para pessoas carentes
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/04/29/quem-e-john-textor-empresario-e-proprietario-da-saf-do-botafogo-de-futebol-e-regatas/
# [OK] Mundo do futebol: história de John Textor e suas revelações sobre a manipulação
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/04/29/resistencia-ancestral-a-luta-pela-visibilidade-dos-povos-indigenas-no-brasil/
# [OK] Resistência Ancestral: A luta pela visibilidade dos povos indígenas no Brasil
# [LIST] Página 19: https://labnoticias.jor.br/category/reportagens/page/19/
# [LIST] Encontradas 21 URLs de matérias na página 19.
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/01/
# [OK] Mês:janeiro 2024
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/01/24/calendario-da-ufg-desalinhado-entenda-os-motivos/
# [SKIP old] Calendário Desalinhado na UFG: Entenda as Razões e Consequên... (2024-04-29) < corte (2025-06-13)
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/01/24/rumo-ao-estrelato-a-busca-pelo-sucesso-na-capital-do-sertanejo/
# [OK] Rumo ao estrelato: a busca pelo sucesso na capital do sertanejo
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/01/26/30-milhoes-de-animais-estao-nas-ruas-segundo-dados-da-organizacao-mundial-da-saude-oms/
# [SKIP old] 30 milhões de animais estão nas ruas, segundo dados da Organ... (2024-08-13) < corte (2025-06-13)
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/01/30/os-beneficios-da-terapia-de-liberacao-de-trauma-tre/
# [OK] Os benefícios da Terapia de Liberação de Trauma, a TRE
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/03/12/atleta-encontra-oportunidade-em-esporte-pouco-popular/
# [OK] Atleta encontra oportunidade em esporte pouco popular
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/03/12/como-a-ia-tem-contribuido-para-a-producao-de-conteudos-que-sexualizam-mulheres-e-criancas/
# [OK] Como a IA tem contribuído para a produção de conteúdos que sexualizam mulheres e
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/03/12/conheca-o-impacto-das-mulheres-no-esporte-a-motor/
# [OK] Conheça o impacto das mulheres no esporte a motor
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/03/12/dupla-face-da-tecnologia-os-beneficios-e-perigos-da-inteligencia-artificial/
# [OK] Dupla face da tecnologia: os benefícios e perigos da Inteligência Artificial
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/03/12/goiania-saints-futebol-americano-uma-cultura-do-exterior-que-reside-em-goias/
# [OK] ‘Goiânia Saints Futebol Americano’: uma cultura do exterior que reside em Goiás
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/03/12/maes-relatam-dificuldades-na-amamentacao-e-a-importancia-do-leite-materno/
# [OK] Mães relatam dificuldades na amamentação e a importância do leite materno
# [LIST] Página 20: https://labnoticias.jor.br/category/reportagens/page/20/
# [LIST] Encontradas 20 URLs de matérias na página 20.
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/01/24/alem-do-sertanejo-o-eletrofunk-como-novo-simbolo-cultural-goiano/
# [OK] Além do sertanejo: o eletrofunk como novo símbolo cultural goiano
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/01/24/as-vezes-quem-precisa-da-visita-somos-nos-mesmos-e-de-humano-para-humano-entenda-a-importancia-do-trabalho-voluntario-e-suas-diferentes-faces/
# [OK] ‘Às vezes quem precisa da visita somos nós mesmos, é de humano para humano’: Ent
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/01/24/carnaval-seguro-prevencao-contra-ists/
# [OK] Carnaval seguro: prevenção contra ISTs
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/01/24/futebol-e-doacao-de-sangue-seu-gol-de-placa-e-realmente-salvar-vidas/
# [OK] Futebol e doação de sangue: ‘Seu gol de Placa é realmente salvar vidas’
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/01/24/hipertrofia-feminina-o-preconceito-e-a-superacao/
# [OK] Hipertrofia feminina: o preconceito e a superação
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/01/24/janeiro-branco-a-influencia-do-vicio-tecnologico-na-saude-mental-dos-jovens/
# [OK] Janeiro Branco: a influência do vicio tecnológico na saúde mental dos jovens
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/01/24/moda-sustentavel-como-goiania-esta-incorporando-a-sustentabilidade-ao-cenario-fashion/
# [OK] Moda sustentável: como Goiânia está incorporando a sustentabilidade ao cenário f
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/01/24/nosso-lar/
# [OK] NOSSO LAR 2: Filme baseado na obra de Chico Xavier volta aos cinemas
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/01/24/odio-contra-criancas-por-que-um-discurso-aceito/
# [OK] Ódio contra crianças: por que um discurso aceito?
# [ARTICLE] Baixando: https://labnoticias.jor.br/2024/01/24/perpetuacao-da-violencia-contra-a-mulher/
# [OK] ‘Lei não trata pessoas gestantes como capazes de tomar decisões sobre sua vida r
# [DONE] Crawl Lab Notícias finalizado.

# %%
import pandas as pd

conn = get_conn()
df = pd.read_sql_query("""
    SELECT *
    FROM labnoticias_reportagens
    ORDER BY id DESC
""", conn)
conn.close()

df
# Out:
#       id                                              title subtitle  \
# 0    200  ‘Lei não trata pessoas gestantes como capazes ...     None
# 1    199  Ódio contra crianças: por que um discurso aceito?     None
# 2    198  NOSSO LAR 2: Filme baseado na obra de Chico Xa...     None
# 3    197  Moda sustentável: como Goiânia está incorporan...     None
# 4    196  Janeiro Branco: a influência do vicio tecnológ...     None
# ..   ...                                                ...      ...
# 195    5  Entre o 25 de março e o 20 de novembro: o Cear...     None
# 196    4  Aparecida de Goiânia: 62 anos de emancipação d...     None
# 197    3  A floresta que vale bilhões: como o mercado de...     None
# 198    2                                  Mês:novembro 2025     None
# 199    1                                       Lab Notícias     None
#
#                                                    url      section  city  \
# 0    https://labnoticias.jor.br/2024/01/24/perpetua...  Reportagens  None
# 1    https://labnoticias.jor.br/2024/01/24/odio-con...  Reportagens  None
# 2     https://labnoticias.jor.br/2024/01/24/nosso-lar/  Reportagens  None
# 3    https://labnoticias.jor.br/2024/01/24/moda-sus...  Reportagens  None
# 4    https://labnoticias.jor.br/2024/01/24/janeiro-...  Reportagens  None
# ..                                                 ...          ...   ...
# 195  https://labnoticias.jor.br/2025/11/28/entre-o-...  Reportagens  None
# 196  https://labnoticias.jor.br/2025/11/28/aparecid...  Reportagens  None
# 197  https://labnoticias.jor.br/2025/11/28/a-flores...  Reportagens  None
# 198                https://labnoticias.jor.br/2025/11/  Reportagens  None
# 199                        https://labnoticias.jor.br/  Reportagens  None
#
#                                                 author  \
# 0                               ANDRESSA MOREIRA BUENO
# 1         Natália EduardaAcadêmica de Jornalismo | UFG
# 2    FRANCISCA PATRICIA DE SOUZA SILVAestudante de ...
# 3    Ana Beatriz MilhomemEstudante de jornalismo pe...
# 4    Julhia Mendes BritoEstudante de Jornalismo na ...
# ..                                                 ...
# 195  Tiago CalebEstudante de Jornalismo na UFG. Apa...
# 196  Fernando SilveiraEstudante de Jornalismo na Un...
# 197  Luiza GuimarãesEstudante de jornalismo na UFG....
# 198                                               Mês:
# 199                                       Lab Notícias
#
#                                           published_at updated_at  \
# 0                              - 24 de janeiro de 2024       None
# 1                              - 24 de janeiro de 2024       None
# 2                               - 11 de agosto de 2024       None
# 3                              - 24 de janeiro de 2024       None
# 4                              - 24 de janeiro de 2024       None
# ..                                                 ...        ...
# 195  Entre o 25 de março e o 20 de novembro: o Cear...       None
# 196  Aparecida de Goiânia: 62 anos de emancipação d...       None
# 197                           - 28 de novembro de 2025       None
# 198                       novembro 2025 - Lab Notícias       None
# 199  Aparecida de Goiânia: 62 anos de emancipação d...       None
#
#                                                   text  \
# 0    Aprovada no dia 11 de janeiro de 2024 pela Ass...
# 1    O comentário capturado em um perfil no Instagr...
# 2    Dia 25 de janeiro chega nas telonas “Nosso Lar...
# 3    Cotidianamente lojas nos bombardeiam com novas...
# 4    JANEIRO BRANCO\n\nO Janeiro Branco é uma campa...
# ..                                                 ...
# 195  No dia 25 de março, o estado do Ceará celebra ...
# 196  Foi no ano de 1922, com a construção de uma ig...
# 197  Como o mercado de créditos de carbono virou di...
# 198  Nos últimos anos, Goiânia vem passando por uma...
# 199  Laboratório de jornalismo digital da UFG e da ...
#
#                                                   tags  \
# 0    ["educação", "esportes", "economia", "cultura"...
# 1    ["educação", "esportes", "economia", "cultura"...
# 2    ["educação", "esportes", "economia", "cultura"...
# 3    ["educação", "esportes", "economia", "cultura"...
# 4    ["educação", "esportes", "economia", "cultura"...
# ..                                                 ...
# 195  ["educação", "esportes", "economia", "cultura"...
# 196  ["educação", "esportes", "economia", "cultura"...
# 197  ["educação", "esportes", "economia", "cultura"...
# 198  ["educação", "esportes", "economia", "cultura"...
# 199  ["educação", "esportes", "economia", "cultura"...
#
#                                               raw_html  \
# 0    <!DOCTYPE html>\n<html lang="pt-BR">\n<head>\n...
# 1    <!DOCTYPE html>\n<html lang="pt-BR">\n<head>\n...
# 2    <!DOCTYPE html>\n<html lang="pt-BR">\n<head>\n...
# 3    <!DOCTYPE html>\n<html lang="pt-BR">\n<head>\n...
# 4    <!DOCTYPE html>\n<html lang="pt-BR">\n<head>\n...
# ..                                                 ...
# 195  <!DOCTYPE html>\n<html lang="pt-BR">\n<head>\n...
# 196  <!DOCTYPE html>\n<html lang="pt-BR">\n<head>\n...
# 197  <!DOCTYPE html>\n<html lang="pt-BR">\n<head>\n...
# 198  <!DOCTYPE html>\n<html lang="pt-BR">\n<head>\n...
# 199  <!DOCTYPE html>\n<html lang="pt-BR">\n<head>\n...
#
#                            scraped_at
# 0    2025-12-10T19:58:54.873577+00:00
# 1    2025-12-10T19:58:53.149560+00:00
# 2    2025-12-10T19:58:51.469383+00:00
# 3    2025-12-10T19:58:49.827851+00:00
# 4    2025-12-10T19:58:48.084783+00:00
# ..                                ...
# 195  2025-12-10T19:52:17.037024+00:00
# 196  2025-12-10T19:52:15.303088+00:00
# 197  2025-12-10T19:52:13.704379+00:00
# 198  2025-12-10T19:52:12.029530+00:00
# 199  2025-12-10T19:52:10.167647+00:00
#
# [200 rows x 13 columns]

# %%
df.to_csv("lab_noticias.csv")
